# %% [markdown]
# #Cài đặt thư viện và import dữ liệu

# %%
import warnings
warnings.filterwarnings('ignore')
# Out:
# time: 730 µs (started: 2023-12-23 04:52:05 +00:00)

# %%
# !pip install nltk
# !pip install underthesea
# !pip install pyvi
# !pip install langid
# !pip install num2words
# !pip install vietnam-number
# !pip install tensorflow
# !pip install --upgrade keras tensorflow
# !pip install prettytable
# !pip install imblearn
# !pip install visualkeras
# !pip install -q ipython-autotime
# %load_ext autotime
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# Collecting underthesea
#   Downloading underthesea-6.8.0-py3-none-any.whl (20.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 45.5 MB/s eta 0:00:00
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.10/dist-packages (from underthesea) (8.1.7)
# Collecting python-crfsuite>=0.9.6 (from underthesea)
#   Downloading python_crfsuite-0.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.0 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from underthesea) (3.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from underthesea) (4.66.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from underthesea) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from underthesea) (1.3.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from underthesea) (1.2.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from underthesea) (6.0.1)
# Collecting underthesea-core==1.0.4 (from underthesea)
#   Downloading underthesea_core-1.0.4-cp310-cp310-manylinux2010_x86_64.whl (657 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.8/657.8 kB 49.8 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->underthesea) (2023.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->underthesea) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->underthesea) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->underthesea) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->underthesea) (2023.11.17)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->underthesea) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->underthesea) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->underthesea) (3.2.0)
# Installing collected packages: underthesea-core, python-crfsuite, underthesea
# Successfully installed python-crfsuite-0.9.10 underthesea-6.8.0 underthesea-core-1.0.4
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 40.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pyvi) (1.2.2)
# Collecting sklearn-crfsuite (from pyvi)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyvi) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyvi) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyvi) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyvi) (3.2.0)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->pyvi) (0.9.10)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->pyvi) (1.16.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->pyvi) (4.66.1)
# Installing collected packages: sklearn-crfsuite, pyvi
# Successfully installed pyvi-0.1.1 sklearn-crfsuite-0.3.6
# Collecting langid
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 20.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from langid) (1.23.5)
# Building wheels for collected packages: langid
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941172 sha256=7b109f2ef53ba98e603bd74a0da3f7eceb8ada9de745b809355c72a9519653ec
#   Stored in directory: /root/.cache/pip/wheels/23/c8/c6/eed80894918490a175677414d40bd7c851413bbe03d4856c3c
# Successfully built langid
# Installing collected packages: langid
# Successfully installed langid-1.1.6
# Collecting num2words
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 2.7 MB/s eta 0:00:00
# Collecting docopt>=0.6.2 (from num2words)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=c42ef08082e5da7ce58e48371c53584dd45fa757bfdda3045c06883fc2dedcaa
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.13
# Collecting vietnam-number
#   Downloading vietnam_number-1.0.3-py3-none-any.whl (21 kB)
# Installing collected packages: vietnam-number
# Successfully installed vietnam-number-1.0.3
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting keras
#   Downloading keras-3.0.2-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.15.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.23.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.0)
# Collecting namex (from keras)
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras) (0.1.8)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Installing collected packages: tensorflow
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# Successfully installed tensorflow-2.15.0.post1
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable) (0.2.12)
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (3.2.0)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 16.6 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18 visualkeras-0.0.2
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.3 MB/s eta 0:00:00
# time: 535 µs (started: 2023-12-23 04:52:03 +00:00)

# %%
# mô hình tiếng Anh của spaCy
# !python -m spacy download en_core_web_sm
# Out:
# 2023-12-22 12:08:50.947695: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-22 12:08:50.947763: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-22 12:08:50.949161: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-22 12:08:50.957475: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-22 12:08:52.465713: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 23.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# time: 26.7 s (started: 2023-12-22 12:08:44 +00:00)

# %%
import pandas as pd
import numpy as np
import re
import regex
import string
from wordcloud import WordCloud
import operator
import spacy
import joblib as jlb
# Out:
# time: 19.2 s (started: 2023-12-23 04:52:11 +00:00)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import sent_tokenize as eng_sent

from underthesea import word_tokenize, pos_tag, sent_tokenize as vie_sent
from pyvi import ViPosTagger, ViTokenizer, ViUtils

import langid
from vietnam_number import n2w
import num2words
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# time: 5.78 s (started: 2023-12-23 04:52:31 +00:00)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
# Out:
# time: 620 ms (started: 2023-12-23 04:52:38 +00:00)

# %%
from nltk.classify import NaiveBayesClassifier
from nltk.classify import MaxentClassifier

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, precision_recall_fscore_support, classification_report
from sklearn.utils.class_weight import compute_class_weight

import pickle as pkl
import tensorflow as tf

from keras.layers import Embedding, Dense, Dropout, Bidirectional, LSTM, GRU, Input, GlobalMaxPooling1D, LayerNormalization, Conv1D, MaxPooling1D
from keras.optimizers import Adam
from keras.models import load_model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import plot_model
# Out:
# time: 4.78 ms (started: 2023-12-23 04:52:40 +00:00)

# %%
# https://drive.google.com/uc?id=1A8UreFunzXKY8z_ItXNl3kZMVlBla-kk
# !gdown 1A8UreFunzXKY8z_ItXNl3kZMVlBla-kk
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1A8UreFunzXKY8z_ItXNl3kZMVlBla-kk
# To: /content/UEH-reviews-cleaned.xlsx
# 100% 77.8k/77.8k [00:00<00:00, 58.1MB/s]
# time: 2.05 s (started: 2023-12-23 04:52:43 +00:00)

# %% [markdown]
# # Tiền xử lý và EDA

# %% [markdown]
# ## EDA

# %%
file = r'UEH-reviews-cleaned.xlsx'
raw_df = pd.read_excel(file, sheet_name='Sheet1')
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 841 entries, 0 to 840
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   reviewer   841 non-null    object
#  1   date       841 non-null    object
#  2   stars      831 non-null    float64
#  3   likes      262 non-null    float64
#  4   context    841 non-null    object
#  5   location   841 non-null    object
#  6   sentiment  841 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 46.1+ KB
# time: 1.26 s (started: 2023-12-23 04:52:51 +00:00)

# %%
raw_df.head(10)
# Out:
#                  reviewer         date  stars  likes  \
# 0        Thanh Nam Nguyễn  6 years ago    4.0    NaN
# 1  Vincent magnus Kenneth  2 years ago    5.0    NaN
# 2        Binh Phuong Tang   a year ago    5.0    NaN
# 3          Trà Lê Thị Thu  3 years ago    5.0    NaN
# 4               Long Trần  4 years ago    5.0    NaN
# 5            hakun nguyen  7 years ago    5.0    NaN
# 6                  Văn Lê   a year ago    5.0    NaN
# 7                Huy Trần  9 years ago    4.0    NaN
# 8               Thiên Bùi   a year ago    5.0    NaN
# 9              Gia Nguyen  7 years ago    4.0    NaN
#
#                                              context location sentiment
# 0  One of the best universities in Vietnam\n I m ...     uehA  positive
# 1  Trường sạch đẹp, giảng viên dễ thương,chương t...     uehA  positive
# 2  Cơ sở vật chất hiện đại, thật tuyệt vời. 1 trư...     uehB  positive
# 3  Ngôi trường có đội ngũ giáo viên giỏi, nhiệt t...     uehA  positive
# 4  Hay tự ý đổi lịch học của học sinh :)\n nhưng ...     uehI  positive
# 5  Truong rat dep. Có sân bóng chuyền, cầu lông, ...    uehQ8  positive
# 6  Cơ sở vật chất hiện đại, không gian xanh và th...     uehN  positive
# 7  Được mỗi cái cơ sở này là đây đủ tiện nghi, và...     uehB  positive
# 8  Trường rộng rãi, thoáng mát. Bãi đậu xe rộng r...     uehB  positive
# 9  Nơi đào tạo các chuyên ngành kinh tế uy tính c...     uehB  positive
# time: 19.2 ms (started: 2023-12-23 04:52:54 +00:00)

# %%
df = raw_df.copy()
# Out:
# time: 1.15 ms (started: 2023-12-23 04:52:56 +00:00)

# %%
df['context'].str.len().hist()
plt.title("Sô lượng chữ ở mỗi cmt")
plt.show()
# Out:
# time: 343 ms (started: 2023-12-23 04:52:57 +00:00)

# %%
# Lọc và hiển thị các dòng có số từ trên 500
over500_text_rows = df[df['context'].str.split().apply(len) > 500]
# Tổng số dòng có số từ lớn hơn 500
total_rows = len(over500_text_rows)
print(f"Tổng số dòng có số từ trên 500: {total_rows}")
# Hiển thị thông tin về các dòng đó
print("Các dòng có số từ trên 500:")
for index, row in over500_text_rows.iterrows():
    print(f"Index: {index}")
# Out:
# Tổng số dòng có số từ trên 500: 5
# Các dòng có số từ trên 500:
# Index: 673
# Index: 697
# Index: 698
# Index: 711
# Index: 726
# time: 16.7 ms (started: 2023-12-23 04:52:59 +00:00)

# %%
count_col_stars = df['stars'].value_counts().reset_index(name='count')
# Vẽ barplot với số lượng và khoảng cách giữa số và cột
plt.figure(figsize=(8, 6))
ax = sns.barplot(x='index', y='count', data=count_col_stars)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height() + 0.05 * ax.get_ylim()[1]),
                ha='center', va='baseline', fontsize=10, color='black')
plt.xlabel("Rating")
plt.ylabel("Count")
plt.title("Number of data for each rating")
plt.ylim(0, 700)
plt.show()
# Out:
# time: 258 ms (started: 2023-12-23 04:53:00 +00:00)

# %%
labels = count_col_stars['index']
sizes = count_col_stars['count']
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Tỷ lệ % theo điểm đánh giá ')
plt.show()
# Out:
# time: 188 ms (started: 2023-12-23 04:53:04 +00:00)

# %% [markdown]
# ## Tiền xử lý

# %% [markdown]
# https://viblo.asia/p/tien-xu-li-du-lieu-van-ban-voi-nltk-Az45b0LgZxY
# https://github.com/ChauLu38/Shopee_Comments_Sentiment/blob/main/Shopee_Sentiments_Step3.ipynb
# https://github.com/JNoether/Multi_Intent_Recognition/blob/main/Model.ipynb
# https://thecleverprogrammer.com/2020/12/06/resume-screening-with-python/
# https://github.com/adashofdata/nlp-in-python-tutorial
# https://viblo.asia/p/su-dung-colab-giai-quyet-bai-toan-ma-hoa-voi-google-drive-cho-tai-khoan-ca-nhan-yZjJYxbO4OE: mã hóa cho tài khoản
#
# https://vinbigdata.com/cong-nghe-giong-noi/xu-ly-ngon-ngu-tu-nhien-bai-toan-cong-cu-ban-nen-biet.html

# %%
def remove_punctuation(text):
    return "".join([i for i in text if i not in string.punctuation])
def remove_emoji(text):
    emoji_pattern = re.compile("["
                              u"\U0001F600-\U0001F64F"  # emoticons
                              u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                              u"\U0001F680-\U0001F6FF"  # transport & map symbols
                              u"\U0001F700-\U0001F77F"  # alchemical symbols
                              u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                              u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                              u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                              u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                              u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                              u"\U00002702-\U000027B0"  # Dingbats
                              u"\U000024C2-\U0001F251"
                              "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)
def preprocess(text):
    text = remove_punctuation(text)
    text = remove_emoji(text)
    text = text.lower()
    return text
# Out:
# time: 1.19 ms (started: 2023-12-23 04:53:07 +00:00)

# %%
df['pre_context'] = df['context'].apply(preprocess)
df.head(5)
# Out:
#                  reviewer         date  stars  likes  \
# 0        Thanh Nam Nguyễn  6 years ago    4.0    NaN
# 1  Vincent magnus Kenneth  2 years ago    5.0    NaN
# 2        Binh Phuong Tang   a year ago    5.0    NaN
# 3          Trà Lê Thị Thu  3 years ago    5.0    NaN
# 4               Long Trần  4 years ago    5.0    NaN
#
#                                              context location sentiment  \
# 0  One of the best universities in Vietnam\n I m ...     uehA  positive
# 1  Trường sạch đẹp, giảng viên dễ thương,chương t...     uehA  positive
# 2  Cơ sở vật chất hiện đại, thật tuyệt vời. 1 trư...     uehB  positive
# 3  Ngôi trường có đội ngũ giáo viên giỏi, nhiệt t...     uehA  positive
# 4  Hay tự ý đổi lịch học của học sinh :)\n nhưng ...     uehI  positive
#
#                                          pre_context
# 0  one of the best universities in vietnam\n i m ...
# 1  trường sạch đẹp giảng viên dễ thươngchương trì...
# 2  cơ sở vật chất hiện đại thật tuyệt vời 1 trườn...
# 3  ngôi trường có đội ngũ giáo viên giỏi nhiệt tì...
# 4  hay tự ý đổi lịch học của học sinh \n nhưng nh...
# time: 44.2 ms (started: 2023-12-23 04:53:10 +00:00)

# %%
#Copy và sao lưu dữ liệu
df1 = df.copy()
df1.to_excel('df1.xlsx', index=False)
# Out:
# time: 227 ms (started: 2023-12-23 04:53:12 +00:00)

# %%
# Tạo cột để phân biệt 2 ngôn ngữ Anh-Việt
def detect_language(text):
    return langid.classify(text)[0]
df['language'] = df['pre_context'].apply(detect_language)
# Out:
# time: 4.48 s (started: 2023-12-23 04:53:13 +00:00)

# %%
# Tạo DF mới với từng ngôn ngữ
vn_df = df[df['language'] != 'en'].copy()
eng_df = df[df['language'] == 'en'].copy()
# Out:
# time: 5.51 ms (started: 2023-12-23 04:53:18 +00:00)

# %%
vn_df.head(5)
# Out:
#                  reviewer         date  stars  likes  \
# 1  Vincent magnus Kenneth  2 years ago    5.0    NaN
# 2        Binh Phuong Tang   a year ago    5.0    NaN
# 3          Trà Lê Thị Thu  3 years ago    5.0    NaN
# 4               Long Trần  4 years ago    5.0    NaN
# 5            hakun nguyen  7 years ago    5.0    NaN
#
#                                              context location sentiment  \
# 1  Trường sạch đẹp, giảng viên dễ thương,chương t...     uehA  positive
# 2  Cơ sở vật chất hiện đại, thật tuyệt vời. 1 trư...     uehB  positive
# 3  Ngôi trường có đội ngũ giáo viên giỏi, nhiệt t...     uehA  positive
# 4  Hay tự ý đổi lịch học của học sinh :)\n nhưng ...     uehI  positive
# 5  Truong rat dep. Có sân bóng chuyền, cầu lông, ...    uehQ8  positive
#
#                                          pre_context language
# 1  trường sạch đẹp giảng viên dễ thươngchương trì...       vi
# 2  cơ sở vật chất hiện đại thật tuyệt vời 1 trườn...       vi
# 3  ngôi trường có đội ngũ giáo viên giỏi nhiệt tì...       vi
# 4  hay tự ý đổi lịch học của học sinh \n nhưng nh...       vi
# 5  truong rat dep có sân bóng chuyền cầu lông bón...       vi
# time: 23.5 ms (started: 2023-12-23 04:53:18 +00:00)

# %% [markdown]
# ###Số và stopword dựa trên ngôn ngữ

# %%
def convert_n2w_eng(text):
    if text.isdigit():
        return num2words(text)
    else:
        return text
eng_df['pre_context'] = eng_df['pre_context'].apply(convert_n2w_eng)
eng_df.head(5)
# Out:
#                              reviewer          date  stars  likes  \
# 0                    Thanh Nam Nguyễn   6 years ago    4.0    NaN
# 11  Vtrippie Vietnam Free Tour Guides   7 years ago    4.0    NaN
# 16                          Saori Nos   4 years ago    5.0    NaN
# 17                   Ricky San Morgan  5 months ago    5.0    NaN
# 22                   Đỗ Thị Hoàng Yến   2 years ago    5.0    NaN
#
#                                               context location sentiment  \
# 0   One of the best universities in Vietnam\n I m ...     uehA  positive
# 11  Nice school with a good environment of club/gr...     uehA  positive
# 16  Vietnammese student is so cute and the food ne...     uehA  positive
# 17  Well maintained, clean and neat Campus, Great ...     uehA  positive
# 22  This was a fantastic experience though the lib...  uehLibB  positive
#
#                                           pre_context language
# 0   one of the best universities in vietnam\n i m ...       en
# 11  nice school with a good environment of clubgro...       en
# 16  vietnammese student is so cute and the food ne...       en
# 17  well maintained clean and neat campus great pl...       en
# 22  this was a fantastic experience though the lib...       en
# time: 27.9 ms (started: 2023-12-23 04:53:18 +00:00)

# %%
def convert_n2w_vn(text):
    if text.isdigit():
        return n2w(text)
    else:
        return text
vn_df['pre_context'] = vn_df['pre_context'].apply(convert_n2w_vn)
vn_df.head(5)
# Out:
#                  reviewer         date  stars  likes  \
# 1  Vincent magnus Kenneth  2 years ago    5.0    NaN
# 2        Binh Phuong Tang   a year ago    5.0    NaN
# 3          Trà Lê Thị Thu  3 years ago    5.0    NaN
# 4               Long Trần  4 years ago    5.0    NaN
# 5            hakun nguyen  7 years ago    5.0    NaN
#
#                                              context location sentiment  \
# 1  Trường sạch đẹp, giảng viên dễ thương,chương t...     uehA  positive
# 2  Cơ sở vật chất hiện đại, thật tuyệt vời. 1 trư...     uehB  positive
# 3  Ngôi trường có đội ngũ giáo viên giỏi, nhiệt t...     uehA  positive
# 4  Hay tự ý đổi lịch học của học sinh :)\n nhưng ...     uehI  positive
# 5  Truong rat dep. Có sân bóng chuyền, cầu lông, ...    uehQ8  positive
#
#                                          pre_context language
# 1  trường sạch đẹp giảng viên dễ thươngchương trì...       vi
# 2  cơ sở vật chất hiện đại thật tuyệt vời 1 trườn...       vi
# 3  ngôi trường có đội ngũ giáo viên giỏi nhiệt tì...       vi
# 4  hay tự ý đổi lịch học của học sinh \n nhưng nh...       vi
# 5  truong rat dep có sân bóng chuyền cầu lông bón...       vi
# time: 14.7 ms (started: 2023-12-23 04:53:19 +00:00)

# %%
file_path = ('/content/vietnamese-stopwords.txt')
with open(file_path, 'r', encoding='utf-8') as file:
    vn_stopwords = file.readline()
# Out:
# time: 1.91 ms (started: 2023-12-23 04:53:20 +00:00)

# %%
# Xử lý stopwords cho tiếng Anh
eng_stopwords = nltk.corpus.stopwords.words('english')
eng_df['pre_context'] = eng_df['pre_context'].apply(lambda x: ' '
                        .join([word for word in x.split() if word.lower() not in eng_stopwords]))
# Xử lý stopwords cho tiếng Việt
vn_df['pre_context'] = vn_df['pre_context'].apply(lambda x: ' '
                      .join([word for word in x.split() if word.lower() not in vn_stopwords]))
# Out:
# time: 18 ms (started: 2023-12-23 04:53:21 +00:00)

# %%
eng_df.head()
# Out:
#                              reviewer          date  stars  likes  \
# 0                    Thanh Nam Nguyễn   6 years ago    4.0    NaN
# 11  Vtrippie Vietnam Free Tour Guides   7 years ago    4.0    NaN
# 16                          Saori Nos   4 years ago    5.0    NaN
# 17                   Ricky San Morgan  5 months ago    5.0    NaN
# 22                   Đỗ Thị Hoàng Yến   2 years ago    5.0    NaN
#
#                                               context location sentiment  \
# 0   One of the best universities in Vietnam\n I m ...     uehA  positive
# 11  Nice school with a good environment of club/gr...     uehA  positive
# 16  Vietnammese student is so cute and the food ne...     uehA  positive
# 17  Well maintained, clean and neat Campus, Great ...     uehA  positive
# 22  This was a fantastic experience though the lib...  uehLibB  positive
#
#                                           pre_context language
# 0      one best universities vietnam great time place       en
# 11  nice school good environment clubgroup activities       en
# 16   vietnammese student cute food nearby quite cheap       en
# 17  well maintained clean neat campus great place ...       en
# 22         fantastic experience though library repair       en
# time: 12.3 ms (started: 2023-12-23 04:53:23 +00:00)

# %%
vn_df.head()
# Out:
#                  reviewer         date  stars  likes  \
# 1  Vincent magnus Kenneth  2 years ago    5.0    NaN
# 2        Binh Phuong Tang   a year ago    5.0    NaN
# 3          Trà Lê Thị Thu  3 years ago    5.0    NaN
# 4               Long Trần  4 years ago    5.0    NaN
# 5            hakun nguyen  7 years ago    5.0    NaN
#
#                                              context location sentiment  \
# 1  Trường sạch đẹp, giảng viên dễ thương,chương t...     uehA  positive
# 2  Cơ sở vật chất hiện đại, thật tuyệt vời. 1 trư...     uehB  positive
# 3  Ngôi trường có đội ngũ giáo viên giỏi, nhiệt t...     uehA  positive
# 4  Hay tự ý đổi lịch học của học sinh :)\n nhưng ...     uehI  positive
# 5  Truong rat dep. Có sân bóng chuyền, cầu lông, ...    uehQ8  positive
#
#                                          pre_context language
# 1  trường sạch đẹp giảng viên dễ thươngchương trì...       vi
# 2  cơ sở vật chất hiện đại thật tuyệt vời 1 trườn...       vi
# 3  ngôi trường có đội ngũ giáo viên giỏi nhiệt tì...       vi
# 4  hay tự ý đổi lịch học của học sinh nhưng nhìn ...       vi
# 5  truong rat dep có sân bóng chuyền cầu lông bón...       vi
# time: 14.3 ms (started: 2023-12-23 04:53:24 +00:00)

# %% [markdown]
# ###Tokenize

# %%
df = pd.concat([vn_df, eng_df], axis=0, ignore_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 841 entries, 0 to 840
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   reviewer     841 non-null    object
#  1   date         841 non-null    object
#  2   stars        831 non-null    float64
#  3   likes        262 non-null    float64
#  4   context      841 non-null    object
#  5   location     841 non-null    object
#  6   sentiment    841 non-null    object
#  7   pre_context  841 non-null    object
#  8   language     841 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 59.3+ KB
# time: 12.3 ms (started: 2023-12-23 04:53:25 +00:00)

# %% [markdown]
# ####Word Tokenize

# %%
special_char = [':',')','(','.',',',';','...']
for char in  special_char:
  df['pre_context'] = df['pre_context'].apply(lambda x: x.replace(char, ''))

df['pre_context'].head()
# Out:
# 0    trường sạch đẹp giảng viên dễ thươngchương trì...
# 1    cơ sở vật chất hiện đại thật tuyệt vời 1 trườn...
# 2    ngôi trường có đội ngũ giáo viên giỏi nhiệt tì...
# 3    hay tự ý đổi lịch học của học sinh nhưng nhìn ...
# 4    truong rat dep có sân bóng chuyền cầu lông bón...
# Name: pre_context, dtype: object
# time: 13.9 ms (started: 2023-12-23 04:53:27 +00:00)

# %%
def wt(sentence, lang):
    if lang == 'en':
        tokens = word_tokenize(sentence)
    else:
        tokens = ViTokenizer.tokenize(sentence).split()
    return tokens
# Out:
# time: 868 µs (started: 2023-12-23 04:53:28 +00:00)

# %%
df['tokens'] = df.apply(lambda row: wt(row['pre_context'], row['language']), axis=1)
print(df['tokens'])
# Out:
# 0      [trường, sạch, đẹp, giảng_viên, dễ, thươngchươ...
# 1      [cơ_sở, vật_chất, hiện_đại, thật, tuyệt_vời, 1...
# 2      [ngôi, trường, có, đội_ngũ, giáo_viên, giỏi, n...
# 3      [hay, tự_ý, đổi, lịch, học, của, học_sinh, như...
# 4      [truong, rat, dep, có, sân, bóng_chuyền, cầu_l...
#                              ...
# 836    [best, school, town, economics, huge, placemen...
# 837    [excellent, university, world, class, educatio...
# 838    [new, campus, really, good, big, parking, spac...
# 839    [excellent, environment, good, campus, fully, ...
# 840    [one, best, universities, vietnam, great, time...
# Name: tokens, Length: 841, dtype: object
# time: 924 ms (started: 2023-12-23 04:53:29 +00:00)

# %%
english_tokens_list = [token for sublist in df[df['language'] == 'en']['tokens'].tolist() for token in sublist]
vietnamese_tokens_list = [token for sublist in df[df['language'] != 'en']['tokens'].tolist() for token in sublist]

# Display the lists of English and Vietnamese tokens
print("English Tokens:", english_tokens_list)
print("Vietnamese Tokens:", vietnamese_tokens_list)
# Out:
# English Tokens: ['one', 'best', 'universities', 'vietnam', 'great', 'time', 'place', 'nice', 'school', 'good', 'environment', 'clubgroup', 'activities', 'vietnammese', 'student', 'cute', 'food', 'nearby', 'quite', 'cheap', 'well', 'maintained', 'clean', 'neat', 'campus', 'great', 'place', 'education', 'fantastic', 'experience', 'though', 'library', 'repair', 'best', 'students', 'learners', 'interested', 'economics', 'largest', 'uni', 'south', 'vietnam', 'many', 'famous', 'lecturers', 'beautifull', 'school', 'food', 'served', 'school', 'amazing', 'infrastructure', 'high', 'quality', 'education', 'one', 'best', 'institution', 'vietnam', 'good', 'atmosphere', 'university', 'good', 'position', 'ho', 'chi minh', 'city', 'specially', 'economic', 'university', 'talent', 'students', 'new', 'capus', 'nice', 'building', 'morden', 'facilities', 'facilitiea', 'great', 'even', 'though', 'spacy', 'great', 'facility', 'good', 'location', 'students', 'best', 'place', 'education', 'good', 'environment', 'enough', 'equipment', 'practice', 'good', 'education', 'enviroment', 'highly', 'recommended', 'good', 'university', 'studied', 'probably', 'best', 'business', 'school', 'town', 'best', 'university', 'economics', 'vietnam', 'ueh', 'best', 'university', 'vietnam', 'famous', 'university', 'ho', 'chi minh', 'city', 'profectional', 'school', 'lets', 'join', 'us', 'best', 'university', 'business', 'id', 'lived', '4', 'years', 'great', 'best', 'university', 'place', 'study', 'top', 'university', 'hochiminh', 'city', 'modern', 'useful', 'beautiful', 'nice', 'school', 'economic', 'student', 'good', 'university', 'well', 'teaching', 'best', 'university', 'vietnam', 'gorgeous', 'pretty', 'building', 'good', 'university', 'super', 'university', 'must', 'join', 'im', 'happy', 'im', 'good', 'studys', 'life', 'big', 'classroom', 'without', 'ac', 'nice', 'university', 'study', 'good', 'vibes', 'event', 'best', 'place', 'studying', 'p', 'uiversery', 'good', 'love', 'uni', 'campus', 'teachers', 'good', 'top', 'university', 'hcmc', 'good', 'view', 'street', 'xu ly', 'cong', 'viec', 'nhanh', 'best', 'place', 'study', 'great', 'university', 'good', 'place', 'fee', 'increased', 'best', 'uni', 'hcmc', 'good', 'university', 'good', 'university', 'lovely', 'place', 'nice', 'campus', 'wide', 'place', 'nice', 'place', 'nice', 'place', 'nice', 'place', 'cool', 'space', 'love', 'pro', '3', 'ueh', 'great', 'good', 'good', 'great', 'ok', 'lam', 'great', 'tuyet', 'good', '5', 'sao', 'good', 'no1', 'good', 'good', 'ok', 'good', 'good', 'duoc', 'good', 'good', 'fine', 'good', 'nice', 'good', 'ngon', 'good', 'good', 'good', 'good', 'okay', 'good', 'nice', 'good', 'good', 'nice', 'good', 'good', 'like', 'good', 'good', 'nice', 'good', 'good', 'good', 'good', 'gud', 'vui', 'ok', 'ok', 'ok', 'ok', 'ow', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'studied', 'perspective', 'everything', 'good', 'got', 'good', 'job', 'graduation', 'professors', 'friendly', 'helpful', 'school', 'atmosphere', 'good', 'compromised', 'nature', 'modern', 'bad', 'ok', 'ok', 'dc', 'no1', 'love', 'ueh', 'thich', 'toan', 'ly', 'thuyet', 'xuong', 'moi', 'truong', 'hic', 'rat', 'tot', 'good', 'good', 'opportunity', 'gain', 'knowleage', 'experience', 'economy', 'well', 'persional', 'skill', 'high', 'education', 'standard', 'also', 'lot', 'event', 'competion', 'meeting', 'camping', 'etc', 'join', 'study', 'prestigious', 'university', 'pretty', 'good', 'education', 'quality', 'compared', 'others', 'vietnam', 'problem', 'seriously', 'lacks', 'parking', 'space', 'ueh', 'moee', 'beautiful', 'cafe', 'book', 'stor', 'stay', 'nice', 'place', 'enjoy', 'time', 'stay', 'feel', 'proud', 'university', 'meeting', 'hall', 'repaired', 'aircon', 'started', 'working', 'well', 'therere', 'many', 'performances', 'student', 'educations', 'entertaiment', 'fresh', 'air', 'quiet', 'great', 'place', 'study', 'love', 'school', 'much', 'lots', 'talent ...
# Vietnamese Tokens: ['trường', 'sạch', 'đẹp', 'giảng_viên', 'dễ', 'thươngchương', 'trình', 'học', 'tốt', 'from', 'ueher', '43', 'cơ_sở', 'vật_chất', 'hiện_đại', 'thật', 'tuyệt_vời', '1', 'trường', 'đại_học', 'lớn', 'của', 'miền', 'nam', 'ngôi', 'trường', 'có', 'đội_ngũ', 'giáo_viên', 'giỏi', 'nhiệt_tình', 'và', 'vô_cùng', 'dễ_thương', '…', 'hay', 'tự_ý', 'đổi', 'lịch', 'học', 'của', 'học_sinh', 'nhưng', 'nhìn_chung', 'rất', 'là', 'tốt', 'gud', 'gud', 'truong', 'rat', 'dep', 'có', 'sân', 'bóng_chuyền', 'cầu_lông', 'bóng_đá', 'nữa', 'mình', 'rất', 'yêu', 'ý', 'cơ_sở', 'vật_chất', 'hiện_đại', 'không_gian', 'xanh', 'và', 'thoáng', 'mọi', 'người', 'thân_thiện', 'được', 'mỗi', 'cái', 'cơ_sở', 'này', 'là', 'đây', 'đủ', 'tiện_nghi', 'và', 'giống', 'cái', 'trường_học', 'nhất', 'trường', 'rộng_rãi', 'thoáng', 'mát', 'bãi', 'đậu', 'xe', 'rộng_rãi', 'môi_trường', 'thân_thiện', 'nơi', 'đào_tạo', 'các', 'chuyên_ngành', 'kinh_tế', 'uy', 'tính', 'của', 'khu_vực', 'tphồ', 'chí', 'minh', 'cơ_sở', 'vật_chất', 'bên', 'campus', 'này', 'là', 'xịn', 'nhứt', 'lunnn', 'đã', 'dữ', 'lắm', 'bà_con', 'uiiii', 'nơi', 'đào_tạo', 'nhiều', 'nhà', 'kinh_tế', 'doanh_nghiệp', 'trẻ', 'có', 'uy_tín', 'trên', 'cả', 'nước', 'là', 'trường', 'đại_học', 'đào_tạo', 'cử_nhân', 'kinh_tế', 'tốt', 'nhất', 'hiện_nay', 'ở', 'việt_nam', 'ai', 'muốn', 'tài_chính', 'ổn_định', 'trong', 'tương_lai', 'nên', 'chọn', 'trường', 'đại_học', 'này', 'nơi', 'đào_tạo', 'những', 'cử_nhân', 'nhà', 'quản_lý', 'tương_lai', 'chất_lượng', 'hàng_đầu', 'là', 'một', 'trong', 'các', 'đại_học', 'uy_tín', 'ở', 'tphcm', 'cũng', 'như', 'cả', 'nước', 'cơ_sở', 'vật_chất', 'hiện_đại', 'sạch_sẽ', 'vô_cùng', 'học_sinh', 'thân_thiện', '1000đ', 'ký_túc_xá', 'nằm', 'vị_trí', 'trung_tâm', 'thoáng', 'mát', 'tiện_nghi', 'và', 'an_ninh', 'chất_lượng', 'giảng_dạy', 'cao', 'nhiều', 'phong_trào', 'hoạt_động', 'cho', 'sinh_viên', 'ngôi', 'trường', 'rất', 'đẹp', 'và', 'tui', 'rất', 'thích', 'nét', 'văn_hóa', 'nơi', 'này', 'một', 'nơi', 'đào_tạo', 'tuyệt_vời', 'chuyên_ngành', 'kinh_tế', 'luật', 'quản_lý', 'cơ_sở', 'vật_chất', 'trường', 'quá', 'xịn', 'xò', 'luôn', 'nè', 'tự_hào', 'là', 'một', 'sv', 'ueh', 'trường', 'mới', 'khang_trang', 'yên_tĩnh', 'nằm', 'trên', 'đường', 'nguyễn', 'văn', 'linh', 'trường', 'hàng_đầu', 'trong', 'hoạt_động', 'đào_tạo', 'lình', 'vực', 'kinh_doanh', 'học', 'học', 'nữa', 'học', 'mãi', 'học', 'đến', 'khi', 'nào', 'cạn_kiệt', 'thì_thôi', 'thư_viện', 'cực_kì', 'xịn', 'xò', 'với', 'cơ_sở', 'vật_chất', 'hiện_đại', 'nè', '…', 'giá', 'quá', 'rẻ', 'chất_lượng', 'tương_đối', 'ổn', 'một', 'thời', 'không_thể', 'quên', 'cơ_sở', 'khang_trang', 'nhiều', 'hoạt_động', 'ngoại', 'khóa', 'cho', 'sinh_viên', 'trường', 'xịn', 'chất_lượng', 'giảng_dạy', 'tốt', 'giảng_viên', 'cute', 'rộng_rãi', 'thoáng', 'mát', 'đội_ngũ', 'nhân_viên', 'chuyên_nghiệp', 'mình', 'luôn', 'tự_hào', 'được', 'tốt_nghiệp', 'từ', 'đại_học', 'kinh_tế', 'tphcm', 'trường', 'thì', 'khỏi', 'phải', 'chê', 'rùi', 'ạ', 'csvc', 'top', 'đầu', 'nha', 'yêu', 'ueh', 'trường', 'khang_trang', 'rộng_rãi', 'khá', 'ghen_tị', 'với', 'sinh_viên', 'ueh', 'thầy', 'mới', 'bạn', 'mới', 'trường', 'mới', 'kiến_thức', 'mới', 'tuyệt_vời', 'khá', 'là', 'xịn', 'xò', 'bãi', 'xe', 'dưới', 'hầm', 'khá', 'rộng', 'bảo_vệ', 'thân_thiện', 'quy_mô', 'lớn', 'giáo', 'duc', 'tốt', 'hệ_thống', 'thông_tin', 'tốt', 'rất', 'thích', 'trường', 'này', 'nhưng', 'đáng', 'tiếc', 'thi', 'không', 'đậu', 'huhu', 'cơ_sở', 'vật_chất', 'hiện_đại', 'chương_trình', 'đào_tạo', 'tiên_tiến', 'sinh_viên', 'trường', 'ra', 'đường', 'đứng', 'làm', 'tắc_nghẽn', 'giao_thông', 'quá', 'khang_trang', 'quá', 'hiện_đại', 'thân_thiện', 'với', 'môi_trường', 'chất_lượng', 'đào_tạo', 'tốt', 'tự_hào', 'là', 'sinh_viên', 'của', 'trường', 'trụ_sở', 'chính', 'nên', 'có', 'hội_trường', 'rất', 'rộng', 'cho', 'sinh_viên', 'top', '1000', 'trường', 'đào_tạo', 'kinh_doanh', 'tốt', 'nhất', 'thế_giới', 'trường', 'đại_học', 'hàng_đầu', 'về', 'kinh_tế', 'thương_mại', 'ở', 'tphcm', 'oktrường', 'đào_tạo', 'những', 'doanh_nhân', 'thành ...
# time: 32.4 ms (started: 2023-12-23 04:53:31 +00:00)

# %%
# Count the frequency of tokens in each list
english_token_counts = Counter(english_tokens_list)
vietnamese_token_counts = Counter(vietnamese_tokens_list)

# Get the top 10 most frequent tokens
top_10_english_tokens = dict(english_token_counts.most_common(10))
top_10_vietnamese_tokens = dict(vietnamese_token_counts.most_common(10))

# Plotting
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

# English tokens plot
axes[0].bar(top_10_english_tokens.keys(), top_10_english_tokens.values(), color='skyblue')
axes[0].set_title('Top 10 English Tokens')
axes[0].set_xlabel('Tokens')
axes[0].set_ylabel('Frequency')

# Vietnamese tokens plot
axes[1].bar(top_10_vietnamese_tokens.keys(), top_10_vietnamese_tokens.values(), color='salmon')
axes[1].set_title('Top 10 Vietnamese Tokens')
axes[1].set_xlabel('Tokens')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# time: 1.11 s (started: 2023-12-23 04:53:32 +00:00)

# %% [markdown]
# ####Sentence Tokenize

# %%
sen_token = df.copy()
# Out:
# time: 1.07 ms (started: 2023-12-23 04:53:39 +00:00)

# %%
special_char_sen = [')','(',',','\n']
for char in  special_char_sen:
  sen_token['context'] = df['context'].apply(lambda x: x.replace(char, ''))

sen_token['context'].head()
# Out:
# 0    Trường sạch đẹp, giảng viên dễ thương,chương t...
# 1    Cơ sở vật chất hiện đại, thật tuyệt vời. 1 trư...
# 2    Ngôi trường có đội ngũ giáo viên giỏi, nhiệt t...
# 3    Hay tự ý đổi lịch học của học sinh :) nhưng nh...
# 4    Truong rat dep. Có sân bóng chuyền, cầu lông, ...
# Name: context, dtype: object
# time: 20.7 ms (started: 2023-12-23 04:53:48 +00:00)

# %%
def st(sentence, lang):
    if lang == 'en':
        tokens = eng_sent(sentence)
    else:
        tokens = vie_sent(sentence)
    return tokens
# Out:
# time: 861 µs (started: 2023-12-23 04:53:50 +00:00)

# %%
sen_token['sent_tokens'] = sen_token.apply(lambda row: st(row['context'],
                                                          row['language']), axis=1)

sen_token['sent_tokens'].head()
# Out:
# 0    [Trường sạch đẹp, giảng viên dễ thương,chương ...
# 1    [Cơ sở vật chất hiện đại, thật tuyệt vời., 1 t...
# 2    [Ngôi trường có đội ngũ giáo viên giỏi, nhiệt ...
# 3    [Hay tự ý đổi lịch học của học sinh :) nhưng n...
# 4    [Truong rat dep., Có sân bóng chuyền, cầu lông...
# Name: sent_tokens, dtype: object
# time: 114 ms (started: 2023-12-23 04:53:51 +00:00)

# %%
# Assuming 'tokens' column is already created in your DataFrame
english_sen_tokens_list = [token for sublist in sen_token[df['language'] == 'en']['sent_tokens'].tolist() for token in sublist]
vietnamese_sen_tokens_list = [token for sublist in sen_token[df['language'] != 'en']['sent_tokens'].tolist() for token in sublist]

# Display the lists of English and Vietnamese tokens
print("English Sentence Tokens:", english_sen_tokens_list)
print("Vietnamese Sentence Tokens:", vietnamese_sen_tokens_list)
# Out:
# English Sentence Tokens: ['One of the best universities in Vietnam I m having great time at this place', 'Nice school with a good environment of club/group and other activities', 'Vietnammese student is so cute and the food nearby are quite cheap ^^', 'Well maintained, clean and neat Campus, Great place for Education..!', 'This was a fantastic experience though the library is under repair', 'Best for the students or learners who are interested in economics', 'The Largest Uni.', 'Of South Vietnam with many famous lecturers.', 'So beautifull this school is!!', 'Food is not served at school.', 'Amazing infrastructure and very high quality in education', 'One of the best institution in Vietnam.', 'Good atmosphere', 'The University with good position in Ho Chi Minh City.', 'Specially Economic University for talent students.', 'New capus, nice building with morden facilities.', 'Facilitiea are great even though not too spacy', 'Great facility and good location for students.', 'Best place for education and good environment', 'It have enough equipment that we can practice', 'Good education enviroment!', 'Highly recommended', 'Such a very good university I have studied!', 'Probably the best business school in town', 'Best University of Economics in Vietnam', 'UEH is the best University in Vietnam.', 'Famous university in Ho Chi Minh City', 'Profectional school!', "Let's join us.", 'The best university for business...', "where i'd lived for 4 years.", 'Great', 'Best university and place to study', 'Top University in HoChiMinh city!', 'Very modern, useful and beautiful', 'Nice school for economic student', 'Good university, well teaching.', 'the best university in vietnam!', 'Gorgeous and pretty building..', 'Such a very good university', 'Super university must join', "I'm so happy when I'm here", "good for your study's life", 'Big classroom without AC!', 'Nice University to study', 'Good vibes in any event', 'Best place for studying', ':p uiversery very good', 'Love my uni - Campus A', 'teachers are very good', 'Top university in HCMC', 'Good view from street', 'Xu ly cong viec nhanh', 'Best place to study', 'Great university !', 'Very good place :)', 'Fee has increased', 'Best uni in HCMC', 'Good university', 'good university', 'Lovely place', 'Nice campus', 'Wide place.', 'Nice place', 'Nice place', 'Nice place', 'Cool space', 'i love it', 'Here pro', 'I <3 UEH', 'great!!', '!', 'good....', 'good ;)', 'Great!', 'ok lam', 'great', 'Tuyet', 'Good!', '5 sao', 'Good', 'No.1', 'Good', 'Good', 'ok!', '!', 'Good', 'Good', 'duoc', 'Good', 'Good', 'Fine', 'good', 'Nice', 'Good', 'Ngon', 'Good', 'Good', 'good', 'good', 'Okay', 'Good', 'Nice', 'Good', 'good', 'nice', 'Good', 'Good', 'Like', 'good', 'Good', 'Nice', 'Good', 'good', 'Good', 'good', 'Gud', 'Vui', 'Ok', 'ok', 'Ok', 'Ok', 'Ow', 'ok', 'ok', 'Ok', 'Ok', 'Ok', 'Ok', 'Ok', 'ok', 'OK', 'Ok', 'Ok', 'Ok', 'Ok', 'Ok', 'Ok', 'Ok', 'Ok', 'Ok', 'Ok', 'Ok', 'OK', 'Ok', 'I studied here, from my perspective, everything was good, I got a good job after graduation, professors were friendly and helpful.', 'School atmosphere is good, it is compromised to nature and modern!', 'Not bad.', 'Ok', 'Ok', 'Dc', 'No.1', 'I love UEH', 'Thich', 'Toan ly thuyet xuong', 'Moi truong hic rat tot', 'Good', 'You can have good opportunity to gain knowleage and experience about economy as well as persional skill by its high education standard.', 'They also have a lot of event, competion, meeting, camping, etc.... that you join', 'This is where I study.', 'A prestigious university with pretty good education quality compared to others in Vietnam.', 'The only problem is that it seriously lacks parking space.', 'UEH more and moee beautiful.', 'There and cafe book stor here to stay.', 'Nice place for enjoy.', 'If you had the time to stay here you can feel proud of the University.', 'The meeting hall had repaired, the aircon started working well.', "There're many performances for student about educations and entertaiment.", ' ...
# Vietnamese Sentence Tokens: ['Trường sạch đẹp, giảng viên dễ thương,chương trình học tốt - from Ueher 43', 'Cơ sở vật chất hiện đại, thật tuyệt vời.', '1 trường Đại Học lớn của miền Nam', 'Ngôi trường có đội ngũ giáo viên giỏi, nhiệt tình và vô cùng dễ thương💞 …', 'Hay tự ý đổi lịch học của học sinh :) nhưng nhìn chung rất là tốt gud gud', 'Truong rat dep.', 'Có sân bóng chuyền, cầu lông, bóng đá nữa.', 'Mình rất yêu ý', 'Cơ sở vật chất hiện đại, không gian xanh và thoáng, mọi người thân thiện', 'Được mỗi cái cơ sở này là đây đủ tiện nghi, và giống cái trường học nhất', 'Trường rộng rãi, thoáng mát.', 'Bãi đậu xe rộng rãi, môi trường thân thiện', 'Nơi đào tạo các chuyên ngành kinh tế uy tính của khu vực Tp.Hồ Chí Minh', 'cơ sở vật chất bên campus này là xịn nhứt lunnn, đã dữ lắm bà con uiiii', 'Nơi đào tạo nhiều nhà kinh tế, doanh nghiệp trẻ có uy tín trên cả nước', 'là trường đại học đào tạo cử nhân kinh tế tốt nhất hiện nay ở việt nam', 'Ai muốn tài chính ổn định trong tương lai nên chọn trường đại học này.', 'Nơi đào tạo những cử nhân - nhà quản lý tương lai chất lượng hàng đầu', 'Là một trong các đại học uy tín ở TP.HCM cũng như cả nước', 'Cơ sở vật chất hiện đại, sạch sẽ vô cùng Học sinh thân thiện 1000đ', 'Ký túc xá nằm vị trí trung tâm, thoáng mát, tiện nghi và an ninh.', 'Chất lượng giảng dạy cao, nhiều phong trào hoạt động cho sinh viên', 'Ngôi trường rất đẹp và tui rất thích nét văn hóa nơi này.', 'Một nơi đào tạo tuyệt vời chuyên ngành kinh tế, luật, quản lý.', 'Cơ sở vật chất trường quá xịn xò luôn nè, tự hào là một SV UEH', 'Trường mới khang trang yên tĩnh nằm trên đường Nguyễn văn Linh', 'Trường hàng đầu trong hoạt động đào tạo lình vực kinh doanh !', 'Học học nữa học mãi... Học đến khi nào cạn kiệt thì thôi :))', 'Thư viện cực kì xịn xò với cơ sở vật chất hiện đại nè 🥰🥰🥰🥰 …', 'Giá quá rẻ, chất lượng tương đối ổn, một thời không thể quên', 'Cơ sở khang trang, nhiều hoạt động ngoại khóa cho sinh viên', 'Trường xịn, chất lượng giảng dạy tốt, giảng viên cute :)))', 'Rộng rãi thoáng mát đội ngũ nhân viên chuyên nghiệp', 'Mình luôn tự hào được tốt nghiệp từ Đại học Kinh tế Tphcm', 'Trường thì khỏi phải chê rùi ạ, csvc top đầu nha, yêu UEH', 'Trường khang trang rộng rãi Khá ghen tị với sinh viên UEH', 'Thầy mới, bạn mới, trường mới, kiến thức mới.', 'Tuyệt vời!', 'Khá là xịn xò Bãi xe dưới hầm khá rộng Bảo vệ thân thiện', 'quy mô lớn , giáo duc tốt , hệ thống thông tin tốt', 'Rất thích trường này nhưng đáng tiếc thi không đậu.', 'huhu', 'Cơ sở vật chất hiện đại, chương trình đào tạo tiên tiến', 'Sinh viên trường ra đường đứng làm tắc nghẽn giao thông', 'Quá khang trang quá hiện đại thân thiện với môi trường', 'Chất lượng đào tạo tốt, tự hào là sinh viên của trường', 'trụ sở chính nên có hội trường rất rộng cho sinh viên', 'Top 1000 trường đào tạo kinh doanh tốt nhất thế giới!', 'Trường đại học hàng đầu về kinh tế thương mại ở tphcm', 'Ok.Trường đào tạo những doanh nhân thành đạt.04.2022', 'Môi trường rất tốt để các bạn sinh viên phát triển!', 'Đẹp, thoáng.', 'Nhưng tiền gửi xe khá mắc, hình như 4k', 'Một ngôi trường mà phải công nhận top đầu Việt Nam', 'Cơ sở này bé, lại hay kẹt xe, nói chung là khó đi.', 'Khu vực trước cửa ktx khá lộn xộn và không an toàn', 'hiện đại.. nhưng hơi nóng... tìm thùng rác hơi khó', 'Cơ sở vật chất hiện đại, nhưng bãi gửi xe hơi đông', 'Trường dạy về kinh tế khá nổi tiếng của thành phố', 'Cơ sở mới duy tu, sửa chữa mới, đẹp hơn, sạch sẽ.', 'Môi trường học thuật cực tốt, giảng viên uyên bác', 'Từng ở đây 4 năm.', 'Quảng đời SV không thể nào quên', 'Cơ sở mới xây trước mặt Nguyễn Tri Phương rất đẹp', 'trường tốt nhưng la trường ko biết có việc làm ko', 'Hiện đai, sạch sẽ, chất lượng giáo dục tuyệt vời.', 'Cơ sở vật chất hiện đại Chất lượng giảng dạy tốt', 'Một thời đã xa.', '25 năm vẫn không thay đổi nhiều.', 'Môi trường học tập sạch sẽ đẹp thoáng....', 'Trường đại học đào tạo kinh tế hàng đầu Việt Nam', 'Trường tôi đã học, chất lượng giảng dạy quá tốt',  ...
# time: 10.3 ms (started: 2023-12-23 04:53:54 +00:00)

# %%
top5_longest_en = sorted(english_sen_tokens_list, key=len, reverse=True)[:5]
top5_longest_vi = sorted(vietnamese_sen_tokens_list, key=len, reverse=True)[:5]

# Display the results
print("Top 5 Longest English Sentence Tokens:")
for sentence in top5_longest_en:
  print(sentence, f'\nLenght: {len(sentence)} \n------------------------')

print("\nTop 5 Longest Vietnamese Sentence Tokens:")
for sentence in top5_longest_vi:
  print(sentence,  f'\nLenght: {len(sentence)} \n------------------------')
# Out:
# Top 5 Longest English Sentence Tokens:
# I found that students did not adequately review material in the beginning of courses to build a solid foundation for later lectures - trust me they make more sense and you retain much more information (increasing your memory and understanding) just by listening to the lecturer having the background information.TL;DR: Work hard to get results.
# Lenght: 344
# ------------------------
# In first year in a science program, I would say I spent 2 nights per week socializing in first year, but otherwise was keeping up with all readings, reviewing lecture notes, doing recommended problems/readings, preparing for labs etc (including all weekends).
# Lenght: 259
# ------------------------
# Most of their office hours go unused for some reason, and then students complain about the difficulty of the material which to me only seems to be the case if they put in less effort than they thought was necessary, and got a less than stellar result.
# Lenght: 251
# ------------------------
# Floor 7 has a photocopy machine (each student can print 500 pages for free in a semester if I remember correctly), and a drinks vending machine that makes quite a loud noise when beverages are dropped (I sat on a bench next to it).
# Lenght: 231
# ------------------------
# The school often invites successful business owners and directors from big corporations to share their insights and experiences with the students, as well as to scout for potential startups and talents.
# Lenght: 202
# ------------------------
#
# Top 5 Longest Vietnamese Sentence Tokens:
# Cùng với quá trình đổi mới và phát triển của đất nước, sau 45 năm hình thành và phát triển, với đội ngũ giáo sư, giảng viên được đào tạo từ các trường danh tiếng trong và ngoài nước, có chuyên môn sâu, uy tín khoa học cao, UEH đã có nhiều đóng góp thiết thực trong công tác nghiên cứu khoa học thông qua nhiều công trình công bố quốc tế, các đề tài nghiên cứu trọng điểm cấp nhà nước, cấp địa phương, các nghiên cứu ứng dụng vào thực tiễn; Mạng lưới hợp tác quốc tế rộng khắp với hơn 125 đối tác giáo dục quốc tế đến từ các quốc gia lớn trên thế giới như: Hoa Kỳ, Pháp, Australia, New Zealand, Hà Lan, Hàn Quốc, Singapore,… Đặc biệt, nhà trường đã đào tạo hàng trăm ngàn cán bộ, nhà kinh tế, nhà quản lý có trình độ đại học và sau đại học cho cả nước; đảm bảo chất lượng, uy tín đã và đang đảm nhận các vị trí quan trọng tại các cơ quan quản lý nhà nước; các doanh nghiệp trong và ngoài nước; lãnh đạo, giảng viên các trường đại học, cao đẳng,... Từ những thành tích xuất sắc trong quá trình xây dựng và phát triển, tập thể cán bộ, giảng viên và nhân viên Trường Đại học Kinh tế TP. Hồ Chí Minh đã được Chủ tịch nước trao tặng 02 Huân chương Lao động hạng Ba (1986), 02 Huân chương Lao động hạng Nhì (1991), 02 Huân chương Lao động hạng Nhất (1996), Huân chương Độc lập hạng Ba (2001), Huân chương Độc lập hạng Nhì (2010) và danh hiệu Anh hùng Lao động (2006).
# Lenght: 1360
# ------------------------
# ( K46 chia sẻ ) - Bảng điểm vẫn in Chữ Phân Hiệu khi đưa cho nhà tuyển dụng xem ( K46 chia sẻ) - Giấy tạm hoãn quân sự vẫn in chứ Phân Hiệu Vĩnh Long - Giấy xác nhận sinh viên vẫn In Phân Hiệu Vĩnh Long - Môi trường khá thụ động, khá suy tư, yên bình - Trong phòng đào tạo có một bà cô ( dáng người khá to con ) có thái độ hơi bị thất học và thổ tả - Tới mùa nước nổi trường ngập nước tới đầu gối....  Ưu điểm: - Cơ sở vật chất đáp ứng khá đầy đủ nhu cầu học tập sinh viên - Hỗ trợ và giải đáp thắc mắc cho sinh viên Khá nhanh - Giảng viên đa phần dễ thương....  Nếu bạn thích cuộc sống nhàn nhạ, suy nghĩ, trầm, sâu lắng.... Có thể chọn nơi đây gửi gấm.
# Lenght: 654
# ------------------------
# Đặc biệt, UEH vinh dự nằm trong Top 1000 Trường đào tạo kinh doanh tốt nhất thế giới (Theo BXH Eduniversal) từ năm 2014; Top 601+ Trường Đại học tốt nhất Châu Á (Theo BXH QS châu Á) (2021); Top 100 Trường đào tạo Thạc sĩ tốt nhất thế giới (Theo BXH Eduniversal) (2018); Top 25 đại học tốt nhất thế giới đóng góp cho sự phát triển nghề nghiệp suốt đời theo U-Multirank (2016, 2017, 2018, 2020); Top 9 trường đại học tại Việt Nam, đứng thứ nhất trong số các trường đại học trong lĩnh vực kinh tế, kinh doanh tại Việt Nam về năng lực số hóa và mức độ lan tỏa, ảnh hưởng về tài nguyên học thuật (Theo BXH Webometrics) (2021).
# Lenght: 622
# ------------------------
# *Của cả KTX (dùng chung): • 1 phòng tự học, đầy đủ quạt, đèn và ổ cắm, kệ sách tham khảo; • Mỗi lầu đều có 1 máy nước uống nóng lạnh miễn phí; • 1 phòng giặt sấy; • KTX ko có căn tin và ko cho tự nấu ăn nên ăn ngoài 100%; • 2 thang máy; • 2 máy quét sv ra vào bằng mã QR • 1 máy in/photocopy miễn phí;  - Về chi phí: • Tiền phòng: Phòng quạt 300k/sv/tháng, điện nước ~10-50k/sv/tháng • Để xe máy 10k/ngày nếu chưa có vé tháng, 5k/ngày nếu có vé tháng, thu theo tháng • Ăn uống: ăn ngoài hoàn toàn, 20-30k/bữa ăn, ăn ngon hơn thì nhiều $ hơn :>> • 15k/lượt giặt hoặc sấy  An ninh ở ktx tất nhiên tốt hơn hẳn so với ở trọ.
# Lenght: 620
# ------------------------
# Ngày 27.10.1976, là cột mốc quan trọng đánh dấu một bước chuyển mình mới cho giáo dục của Việt Nam - Một trường đại học khối ngành kinh tế, quản lý đầu tiên ra đời (trực thuộc Bộ Đại học và Trung học chuyên nghiệp) với nhiệm vụ đào tạo cán bộ nghiên cứu, quản lý, giảng dạy cho khối ngành kinh tế đáp ứng nhu cầu cấp bách của Miền Nam sau giải phóng, thống nhất đất nước, đặt nền móng ban đầu trở thành một trong các trường đại học hàng đầu cả nước trong đào tạo và nghiên cứu về khoa học kinh tế, quản trị kinh doanh, và luật đó là trường Đại học Kinh tế TP. Hồ Chí Minh.
# Lenght: 572
# ------------------------
# time: 2.17 ms (started: 2023-12-23 04:53:56 +00:00)

# %% [markdown]
# ## POS_tagging

# %% [markdown]
# Chuyển đổi cái tags của hai thư viện cho đồng bộ với nhau
# - tham khảo POS của pyvi: [github.com](https://github.com/trungtv/pyvi/blob/master/README.rst)
# - tham khảo POS của spacy: [melaniewalsh.github.io](https://melaniewalsh.github.io/Intro-Cultural-Analytics/05-Text-Analysis/13-POS-Keywords.html)

# %%
#Số quan sát 2 ngôn ngữ
vie_df = df[df['language'] == 'vi']
eng_df = df[df['language'] == 'en']
print(f'Số quan sát tiếng Việt: {vie_df.shape[0]}')
print(f'Số quan sát tiếng Anh: {eng_df.shape[0]}')
# Out:
# Số quan sát tiếng Việt: 624
# Số quan sát tiếng Anh: 181
# time: 7.01 ms (started: 2023-12-23 04:54:00 +00:00)

# %%
pos = {
    'A': 'ADJ',  # Adjective: tính từ
    'C': 'CCONJ',  # Coordinating conjunction: liên từ
    'E': 'ADP',  # Preposition: giới từ
    'I': 'INTJ',  # Interjection: thán từ
    'L': 'DET',  # Determiner: đại từ xác định (a, an, the...)
    'M': 'NUM',  # Numeral: số
    'N': 'NOUN',  # Common noun: danh từ thông dụng
    'Nc': 'NOUN',  # Noun classifier: danh từ loại
    'Ny': 'NOUN',  # Noun abbreviation: danh từ viết tắt
    'Np': 'PROPN',  # Proper noun: tên riêng
    'Nu': 'NOUN',  # Unit noun: đơn vị
    'P': 'PRON',  # Pronoun: đại từ danh xưng
    'R': 'ADV',  # Adverb: trạng từ
    'S': 'SCONJ',  # Subordinating conjunction: liên từ phụ thuộc
    'T': 'AUX',  # Auxiliary, modal words: trợ động từ
    'V': 'VERB',  # Verb: động từ
    'F': 'PUNCT'  # Filtered out (punctuation): dấu cấu
}
# Out:
# time: 877 µs (started: 2023-12-23 04:54:01 +00:00)

# %%
full_viecontext = ' '.join(vie_df['context'])
full_engcontext = ' '.join(eng_df['context'])
print(f'Độ dài câu review tổng hợp tiếng Việt: {len(full_viecontext)}')
print(f'Độ dài câu review tổng hợp tiếng Anh: {len(full_engcontext)}')
# Out:
# Độ dài câu review tổng hợp tiếng Việt: 78835
# Độ dài câu review tổng hợp tiếng Anh: 11762
# time: 2.27 ms (started: 2023-12-23 04:54:03 +00:00)

# %%
# xử lý cho tiếng Việt
viecontext_postagger = ViPosTagger.postagging(ViTokenizer.tokenize(full_viecontext))
vieps_result = {word: pos.get(postag, 'X') for word, postag in zip(viecontext_postagger[0],
                            viecontext_postagger[1])} # X là other (những từ không xác định)
list(vieps_result.items())[:5]
# Out:
# [('Trường', 'NOUN'),
#  ('sạch', 'ADJ'),
#  ('đẹp', 'ADJ'),
#  (',', 'PUNCT'),
#  ('giảng_viên', 'NOUN')]
# time: 3.52 s (started: 2023-12-23 04:54:04 +00:00)

# %%
# xử lý cho tiếng Anh
engcontext_postagger = spacy.load('en_core_web_sm')(full_engcontext)
engps_result = {word.text: word.pos_ for word in engcontext_postagger}
list(engps_result.items())[:5]
# Out:
# [('One', 'NUM'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('best', 'ADJ'),
#  ('universities', 'NOUN')]
# time: 1.63 s (started: 2023-12-23 04:54:08 +00:00)

# %%
# combine kết quả và tạo df kết quả cả hai ngôn ngữ
pos_df = pd.DataFrame({
    'Word': list(vieps_result.keys()) + list(engps_result.keys()),
    'POS': list(vieps_result.values()) + list(engps_result.values()),
    'Ngôn ngữ': (['Tiếng Việt'] * len(vieps_result)) + (['Tiếng Anh'] * len(engps_result))
})
poscount_df = pos_df.groupby(['POS', 'Ngôn ngữ']).size().reset_index(name='Count')
poscount_df
# Out:
#       POS    Ngôn ngữ  Count
# 0     ADJ   Tiếng Anh    123
# 1     ADJ  Tiếng Việt    303
# 2     ADP   Tiếng Anh     26
# 3     ADP  Tiếng Việt     37
# 4     ADV   Tiếng Anh     57
# 5     ADV  Tiếng Việt     62
# 6     AUX   Tiếng Anh     25
# 7     AUX  Tiếng Việt      6
# 8   CCONJ   Tiếng Anh      4
# 9   CCONJ  Tiếng Việt     26
# 10    DET   Tiếng Anh     13
# 11    DET  Tiếng Việt     17
# 12   INTJ   Tiếng Anh      4
# 13   NOUN   Tiếng Anh    243
# 14   NOUN  Tiếng Việt   1125
# 15    NUM   Tiếng Anh     19
# 16    NUM  Tiếng Việt    134
# 17   PART   Tiếng Anh      4
# 18   PRON   Tiếng Anh     32
# 19   PRON  Tiếng Việt     40
# 20  PROPN   Tiếng Anh     64
# 21  PROPN  Tiếng Việt    211
# 22  PUNCT   Tiếng Anh     13
# 23  PUNCT  Tiếng Việt     27
# 24  SCONJ   Tiếng Anh     15
# 25  SCONJ  Tiếng Việt      2
# 26  SPACE   Tiếng Anh      2
# 27    SYM   Tiếng Anh      2
# 28   VERB   Tiếng Anh    153
# 29   VERB  Tiếng Việt    657
# 30      X   Tiếng Anh      3
# 31      X  Tiếng Việt     10
# time: 20.6 ms (started: 2023-12-23 04:54:10 +00:00)

# %%
# trực quan
plt.figure(figsize=(15, 6))
sns.barplot(x=poscount_df['POS'], y=poscount_df['Count'], hue=poscount_df['Ngôn ngữ'])
plt.title('Biểu đồ cột thể hiện tần suất xuất hiện các POS Taggings của reviews theo ngôn ngữ')
plt.xlabel('POS Taggings')
plt.ylabel('Số lần xuất hiện')
plt.show()
# Out:
# time: 482 ms (started: 2023-12-23 04:54:10 +00:00)

# %% [markdown]
# ###Lọc và xử lý theo ngôn ngữ

# %% [markdown]
# ####Xác định top chủ đề được đề cập nhiều nhất

# %%
# lọc token là danh từ và trực quan bằng wordcloud
result = {**vieps_result, **engps_result}
nouns_text = ' '.join([word for word, pos in result.items() if pos == 'NOUN'])
wordcloud = WordCloud(width=800, height=400, colormap=sns.color_palette("crest", as_cmap=True), background_color='white').generate_from_text(nouns_text)
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# time: 1.24 s (started: 2023-12-23 04:54:13 +00:00)

# %%
# tổng số lần xuất hiện
poscount_df.groupby('Ngôn ngữ')['Count'].sum()
# Out:
# Ngôn ngữ
# Tiếng Anh      802
# Tiếng Việt    2657
# Name: Count, dtype: int64
# time: 8.11 ms (started: 2023-12-23 04:54:20 +00:00)

# %%
# tìm các danh từ xuất hiện nhiều nhất
vienouns = {word: count for word, count in Counter(vieps_result.keys()).items() if vieps_result[word] == 'NOUN'}
vienouns = sorted(vienouns.items(), key=operator.itemgetter(1), reverse=True)
engnouns = {word: count for word, count in Counter(engps_result.keys()).items() if engps_result[word] == 'NOUN'}
engnouns = sorted(engnouns.items(), key=operator.itemgetter(1), reverse=True)
print(vienouns[:10])
print(engnouns[:10])
# Out:
# [('Trường', 1), ('giảng_viên', 1), ('chương_trình', 1), ('from', 1), ('Cơ_sở', 1), ('vật_chất', 1), ('trường', 1), ('miền', 1), ('đội_ngũ', 1), ('giáo_viên', 1)]
# [('universities', 1), ('time', 1), ('place', 1), ('school', 1), ('environment', 1), ('club', 1), ('group', 1), ('activities', 1), ('student', 1), ('food', 1)]
# time: 7.18 ms (started: 2023-12-23 04:54:22 +00:00)

# %% [markdown]
# #### Phân tích nội dung tiêu cực: Giảng viên

# %%
# tìm những review về chủ đề giảng viên cần cải thiện
lec_keywords = ['giảng viên', 'giáo viên', 'teacher', 'lecturer', 'khoa', 'đội ngũ', 'cán bộ', 'quản lý', 'văn phòng']
lec_negrvs = df[(df['sentiment'] == 'negative') & df['context'].str.contains('|'.join(lec_keywords), case=False)]
lec_negrvs = lec_negrvs.sort_values(by='likes', ascending=False)
lec_negrvs[['context', 'likes', 'location', 'sentiment', 'language']]
# Out:
#                                                context  likes location  \
# 575  Thái độ văn phòng đào tạo k tốt. Mình vào hỏi ...   20.0     uehA
# 570  Tệ,mức học phí quá cao 930k/1 tín,tuyển sinh đ...   10.0     uehA
# 566  Một ngôi trường lừa đảo, lúc tuyển sinh thì nó...    9.0     uehI
# 568  Giảng viên không có tinh thần, phòng ban làm v...    9.0     uehA
# 550  Trường có cơ sở vật chất hiện đại không sử dụn...    7.0     uehB
# 557  NHƯỢC ĐIỂM:\n - Khi đi thực tập trường in cái ...    7.0   uehVL1
# 548  Cán bộ phòng ban hoàn toàn không có tin thần p...    6.0     uehA
# 530  Giảng viên không có tinh thần, phòng ban làm v...    4.0     uehB
# 499  Mình đã xác minh là chỗ này đã đập bỏ rồi mà g...    3.0     uehB
# 490  Cơ sở nhỏ xíu, cũ. Không có thư viện, không có...    2.0     uehE
# 352  ĐHKT TP.HỒ CHÍ MINH là cơ sở đào tạo đại học v...    1.0     uehB
# 591  Môi trường thân thiện, cơ sở chất lượng, giảng...    NaN     uehB
# 637  Cơ sở vật chất tốt, máy lạnh 🥶 gất lạnh\n Tuy ...    NaN  uehLibN
# 830  This is where I learned my economics degree. I...    NaN     uehA
# 834  Prestigious and old school in town. Parking lo...    NaN     uehA
#
#     sentiment language
# 575  negative       vi
# 570  negative       vi
# 566  negative       vi
# 568  negative       vi
# 550  negative       vi
# 557  negative       vi
# 548  negative       vi
# 530  negative       vi
# 499  negative       vi
# 490  negative       vi
# 352  negative       vi
# 591  negative       vi
# 637  negative       vi
# 830  negative       en
# 834  negative       en
# time: 95.6 ms (started: 2023-12-23 04:54:25 +00:00)

# %%
# hiện chi tiết nội dung review
print(f'Số bình luận tiêu cực về chủ đề "Giảng viên" là {len(lec_negrvs)} reviews',
      '\n---------------------------------------------------------------------------')
for index, row in lec_negrvs.iterrows():
    print(f'Tên người đánh giá: {row["reviewer"]}\nCơ sở đánh giá: {row["location"]}\nNội dung đánh giá: {row["context"]}',
          '\n---------------------------------------------------------------------------')
# Out:
# Số bình luận tiêu cực về chủ đề "Giảng viên" là 15 reviews
# ---------------------------------------------------------------------------
# Tên người đánh giá: Gia Quốc
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Thái độ văn phòng đào tạo k tốt. Mình vào hỏi mà quát vào mặt. Chỉ nhớ bà cô đó tên quyên, mập. Đi nộp hồ sơ mà hỏi lòng vòng. Kiểu khinh khỉnh. Chưa biết bà đó có dạy học sinh k mà thái độ như bà nội thiên hạ.
# ---------------------------------------------------------------------------
# Tên người đánh giá: APB Phạm
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Tệ,mức học phí quá cao 930k/1 tín,tuyển sinh đầu vào không kĩ,xét học bạ nhiều,giảng viên dạy thiếu tâm huyết,thời gian học ít,cơ sở vật chất chưa đáp ứng được với lượng sinh viên, vậy mà trường còn tuyển khá nhiều chỉ tiêu, công tác đào tạo không chất lượng, càng thế hệ sau càng nát chỉ được danh tiếng của các thế hệ trước.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Tân Nguyễn Hữu
# Cơ sở đánh giá: uehI
# Nội dung đánh giá: Một ngôi trường lừa đảo, lúc tuyển sinh thì nói rất hay tuy nhiên xảy ra vấn đề gì thì bị pending lại, dù tôi đã rất nhiều lần đến trường trực tiếp giải quyết, câu trả lời vẫn là " Không có quản lý đi làm, em đi về đi" và không có ngày hẹn, hay trả lời mail xác nhận nào cả. Mọi người hãy cân nhắc kỹ các vấn đề về Phòng tuyển sinh ở đây. Rất tệ về cả chất lượng lẫn tư cách làm việc của nhuungwx người đã làm việc với tôi Ms Thanh, Mr Phương, và Minh Anh.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Apes Together Strong
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Giảng viên không có tinh thần, phòng ban làm việc kém, môi trường học tập độc hại, sinh viên sân si.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Bình Lê Thanh
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Trường có cơ sở vật chất hiện đại không sử dụng tối ưu
#  Giảng viên giỏi và hay thì không còn dạy.
#  Giảng viên cấp 3 thì nhiều, dạy thì chán, đọc sách giáo khoa ra không.
#  Làm việc còn theo cơ chế xin cho, giải quyết quan liêu, giảng viên trưởng khoa nói năng thay trắng đổi đen, và giảng viên chơi đá bóng trách nhiệm & lỗi rất hay.
# ---------------------------------------------------------------------------
# Tên người đánh giá: 30.Phú Trường
# Cơ sở đánh giá: uehVL1
# Nội dung đánh giá: NHƯỢC ĐIỂM:
#  - Khi đi thực tập trường in cái phiếu có Logo Phân Hiệu UEH Vĩnh Long chà bá. ( K46 chia sẻ )
#  - Bảng điểm vẫn in Chữ Phân Hiệu khi đưa cho nhà tuyển dụng xem ( K46 chia sẻ)
#  - Giấy tạm hoãn quân sự vẫn in chứ Phân Hiệu Vĩnh Long
#  - Giấy xác nhận sinh viên vẫn In Phân Hiệu Vĩnh Long
#  - Môi trường khá thụ động, khá suy tư, yên bình
#  - Trong phòng đào tạo có một bà cô ( dáng người khá to con ) có thái độ hơi bị thất học và thổ tả
#  - Tới mùa nước nổi trường ngập nước tới đầu gối....
#
#  Ưu điểm:
#  - Cơ sở vật chất đáp ứng khá đầy đủ nhu cầu học tập sinh viên
#  - Hỗ trợ và giải đáp thắc mắc cho sinh viên Khá nhanh
#  - Giảng viên đa phần dễ thương....
#
#  Nếu bạn thích cuộc sống nhàn nhạ, suy nghĩ, trầm, sâu lắng.... Có thể chọn nơi đây gửi gấm. Nhưng lựa chọn nào cũng phải trả giá, đừng vì cái danh mà đánh mất nhiều thứ. Mình đã học ở đây 1 năm ( Lớp LM001 - K48 - Logistics And Supply Chain Management ) sau đó chuyển trường sang UEL ( Kinh Tế - Luật ). Lên Sài Gòn mình cảm thấy môi trường Sài Gòn nó năng động hơn hẳng Vĩnh Long, lên đây học mình thấy mình thua nhiều thứ hơn mấy đứa học Sài Gòn.
#  Nếu mình học với những con người giỏi, mình sẽ bị tác động theo thôi. Môi nó tác động rất khủng khiếp về tư duy và tính cách.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Duy Khánh Nguyễn
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Cán bộ phòng ban hoàn toàn không có tin thần phục vụ, giảng viên thì không có nhiệt huyết truyền đạt kiến thức
# ---------------------------------------------------------------------------
# Tên người đánh giá: Apes Together Strong
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Giảng viên không có tinh thần, phòng ban làm việc kém, môi trường học tập độc hại, sinh viên sân si.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Tuấn Lê
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Mình đã xác minh là chỗ này đã đập bỏ rồi mà google không xem xét là sao. Đội ngũ làm việc có thiếu hiểu biết thì vừa vừa thôi chứ
# ---------------------------------------------------------------------------
# Tên người đánh giá: Jennifer Louis
# Cơ sở đánh giá: uehE
# Nội dung đánh giá: Cơ sở nhỏ xíu, cũ. Không có thư viện, không có canteen, xung quanh bán ít đồ ăn vặt, có nhiều chỗ gửi xe cho sinh viên. Chỗ gửi xe trong trường nhỏ, ra sớm mà xe để ở trong là thôi rồi khó lấy ra, đi trễ là hết chỗ để xe. Máy tính cho giảng viên xài cũng cũ rồi, máy lạnh cũng hay hư lên hư xuống. Từ lầu 4 trở lên là ghế gỗ, không có chỗ dựa. Được cái mỗi phòng có wifi riêng cho học sinh, sinh viên, giảng viên.
# ---------------------------------------------------------------------------
# Tên người đánh giá: TRAN PHAM
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: ĐHKT TP.HỒ CHÍ MINH là cơ sở đào tạo đại học và sau đại học các ngành về kinh tế hàng đầu của VN. Nơi đây có đội ngũ Giao sư có chuyên môn cao, giáo trình liên tục cập nhật và quan hệ tốt với các trường đại học và tổ chức quốc tế. Trường đã đạo tạo rất nhiều nhân sự trình độ chuyên môn cao cho nền Quốc gia.Tuy nhiên cơ sở vật chất manh mún, nhỏ lẻ và cũ kỹ, không tương xứng với tầm vóc và giá trị của nó mang lại.
# ---------------------------------------------------------------------------
# Tên người đánh giá: NHU PHAM QUYNH
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Môi trường thân thiện, cơ sở chất lượng, giảng viên tùy người: có tâm dễ hiểu hoặc giảng rất có tâm nhưng không hiểu, hoặc không hiểu gì.
#  Trường quá nhiều cơ sở, đi học vất vả, tiền học rất phải suy ngẫm.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Trang ZzzZ
# Cơ sở đánh giá: uehLibN
# Nội dung đánh giá: Cơ sở vật chất tốt, máy lạnh 🥶 gất lạnh
#  Tuy nhiên cô quản lý siêu khó tính và gắt gỏng🥹 …
# ---------------------------------------------------------------------------
# Tên người đánh giá: Huyen Vu
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: This is where I learned my economics degree. It's just so small that you can't have your bike parking, because the parking is for teachers only.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Phuong Nguyen
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Prestigious and old school in town. Parking lot is small and prioritized for teachers.
# ---------------------------------------------------------------------------
# time: 17 ms (started: 2023-12-23 04:54:27 +00:00)

# %% [markdown]
# #### Phân tích nội dung tiêu cực: Cơ sở vật chất

# %%
# tương tự như trên
fac_keywords = ['cơ sở vật chất', 'thiết bị', 'phòng học', 'thư viện', 'nhà xe', 'bãi xe', 'chỗ gửi xe', 'chỗ để xe',
                'phòng lab', 'không gian', 'AC', 'facilities', 'environment', 'facility', 'room', 'parking']
fac_negrvs = df[(df['sentiment'] == 'negative') & df['context'].str.contains('|'.join(fac_keywords), case=False)]
fac_negrvs = fac_negrvs.sort_values(by='likes', ascending=False)
print(f'Số bình luận tiêu cực về chủ đề "Cơ sở vật chất" là {len(fac_negrvs)} reviews',
      '\n---------------------------------------------------------------------------')
for index, row in fac_negrvs.iterrows():
    print(f'Tên người đánh giá: {row["reviewer"]}\nCơ sở đánh giá: {row["location"]}\nNội dung đánh giá: {row["context"]}',
          '\n---------------------------------------------------------------------------')
# Out:
# Số bình luận tiêu cực về chủ đề "Cơ sở vật chất" là 25 reviews
# ---------------------------------------------------------------------------
# Tên người đánh giá: APB Phạm
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Tệ,mức học phí quá cao 930k/1 tín,tuyển sinh đầu vào không kĩ,xét học bạ nhiều,giảng viên dạy thiếu tâm huyết,thời gian học ít,cơ sở vật chất chưa đáp ứng được với lượng sinh viên, vậy mà trường còn tuyển khá nhiều chỉ tiêu, công tác đào tạo không chất lượng, càng thế hệ sau càng nát chỉ được danh tiếng của các thế hệ trước.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Bình Lê Thanh
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Trường có cơ sở vật chất hiện đại không sử dụng tối ưu
#  Giảng viên giỏi và hay thì không còn dạy.
#  Giảng viên cấp 3 thì nhiều, dạy thì chán, đọc sách giáo khoa ra không.
#  Làm việc còn theo cơ chế xin cho, giải quyết quan liêu, giảng viên trưởng khoa nói năng thay trắng đổi đen, và giảng viên chơi đá bóng trách nhiệm & lỗi rất hay.
# ---------------------------------------------------------------------------
# Tên người đánh giá: 30.Phú Trường
# Cơ sở đánh giá: uehVL1
# Nội dung đánh giá: NHƯỢC ĐIỂM:
#  - Khi đi thực tập trường in cái phiếu có Logo Phân Hiệu UEH Vĩnh Long chà bá. ( K46 chia sẻ )
#  - Bảng điểm vẫn in Chữ Phân Hiệu khi đưa cho nhà tuyển dụng xem ( K46 chia sẻ)
#  - Giấy tạm hoãn quân sự vẫn in chứ Phân Hiệu Vĩnh Long
#  - Giấy xác nhận sinh viên vẫn In Phân Hiệu Vĩnh Long
#  - Môi trường khá thụ động, khá suy tư, yên bình
#  - Trong phòng đào tạo có một bà cô ( dáng người khá to con ) có thái độ hơi bị thất học và thổ tả
#  - Tới mùa nước nổi trường ngập nước tới đầu gối....
#
#  Ưu điểm:
#  - Cơ sở vật chất đáp ứng khá đầy đủ nhu cầu học tập sinh viên
#  - Hỗ trợ và giải đáp thắc mắc cho sinh viên Khá nhanh
#  - Giảng viên đa phần dễ thương....
#
#  Nếu bạn thích cuộc sống nhàn nhạ, suy nghĩ, trầm, sâu lắng.... Có thể chọn nơi đây gửi gấm. Nhưng lựa chọn nào cũng phải trả giá, đừng vì cái danh mà đánh mất nhiều thứ. Mình đã học ở đây 1 năm ( Lớp LM001 - K48 - Logistics And Supply Chain Management ) sau đó chuyển trường sang UEL ( Kinh Tế - Luật ). Lên Sài Gòn mình cảm thấy môi trường Sài Gòn nó năng động hơn hẳng Vĩnh Long, lên đây học mình thấy mình thua nhiều thứ hơn mấy đứa học Sài Gòn.
#  Nếu mình học với những con người giỏi, mình sẽ bị tác động theo thôi. Môi nó tác động rất khủng khiếp về tư duy và tính cách.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Mr Thụy
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Hơn 20 năm sống ở SG, lần đầu tiên kẹt xe ở bãi gửi xe, cs B xây lại hoành tráng nhưng bãi xe & hệ thống gửi xe quá tệ.
#  Hy vọng nhà trường cải thiện sớm
# ---------------------------------------------------------------------------
# Tên người đánh giá: Peter
# Cơ sở đánh giá: uehHOTEL
# Nội dung đánh giá: Room: 2/5 - The quality of the room was OK but they didn't clean the room while I stayed here for a few days.
#  Services: 1/5 - I got a discount voucher when I paid immediately - It's OK. But check your room carefully 'cause in the day I checked out, they said I had to pay for an extra as their staff said I lost my room stuff.
#  Food: 2/5 - They served food every morning - noodle and egg, sandwich.
# ---------------------------------------------------------------------------
# Tên người đánh giá: danh pham
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Kinh hoàng vì bãi xe khi lấy xe. Để ở tầng hầng b2 là xác định về hít khói 30 phút trước khi ra đc tới cổng.
# ---------------------------------------------------------------------------
# Tên người đánh giá: trường thịnh nguyễn
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Bãi xe quá tải. Cơ sơ vật chất không đáp ứng cho số lượng con người
# ---------------------------------------------------------------------------
# Tên người đánh giá: Jennifer Louis
# Cơ sở đánh giá: uehE
# Nội dung đánh giá: Cơ sở nhỏ xíu, cũ. Không có thư viện, không có canteen, xung quanh bán ít đồ ăn vặt, có nhiều chỗ gửi xe cho sinh viên. Chỗ gửi xe trong trường nhỏ, ra sớm mà xe để ở trong là thôi rồi khó lấy ra, đi trễ là hết chỗ để xe. Máy tính cho giảng viên xài cũng cũ rồi, máy lạnh cũng hay hư lên hư xuống. Từ lầu 4 trở lên là ghế gỗ, không có chỗ dựa. Được cái mỗi phòng có wifi riêng cho học sinh, sinh viên, giảng viên.
# ---------------------------------------------------------------------------
# Tên người đánh giá: TRAN PHAM
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: ĐHKT TP.HỒ CHÍ MINH là cơ sở đào tạo đại học và sau đại học các ngành về kinh tế hàng đầu của VN. Nơi đây có đội ngũ Giao sư có chuyên môn cao, giáo trình liên tục cập nhật và quan hệ tốt với các trường đại học và tổ chức quốc tế. Trường đã đạo tạo rất nhiều nhân sự trình độ chuyên môn cao cho nền Quốc gia.Tuy nhiên cơ sở vật chất manh mún, nhỏ lẻ và cũ kỹ, không tương xứng với tầm vóc và giá trị của nó mang lại.
# ---------------------------------------------------------------------------
# Tên người đánh giá: AD AS
# Cơ sở đánh giá: uehVL1
# Nội dung đánh giá: place not dep
# ---------------------------------------------------------------------------
# Tên người đánh giá: Linh Pham
# Cơ sở đánh giá: uehE
# Nội dung đánh giá: Bãi xe hơi nhỏ, phòng học nhỏ
# ---------------------------------------------------------------------------
# Tên người đánh giá: Phuong Nguyen
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Không gian dù rộng nhưng vẫn cảm giác hơi ngộp có lẽ do đông sinh viên và xe cộ trong trường quá.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Phong Nguyen
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Cơ sở vật chất hiện đại, nhưng bãi gửi xe hơi đông
# ---------------------------------------------------------------------------
# Tên người đánh giá: Châu Minh
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Nhân viên giữ xe, cơ sở vật chất khá tệ.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Ly Thùy
# Cơ sở đánh giá: uehN
# Nội dung đánh giá: Nắng cực, xa xôi, lắm picachu
# ---------------------------------------------------------------------------
# Tên người đánh giá: Quý Nguyễn
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Nhà xe lúc nào cũng chật
# ---------------------------------------------------------------------------
# Tên người đánh giá: L.C Truong
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Trường thiếu chỗ gửi xe.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Quất Bủh Lê
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Đóng cửa nhà xe sớm hơn mọi khi mà không thông báo, sinh viên không lấy được xe để đi về, lúc hỏi mấy giờ đóng cửa thì không nói, xua tay kêu lẹ lẹ để người khác tới.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Duc Huy Nguyen
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Đến cơ sở này mấy lần khi bạn bè tốt nghiệp, bên trong có hội trường rộng (~500 chỗ) nhưng có vẻ không đủ không gian cho người nhà + bạn bè.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Ocean's Prince
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Không gian cơ sở A khá hạn hẹp, chật chội, nhưng nhiều hoạt động diễn ra, thu hút sinh viên
# ---------------------------------------------------------------------------
# Tên người đánh giá: Trang ZzzZ
# Cơ sở đánh giá: uehLibN
# Nội dung đánh giá: Cơ sở vật chất tốt, máy lạnh 🥶 gất lạnh
#  Tuy nhiên cô quản lý siêu khó tính và gắt gỏng🥹 …
# ---------------------------------------------------------------------------
# Tên người đánh giá: David Nguyen
# Cơ sở đánh giá: uehQ8
# Nội dung đánh giá: It have enough equipment that we can practice
# ---------------------------------------------------------------------------
# Tên người đánh giá: Vtrippie Vietnam Free Tour Guides
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Big classroom without AC!
# ---------------------------------------------------------------------------
# Tên người đánh giá: Huyen Vu
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: This is where I learned my economics degree. It's just so small that you can't have your bike parking, because the parking is for teachers only.
# ---------------------------------------------------------------------------
# Tên người đánh giá: Phuong Nguyen
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Prestigious and old school in town. Parking lot is small and prioritized for teachers.
# ---------------------------------------------------------------------------
# time: 39.3 ms (started: 2023-12-23 04:54:31 +00:00)

# %% [markdown]
# #### Phân tích nội dung tiêu cực: Hoạt động sinh viên

# %%
# tương tự như trên
activity_keywords = ['hoạt động', 'sinh viên', 'activity', 'activities', 'student', 'students', 'ueher', 'thái độ',
                     'club', 'câu lạc bộ', 'clb', 'đội', 'nhóm', 'sự kiện', 'ý thức', 'người học', 'học sinh']
activity_negrvs = df[(df['sentiment'] == 'negative') & df['context'].str.contains('|'.join(activity_keywords), case=False)]
activity_negrvs = activity_negrvs.sort_values(by='likes', ascending=False)
print(f'Số bình luận tiêu cực về chủ đề "Hoạt động sinh viên" là {len(fac_negrvs)} reviews',
      '\n---------------------------------------------------------------------------')
for index, row in activity_negrvs.iterrows():
    print(f'Tên người đánh giá: {row["reviewer"]}\nCơ sở đánh giá: {row["location"]}\nNội dung đánh giá: {row["context"]}\nLikes: {row["likes"]}\n---')
# Out:
# Số bình luận tiêu cực về chủ đề "Hoạt động sinh viên" là 25 reviews
# ---------------------------------------------------------------------------
# Tên người đánh giá: Gia Quốc
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Thái độ văn phòng đào tạo k tốt. Mình vào hỏi mà quát vào mặt. Chỉ nhớ bà cô đó tên quyên, mập. Đi nộp hồ sơ mà hỏi lòng vòng. Kiểu khinh khỉnh. Chưa biết bà đó có dạy học sinh k mà thái độ như bà nội thiên hạ.
# Likes: 20.0
# ---
# Tên người đánh giá: Khải Nguyễn
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Trường đại học kinh tế Tphcm một trong những trường đại học nổi tiếng nhất Việt Nam
#  Khuôn viên khá yên tĩnh và sạch sẻ
#  Chất lượng đào tào tốt
#  Bãi giữ xe cũng nhỏ không quá rộng
#
#  Tuy nhiên:
#  Nằm ngay giữa trung tâm quận nhất nên vấn đề di chuyển có hơi khó khăn cho sinh viên giờ cao điểm
# Likes: 11.0
# ---
# Tên người đánh giá: APB Phạm
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Tệ,mức học phí quá cao 930k/1 tín,tuyển sinh đầu vào không kĩ,xét học bạ nhiều,giảng viên dạy thiếu tâm huyết,thời gian học ít,cơ sở vật chất chưa đáp ứng được với lượng sinh viên, vậy mà trường còn tuyển khá nhiều chỉ tiêu, công tác đào tạo không chất lượng, càng thế hệ sau càng nát chỉ được danh tiếng của các thế hệ trước.
# Likes: 10.0
# ---
# Tên người đánh giá: Apes Together Strong
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Giảng viên không có tinh thần, phòng ban làm việc kém, môi trường học tập độc hại, sinh viên sân si.
# Likes: 9.0
# ---
# Tên người đánh giá: Phước Tài
# Cơ sở đánh giá: uehN
# Nội dung đánh giá: Trường muốn cho sinh viên ra học ở ngoại ô mà lại không xây kí túc xá. Có gọi là sự thiếu chu đáo trong tính toán không
# Likes: 8.0
# ---
# Tên người đánh giá: 30.Phú Trường
# Cơ sở đánh giá: uehVL1
# Nội dung đánh giá: NHƯỢC ĐIỂM:
#  - Khi đi thực tập trường in cái phiếu có Logo Phân Hiệu UEH Vĩnh Long chà bá. ( K46 chia sẻ )
#  - Bảng điểm vẫn in Chữ Phân Hiệu khi đưa cho nhà tuyển dụng xem ( K46 chia sẻ)
#  - Giấy tạm hoãn quân sự vẫn in chứ Phân Hiệu Vĩnh Long
#  - Giấy xác nhận sinh viên vẫn In Phân Hiệu Vĩnh Long
#  - Môi trường khá thụ động, khá suy tư, yên bình
#  - Trong phòng đào tạo có một bà cô ( dáng người khá to con ) có thái độ hơi bị thất học và thổ tả
#  - Tới mùa nước nổi trường ngập nước tới đầu gối....
#
#  Ưu điểm:
#  - Cơ sở vật chất đáp ứng khá đầy đủ nhu cầu học tập sinh viên
#  - Hỗ trợ và giải đáp thắc mắc cho sinh viên Khá nhanh
#  - Giảng viên đa phần dễ thương....
#
#  Nếu bạn thích cuộc sống nhàn nhạ, suy nghĩ, trầm, sâu lắng.... Có thể chọn nơi đây gửi gấm. Nhưng lựa chọn nào cũng phải trả giá, đừng vì cái danh mà đánh mất nhiều thứ. Mình đã học ở đây 1 năm ( Lớp LM001 - K48 - Logistics And Supply Chain Management ) sau đó chuyển trường sang UEL ( Kinh Tế - Luật ). Lên Sài Gòn mình cảm thấy môi trường Sài Gòn nó năng động hơn hẳng Vĩnh Long, lên đây học mình thấy mình thua nhiều thứ hơn mấy đứa học Sài Gòn.
#  Nếu mình học với những con người giỏi, mình sẽ bị tác động theo thôi. Môi nó tác động rất khủng khiếp về tư duy và tính cách.
# Likes: 7.0
# ---
# Tên người đánh giá: GogO Myy
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Học phí mắc, không thích học ở cơ sở N chút nào. Cái web ueh.student sập cũng chả thấy khắc phục
# Likes: 6.0
# ---
# Tên người đánh giá: giang nhan
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Sinh viên hơi ồn ào bất lịch sự đề nghị trường coi lại kỉ luật hơn khi ra đường tránh ảnh hưởng đến người khác kể cả xung quanh trường
# Likes: 6.0
# ---
# Tên người đánh giá: Apes Together Strong
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Giảng viên không có tinh thần, phòng ban làm việc kém, môi trường học tập độc hại, sinh viên sân si.
# Likes: 4.0
# ---
# Tên người đánh giá: Anh Tuấn
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Đang đập để xây lại một phần mặt tiền phía góc đường. Nhưng phía sau vẫn còn sinh viên theo học cả sáng lẫn tối.
# Likes: 4.0
# ---
# Tên người đánh giá: Thieu Quang Tran
# Cơ sở đánh giá: uehKTX4345
# Nội dung đánh giá: đề nghị nhà trường xem xét lại thái độ của nhân viên nữ làm việc tại ktx, thái độ trơ trẽn nói chuyện không ăn học ảnh hưởng đến các sinh viên, thái độ cực kì tiêu cực, nếu không có biện pháp nào thì đây là ktx tồi tệ nhất cho 1 ngày đi học ở NGÔI TRƯỜNG này về
# Likes: 3.0
# ---
# Tên người đánh giá: Tuấn Lê
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Mình đã xác minh là chỗ này đã đập bỏ rồi mà google không xem xét là sao. Đội ngũ làm việc có thiếu hiểu biết thì vừa vừa thôi chứ
# Likes: 3.0
# ---
# Tên người đánh giá: Jennifer Louis
# Cơ sở đánh giá: uehE
# Nội dung đánh giá: Cơ sở nhỏ xíu, cũ. Không có thư viện, không có canteen, xung quanh bán ít đồ ăn vặt, có nhiều chỗ gửi xe cho sinh viên. Chỗ gửi xe trong trường nhỏ, ra sớm mà xe để ở trong là thôi rồi khó lấy ra, đi trễ là hết chỗ để xe. Máy tính cho giảng viên xài cũng cũ rồi, máy lạnh cũng hay hư lên hư xuống. Từ lầu 4 trở lên là ghế gỗ, không có chỗ dựa. Được cái mỗi phòng có wifi riêng cho học sinh, sinh viên, giảng viên.
# Likes: 2.0
# ---
# Tên người đánh giá: Hùng Nguyễn Minh
# Cơ sở đánh giá: uehKTX4345
# Nội dung đánh giá: Là ký túc xá khá lâu đời của sinh viên trường Đại học Kinh tế TP. Hồ Chí Minh. Khoảng cách từ ký túc xá đến trường khá gần, có thể đi bộ. Sau một thời gian xuống cấp, ký túc xá đã được cải tạo một phần. Tuy nhiên, khu vực chung quang ký túc xá khá phức tạp, gái ngành hoạt động ầm ầm. Thậm chí ký túc xá mở căn tin ngay mặt tiền đường Nguyễn Chí Thanh nên không tránh khỏi các thành phần khác nhau trong xã hội có thể tụ tập trong căn tin này.
# Likes: 1.0
# ---
# Tên người đánh giá: Phuong Nguyen
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Không gian dù rộng nhưng vẫn cảm giác hơi ngộp có lẽ do đông sinh viên và xe cộ trong trường quá.
# Likes: 1.0
# ---
# Tên người đánh giá: Huy Nguyễn Đình
# Cơ sở đánh giá: uehLibB
# Nội dung đánh giá: ki bo với sinh viên, đi học sớm tý cũng không cho vô lớp học ngồi, sợ tốn điện (lời nhân viên dọn phòng)
# Likes: 1.0
# ---
# Tên người đánh giá: TRAN PHAM
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: ĐHKT TP.HỒ CHÍ MINH là cơ sở đào tạo đại học và sau đại học các ngành về kinh tế hàng đầu của VN. Nơi đây có đội ngũ Giao sư có chuyên môn cao, giáo trình liên tục cập nhật và quan hệ tốt với các trường đại học và tổ chức quốc tế. Trường đã đạo tạo rất nhiều nhân sự trình độ chuyên môn cao cho nền Quốc gia.Tuy nhiên cơ sở vật chất manh mún, nhỏ lẻ và cũ kỹ, không tương xứng với tầm vóc và giá trị của nó mang lại.
# Likes: 1.0
# ---
# Tên người đánh giá: Nguyen Xuan Thanh
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Sinh viên trường ra đường đứng làm tắc nghẽn giao thông
# Likes: nan
# ---
# Tên người đánh giá: BAA TV
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: trụ sở chính nên có hội trường rất rộng cho sinh viên
# Likes: nan
# ---
# Tên người đánh giá: Thien Quang Otis
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Đào tạo oke mà đông sinh viên trong 1 lớp
# Likes: nan
# ---
# Tên người đánh giá: Trang Nguyen
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Trường không rộng lắm, chỉ một số ít các chuyên ngành học ở đây, còn lại đa phần học Anh văn và một số học vào buổi tối.
#  Kho của Đội CTXH UEH đặt ở tầng 2 của trường.
#  Trước trường có một bãi giữ xe honda và 1 nhà nhỏ giữ xe đạp.
#  Trước lối vào trường có một xe bán nuôi, mì xào và một quán photocopy cũng như một quầy nước.
# Likes: nan
# ---
# Tên người đánh giá: Quất Bủh Lê
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Đóng cửa nhà xe sớm hơn mọi khi mà không thông báo, sinh viên không lấy được xe để đi về, lúc hỏi mấy giờ đóng cửa thì không nói, xua tay kêu lẹ lẹ để người khác tới.
# Likes: nan
# ---
# Tên người đánh giá: Khoa Nguyễn
# Cơ sở đánh giá: uehB
# Nội dung đánh giá: Cơ sở mới khang trang, hiện đại
#  Mỗi tầng vẫn chưa trang bị máy lọc nước dù đã đưa vào hoạt động hơn 3 năm
# Likes: nan
# ---
# Tên người đánh giá: Ocean's Prince
# Cơ sở đánh giá: uehA
# Nội dung đánh giá: Không gian cơ sở A khá hạn hẹp, chật chội, nhưng nhiều hoạt động diễn ra, thu hút sinh viên
# Likes: nan
# ---
# time: 40.7 ms (started: 2023-12-23 04:54:34 +00:00)

# %% [markdown]
# # Xây dựng mô hình phân lớp Sentiment

# %% [markdown]
# ##Tiền xử lý

# %%
def create_data_tuples(df):
    data_tuples = []
    for index, row in df.iterrows():
        # Extract the list of words
        word_list = row['tokens']

        # Create a feature dictionary
        feature_dict = {word: True for word in word_list}

        data_tuples.append((feature_dict, row['sentiment']))
    return data_tuples
# Out:
# time: 606 µs (started: 2023-12-23 04:54:37 +00:00)

# %%
data_tuples = create_data_tuples(df)
data_tuples
# Out:
# [({'trường': True,
#    'sạch': True,
#    'đẹp': True,
#    'giảng_viên': True,
#    'dễ': True,
#    'thươngchương': True,
#    'trình': True,
#    'học': True,
#    'tốt': True,
#    'from': True,
#    'ueher': True,
#    '43': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'vật_chất': True,
#    'hiện_đại': True,
#    'thật': True,
#    'tuyệt_vời': True,
#    '1': True,
#    'trường': True,
#    'đại_học': True,
#    'lớn': True,
#    'của': True,
#    'miền': True,
#    'nam': True},
#   'positive'),
#  ({'ngôi': True,
#    'trường': True,
#    'có': True,
#    'đội_ngũ': True,
#    'giáo_viên': True,
#    'giỏi': True,
#    'nhiệt_tình': True,
#    'và': True,
#    'vô_cùng': True,
#    'dễ_thương': True,
#    '…': True},
#   'positive'),
#  ({'hay': True,
#    'tự_ý': True,
#    'đổi': True,
#    'lịch': True,
#    'học': True,
#    'của': True,
#    'học_sinh': True,
#    'nhưng': True,
#    'nhìn_chung': True,
#    'rất': True,
#    'là': True,
#    'tốt': True,
#    'gud': True},
#   'positive'),
#  ({'truong': True,
#    'rat': True,
#    'dep': True,
#    'có': True,
#    'sân': True,
#    'bóng_chuyền': True,
#    'cầu_lông': True,
#    'bóng_đá': True,
#    'nữa': True,
#    'mình': True,
#    'rất': True,
#    'yêu': True,
#    'ý': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'vật_chất': True,
#    'hiện_đại': True,
#    'không_gian': True,
#    'xanh': True,
#    'và': True,
#    'thoáng': True,
#    'mọi': True,
#    'người': True,
#    'thân_thiện': True},
#   'positive'),
#  ({'được': True,
#    'mỗi': True,
#    'cái': True,
#    'cơ_sở': True,
#    'này': True,
#    'là': True,
#    'đây': True,
#    'đủ': True,
#    'tiện_nghi': True,
#    'và': True,
#    'giống': True,
#    'trường_học': True,
#    'nhất': True},
#   'positive'),
#  ({'trường': True,
#    'rộng_rãi': True,
#    'thoáng': True,
#    'mát': True,
#    'bãi': True,
#    'đậu': True,
#    'xe': True,
#    'môi_trường': True,
#    'thân_thiện': True},
#   'positive'),
#  ({'nơi': True,
#    'đào_tạo': True,
#    'các': True,
#    'chuyên_ngành': True,
#    'kinh_tế': True,
#    'uy': True,
#    'tính': True,
#    'của': True,
#    'khu_vực': True,
#    'tphồ': True,
#    'chí': True,
#    'minh': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'vật_chất': True,
#    'bên': True,
#    'campus': True,
#    'này': True,
#    'là': True,
#    'xịn': True,
#    'nhứt': True,
#    'lunnn': True,
#    'đã': True,
#    'dữ': True,
#    'lắm': True,
#    'bà_con': True,
#    'uiiii': True},
#   'positive'),
#  ({'nơi': True,
#    'đào_tạo': True,
#    'nhiều': True,
#    'nhà': True,
#    'kinh_tế': True,
#    'doanh_nghiệp': True,
#    'trẻ': True,
#    'có': True,
#    'uy_tín': True,
#    'trên': True,
#    'cả': True,
#    'nước': True},
#   'positive'),
#  ({'là': True,
#    'trường': True,
#    'đại_học': True,
#    'đào_tạo': True,
#    'cử_nhân': True,
#    'kinh_tế': True,
#    'tốt': True,
#    'nhất': True,
#    'hiện_nay': True,
#    'ở': True,
#    'việt_nam': True},
#   'positive'),
#  ({'ai': True,
#    'muốn': True,
#    'tài_chính': True,
#    'ổn_định': True,
#    'trong': True,
#    'tương_lai': True,
#    'nên': True,
#    'chọn': True,
#    'trường': True,
#    'đại_học': True,
#    'này': True},
#   'positive'),
#  ({'nơi': True,
#    'đào_tạo': True,
#    'những': True,
#    'cử_nhân': True,
#    'nhà': True,
#    'quản_lý': True,
#    'tương_lai': True,
#    'chất_lượng': True,
#    'hàng_đầu': True},
#   'positive'),
#  ({'là': True,
#    'một': True,
#    'trong': True,
#    'các': True,
#    'đại_học': True,
#    'uy_tín': True,
#    'ở': True,
#    'tphcm': True,
#    'cũng': True,
#    'như': True,
#    'cả': True,
#    'nước': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'vật_chất': True,
#    'hiện_đại': True,
#    'sạch_sẽ': True,
#    'vô_cùng': True,
#    'học_sinh': True,
#    'thân_thiện': True,
#    '1000đ': True},
#   'positive'),
#  ({'ký_túc_xá': True,
#    'nằm': True,
#    'vị_trí': True,
#    'trung_tâm': True,
#    'thoáng': True,
#    'mát': True,
#    'tiện_nghi': True,
#    'và': True,
#    'an_ninh': True},
#   'positive'),
#  ({'chất_lượng': True,
#    'giảng_dạy': True,
#    'cao': True,
#    'nhiều': True,
#    'phong_trào': True,
#    'hoạt_động': True,
#    'cho': True,
#    'sinh_viên': True},
#   'positive'),
#  ({'ngôi': True,
#    'trường': True,
#    'rất': True,
#    'đẹp': True,
#    'và': True,
#    'tui': True,
#    'thích': True,
#    'nét': True,
#    'văn_hóa': True,
#    'nơi': True,
#    'này': True},
#   'positive'),
#  ({'một': True,
#    'nơi': True,
#    'đào_tạo': True,
#    'tuyệt_vời': True,
#    'chuyên_ngành': True,
#    'kinh_tế': True,
#    'luật': True,
#    'quản_lý': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'vật_chất': True,
#    'trường': True,
#    'quá': True,
#    'xịn': True,
#    'xò': True,
#    'luôn': True,
#    'nè': True,
#    'tự_hào': True,
#    'là': True,
#    'một': True,
#    'sv': True,
#    'ueh': True},
#   'positive'),
#  ({'trường': True,
#    'mới': True,
#    'khang_trang': True,
#    'yên_tĩnh': True,
#    'nằm': True,
#    'trên': True,
#    'đường': True,
#    'nguyễn': True,
#    'văn': True,
#    'linh': True},
#   'positive'),
#  ({'trường': True,
#    'hàng_đầu': True,
#    'trong': True,
#    'hoạt_động': True,
#    'đào_tạo': True,
#    'lình': True,
#    'vực': True,
#    'kinh_doanh': True},
#   'positive'),
#  ({'học': True,
#    'nữa': True,
#    'mãi': True,
#    'đến': True,
#    'khi': True,
#    'nào': True,
#    'cạn_kiệt': True,
#    'thì_thôi': True},
#   'negative'),
#  ({'thư_viện': True,
#    'cực_kì': True,
#    'xịn': True,
#    'xò': True,
#    'với': True,
#    'cơ_sở': True,
#    'vật_chất': True,
#    'hiện_đại': True,
#    'nè': True,
#    '…': True},
#   'positive'),
#  ({'giá': True,
#    'quá': True,
#    'rẻ': True,
#    'chất_lượng': True,
#    'tương_đối': True,
#    'ổn': True,
#    'một': True,
#    'thời': True,
#    'không_thể': True,
#    'quên': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'khang_trang': True,
#    'nhiều': True,
#    'hoạt_động': True,
#    'ngoại': True,
#    'khóa': True,
#    'cho': True,
#    'sinh_viên': True},
#   'positive'),
#  ({'trường': True,
#    'xịn': True,
#    'chất_lượng': True,
#    'giảng_dạy': True,
#    'tốt': True,
#    'giảng_viên': True,
#    'cute': True},
#   'positive'),
#  ({'rộng_rãi': True,
#    'thoáng': True,
#    'mát': True,
#    'đội_ngũ': True,
#    'nhân_viên': True,
#    'chuyên_nghiệp': True},
#   'positive'),
#  ({'mình': True,
#    'luôn': True,
#    'tự_hào': True,
#    'được': True,
#    'tốt_nghiệp': True,
#    'từ': True,
#    'đại_học': True,
#    'kinh_tế': True,
#    'tphcm': True},
#   'positive'),
#  ({'trường': True,
#    'thì': True,
#    'khỏi': True,
#    'phải': True,
#    'chê': True,
#    'rùi': True,
#    'ạ': True,
#    'csvc': True,
#    'top': True,
#    'đầu': True,
#    'nha': True,
#    'yêu': True,
#    'ueh': True},
#   'positive'),
#  ({'trường': True,
#    'khang_trang': True,
#    'rộng_rãi': True,
#    'khá': True,
#    'ghen_tị': True,
#    'với': True,
#    'sinh_viên': True,
#    'ueh': True},
#   'positive'),
#  ({'thầy': True,
#    'mới': True,
#    'bạn': True,
#    'trường': True,
#    'kiến_thức': True,
#    'tuyệt_vời': True},
#   'positive'),
#  ({'khá': True,
#    'là': True,
#    'xịn': True,
#    'xò': True,
#    'bãi': True,
#    'xe': True,
#    'dưới': True,
#    'hầm': True,
#    'rộng': True,
#    'bảo_vệ': True,
#    'thân_thiện': True},
#   'positive'),
#  ({'quy_mô': True,
#    'lớn': True,
#    'giáo': True,
#    'duc': True,
#    'tốt': True,
#    'hệ_thống': True,
#    'thông_tin': True},
#   'positive'),
#  ({'rất': True,
#    'thích': True,
#    'trường': True,
#    'này': True,
#    'nhưng': True,
#    'đáng': True,
#    'tiếc': True,
#    'thi': True,
#    'không': True,
#    'đậu': True,
#    'huhu': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'vật_chất': True,
#    'hiện_đại': True,
#    'chương_trình': True,
#    'đào_tạo': True,
#    'tiên_tiến': True},
#   'positive'),
#  ({'sinh_viên': True,
#    'trường': True,
#    'ra': True,
#    'đường': True,
#    'đứng': True,
#    'làm': True,
#    'tắc_nghẽn': True,
#    'giao_thông': True},
#   'negative'),
#  ({'quá': True,
#    'khang_trang': True,
#    'hiện_đại': True,
#    'thân_thiện': True,
#    'với': True,
#    'môi_trường': True},
#   'positive'),
#  ({'chất_lượng': True,
#    'đào_tạo': True,
#    'tốt': True,
#    'tự_hào': True,
#    'là': True,
#    'sinh_viên': True,
#    'của': True,
#    'trường': True},
#   'positive'),
#  ({'trụ_sở': True,
#    'chính': True,
#    'nên': True,
#    'có': True,
#    'hội_trường': True,
#    'rất': True,
#    'rộng': True,
#    'cho': True,
#    'sinh_viên': True},
#   'negative'),
#  ({'top': True,
#    '1000': True,
#    'trường': True,
#    'đào_tạo': True,
#    'kinh_doanh': True,
#    'tốt': True,
#    'nhất': True,
#    'thế_giới': True},
#   'positive'),
#  ({'trường': True,
#    'đại_học': True,
#    'hàng_đầu': True,
#    'về': True,
#    'kinh_tế': True,
#    'thương_mại': True,
#    'ở': True,
#    'tphcm': True},
#   'positive'),
#  ({'oktrường': True,
#    'đào_tạo': True,
#    'những': True,
#    'doanh_nhân': True,
#    'thành': True,
#    'đạt042022': True},
#   'positive'),
#  ({'môi_trường': True,
#    'rất': True,
#    'tốt': True,
#    'để': True,
#    'các': True,
#    'bạn': True,
#    'sinh_viên': True,
#    'phát_triển': True},
#   'positive'),
#  ({'đẹp': True,
#    'thoáng': True,
#    'nhưng': True,
#    'tiền': True,
#    'gửi': True,
#    'xe': True,
#    'khá': True,
#    'mắc': True,
#    'hình_như': True,
#    '4k': True},
#   'negative'),
#  ({'một': True,
#    'ngôi': True,
#    'trường': True,
#    'mà': True,
#    'phải': True,
#    'công_nhận': True,
#    'top': True,
#    'đầu': True,
#    'việt_nam': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'này': True,
#    'bé': True,
#    'lại': True,
#    'hay': True,
#    'kẹt': True,
#    'xe': True,
#    'nói_chung': True,
#    'là': True,
#    'khó': True,
#    'đi': True},
#   'negative'),
#  ({'khu_vực': True,
#    'trước': True,
#    'cửa': True,
#    'ktx': True,
#    'khá': True,
#    'lộn_xộn': True,
#    'và': True,
#    'không': True,
#    'an_toàn': True},
#   'negative'),
#  ({'hiện_đại': True,
#    'nhưng': True,
#    'hơi': True,
#    'nóng': True,
#    'tìm': True,
#    'thùng': True,
#    'rác': True,
#    'khó': True},
#   'negative'),
#  ({'cơ_sở': True,
#    'vật_chất': True,
#    'hiện_đại': True,
#    'nhưng': True,
#    'bãi': True,
#    'gửi': True,
#    'xe_hơi': True,
#    'đông': True},
#   'negative'),
#  ({'trường': True,
#    'dạy': True,
#    'về': True,
#    'kinh_tế': True,
#    'khá': True,
#    'nổi_tiếng': True,
#    'của': True,
#    'thành_phố': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'mới': True,
#    'duy_tu_sửa_chữa': True,
#    'đẹp': True,
#    'hơn': True,
#    'sạch_sẽ': True},
#   'positive'),
#  ({'môi_trường_học_thuật': True,
#    'cực': True,
#    'tốt': True,
#    'giảng_viên': True,
#    'uyên_bác': True},
#   'positive'),
#  ({'từng': True,
#    'ở': True,
#    'đây': True,
#    '4': True,
#    'năm': True,
#    'quảng': True,
#    'đời': True,
#    'sv': True,
#    'không_thể_nào': True,
#    'quên': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'mới': True,
#    'xây': True,
#    'trước': True,
#    'mặt': True,
#    'nguyễn': True,
#    'tri': True,
#    'phương': True,
#    'rất': True,
#    'đẹp': True},
#   'positive'),
#  ({'trường': True,
#    'tốt': True,
#    'nhưng': True,
#    'la': True,
#    'ko': True,
#    'biết': True,
#    'có': True,
#    'việc_làm': True},
#   'positive'),
#  ({'hiện': True,
#    'đai': True,
#    'sạch': True,
#    'sẽ': True,
#    'chất_lượng': True,
#    'giáo_dục': True,
#    'tuyệt_vời': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'vật_chất': True,
#    'hiện_đại': True,
#    'chất_lượng': True,
#    'giảng_dạy': True,
#    'tốt': True},
#   'positive'),
#  ({'một': True,
#    'thời': True,
#    'đã': True,
#    'xa': True,
#    '25': True,
#    'năm': True,
#    'vẫn': True,
#    'không': True,
#    'thay_đổi': True,
#    'nhiều': True},
#   'positive'),
#  ({'môi_trường_học_tập': True, 'sạch_sẽ': True, 'đẹp': True, 'thoáng': True},
#   'positive'),
#  ({'trường': True,
#    'đại_học': True,
#    'đào_tạo': True,
#    'kinh_tế': True,
#    'hàng_đầu': True,
#    'việt_nam': True},
#   'positive'),
#  ({'trường': True,
#    'tôi': True,
#    'đã': True,
#    'học': True,
#    'chất_lượng': True,
#    'giảng_dạy': True,
#    'quá': True,
#    'tốt': True},
#   'positive'),
#  ({'thông_minh': True,
#    'hiện_đại': True,
#    'khoa_học': True,
#    'chuyên_nghiệp': True},
#   'positive'),
#  ({'trường': True,
#    'của': True,
#    'mình': True,
#    'giáo_viên': True,
#    'nhiệt_tình': True,
#    'tận_tâm': True},
#   'positive'),
#  ({'không_gian': True,
#    'sạch_sẽ': True,
#    'thoáng_đãng': True,
#    'và': True,
#    'hiền': True,
#    'đai': True},
#   'positive'),
#  ({'học_phí': True,
#    'cao': True,
#    'cơ_sở': True,
#    'vật_chất': True,
#    'đẹp': True,
#    'tốt': True,
#    'rộng_rãi': True},
#   'positive'),
#  ({'trường': True,
#    'rất': True,
#    'đẹp': True,
#    'hiện_đại_tự_hào': True,
#    'là': True,
#    'một': True,
#    'ueher': True},
#   'positive'),
#  ({'khu': True,
#    'tự': True,
#    'học': True,
#    'b2': True,
#    'b1': True,
#    'hiện_đại': True,
#    'sạch_sẽ': True,
#    'rộng_rãi': True},
#   'positive'),
#  ({'trường': True,
#    'cơ_sở': True,
#    'cải_tiến': True,
#    'đẹp': True,
#    'chất_lượng': True,
#    'cao': True},
#   'positive'),
#  ({'trường': True,
#    'lâu_đời': True,
#    'nhiều': True,
#    'sinh_viên': True,
#    'trong': True,
#    'ngành': True},
#   'positive'),
#  ({'trường': True,
#    'đại_học': True,
#    'tốt': True,
#    'địa_chỉ': True,
#    'gần': True,
#    'hồ': True,
#    'con': True,
#    'rùa': True},
#   'positive'),
#  ({'không_gian': True,
#    'thoáng_đãng': True,
#    'thích_hợp': True,
#    'học_tập': True},
#   'positive'),
#  ({'môi_trường': True,
#    'tuyệt_vời': True,
#    'phòng': True,
#    'học': True,
#    'hiện_đại': True},
#   'positive'),
#  ({'thích': True,
#    'và': True,
#    'hứa_hẹn': True,
#    'sẽ': True,
#    'thi': True,
#    'đỗ': True,
#    'vào': True,
#    'trường': True,
#    'này': True},
#   'positive'),
#  ({'đào_tạo': True,
#    'oke': True,
#    'mà': True,
#    'đông': True,
#    'sinh_viên': True,
#    'trong': True,
#    '1': True,
#    'lớp': True},
#   'negative'),
#  ({'trường': True,
#    'rất': True,
#    'đẹp': True,
#    'ngày': True,
#    'nào': True,
#    'cũng': True,
#    'chạy': True,
#    'ngang': True},
#   'positive'),
#  ({'trường': True,
#    'đào_tạo': True,
#    'tốt': True,
#    'nhiều': True,
#    'chứng_chỉ': True,
#    'có_ích': True},
#   'positive'),
#  ({'cố_gắng': True,
#    'học': True,
#    'tốt': True,
#    'nhái': True,
#    'love': True,
#    'my': True,
#    'school3': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'hạ_tầng': True,
#    'mới': True,
#    'sang_trọng': True,
#    'rộng_rãi': True},
#   'positive'),
#  ({'trường': True,
#    'này': True,
#    'buỗi': True,
#    'tối': True,
#    'bị': True,
#    'quán': True,
#    'nhậu': True,
#    'vây': True,
#    'kín': True},
#   'negative'),
#  ({'chất_lượng': True,
#    'giảng_dạy': True,
#    'hàng': True,
#    'đầutuyệt': True,
#    'vời': True},
#   'positive'),
#  ({'nhân_viên': True,
#    'giữ': True,
#    'xe': True,
#    'cơ_sở': True,
#    'vật_chất': True,
#    'khá': True,
#    'tệ': True},
#   'negative'),
#  ({'ueh': True,
#    'môi_trường': True,
#    'năng_động': True,
#    'cho': True,
#    'sinh_viên': True},
#   'positive'),
#  ({'nơi': True,
#    'đào_tạo': True,
#    'kinh_tế': True,
#    'uy_tín': True,
#    'và': True,
#    'chất_lượng': True},
#   'positive'),
#  ({'trường': True,
#    'mới': True,
#    'đẹp': True,
#    'và': True,
#    'nhiều': True,
#    'ct': True,
#    'hay': True,
#    'hữu_ích': True},
#   'positive'),
#  ({'sinh_viên': True,
#    'rất': True,
#    'ý_thức': True,
#    'không': True,
#    'nghẽn': True,
#    'đường': True},
#   'positive'),
#  ({'ktx': True,
#    'gần': True,
#    'trung_tâm': True,
#    'mà': True,
#    'phòng_ốc': True,
#    'tốt': True,
#    'nhất': True},
#   'positive'),
#  ({'lúc': True,
#    'này': True,
#    'gọn_gàng': True,
#    'sạch_sẽ': True,
#    'hơn': True,
#    'nhiều': True,
#    'rồi': True},
#   'positive'),
#  ({'trường': True,
#    'rất': True,
#    'đẹp': True,
#    'và': True,
#    'hiện_đại': True,
#    'bên': True,
#    'trong': True},
#   'positive'),
#  ({'đại_học': True,
#    'tốt': True,
#    'nhất': True,
#    'miền': True,
#    'nam': True,
#    'love': True,
#    'it': True},
#   'positive'),
#  ({'đại_học': True,
#    'nổi_tiếng': True,
#    'tại': True,
#    'tp': True,
#    'hồ': True,
#    'chí': True,
#    'minh': True},
#   'positive'),
#  ({'tuyệt_vời': True,
#    'ngôi': True,
#    'trường': True,
#    'tầm_cỡ': True,
#    'quốc': True,
#    'tê': True},
#   'positive'),
#  ({'trường': True,
#    'quá': True,
#    'xịn': True,
#    'xò': True,
#    'lun': True,
#    'chất_lượng': True,
#    '10': True,
#    '₫': True},
#   'positive'),
#  ({'xịn': True,
#    'xò': True,
#    'thậc': True,
#    'sự': True,
#    'nhưng': True,
#    'ghéc': True,
#    'trường': True,
#    '…': True},
#   'negative'),
#  ({'quanh': True,
#    'khu_vực': True,
#    'này': True,
#    'vẫn': True,
#    'hơi': True,
#    'mất': True,
#    'an_ninh': True},
#   'negative'),
#  ({'uy_tín': True,
#    'chất_lượng': True,
#    'lơn': True,
#    'nhất': True,
#    'miền': True,
#    'nam': True},
#   'positive'),
#  ({'good': True,
#    'đây': True,
#    'là': True,
#    'cơ_sở': True,
#    'lâu_đời': True,
#    'nên': True,
#    'khá': True,
#    'cũ': True},
#   'positive'),
#  ({'ngôi': True,
#    'trường': True,
#    'rất': True,
#    'đẹp': True,
#    'và': True,
#    'nhiều': True,
#    'cây_xanh': True},
#   'positive'),
#  ({'trường': True,
#    'đang': True,
#    'xây': True,
#    'lại': True,
#    'chắc': True,
#    'sẽ': True,
#    'đẹp': True,
#    'lắm': True},
#   'positive'),
#  ({'sao': True, 'thấy': True, 'toàn': True, 'dây_điện': True, 'gớm_vậy': True},
#   'negative'),
#  ({'các': True,
#    'bạn': True,
#    'sinh_viên': True,
#    'rất': True,
#    'tuyệt_vời': True},
#   'positive'),
#  ({'công_viên': True, 'văn_minh': True, 'học_viên': True, 'lịch_sự': True},
#   'positive'),
#  ({'trường': True, 'đào_tạo': True, 'chất_lượng': True, 'nổi_tiếng': True},
#   'positive'),
#  ({'tuyệt_vời': True, 'cơ_sở': True, 'vật_chất': True, 'hiện_đại': True},
#   'positive'),
#  ({'vị_trí': True,
#    'siêu': True,
#    'đẹp': True,
#    'mình': True,
#    'học': True,
#    'đây': True,
#    'ra': True,
#    'mà': True},
#   'positive'),
#  ({'con': True,
#    'mình': True,
#    'học': True,
#    'ở': True,
#    'đây': True,
#    'trường': True,
#    'dạy': True,
#    'tôt': True},
#   'positive'),
#  ({'thương_hiệu': True,
#    'đào_tạo': True,
#    'tại': True,
#    'phía': True,
#    'nam': True},
#   'positive'),
#  ({'trường': True,
#    'xây': True,
#    'mới': True,
#    'rất': True,
#    'đẹp': True,
#    'và': True,
#    'hiện_đại': True},
#   'positive'),
#  ({'sức': True,
#    'chứa': True,
#    'hội_trường': True,
#    'lớn': True,
#    '500': True,
#    'người': True},
#   'positive'),
#  ({'một': True,
#    'cơ_sở': True,
#    'đẹp': True,
#    'phong_cách': True,
#    'hiện_đại': True},
#   'positive'),
#  ({'trường': True,
#    'khá': True,
#    'tốt': True,
#    'nhưng': True,
#    'hơi': True,
#    'bất_cập': True},
#   'negative'),
#  ({'đào_tạo': True, 'sinh_viên': True, 'chất_lượng': True, 'cao': True},
#   'positive'),
#  ({'trường': True,
#    'mình': True,
#    'v': True,
#    'hong': True,
#    'dám': True,
#    'chê': True,
#    'hahaa': True},
#   'positive'),
#  ({'thích': True,
#    'vô': True,
#    'trường': True,
#    'này': True,
#    'học': True,
#    'quá': True},
#   'positive'),
#  ({'ngôi': True, 'trường': True, 'thân_yêu': True, 'tuyệt_vời': True},
#   'positive'),
#  ({'thích_hợp': True,
#    'cho': True,
#    'các': True,
#    'bạn': True,
#    'trong': True,
#    'nam': True},
#   'positive'),
#  ({'trường': True, 'đạo': True, 'tạo': True, 'chất_lượng': True, 'tốt': True},
#   'positive'),
#  ({'đẹp': True, 'trải': True, 'nghiệm': True, 'tốt': True, 'thoải_mái': True},
#   'positive'),
#  ({'trường': True,
#    'đào_tạo': True,
#    'tốt': True,
#    'chuẩn': True,
#    '5': True,
#    'sao': True},
#   'positive'),
#  ({'giáo_viên': True, 'nhiều': True, 'kinh_nghiệm': True}, 'positive'),
#  ({'đại_học': True, 'hàng_đầu': True, 'vn': True, 'về': True, 'kinh_tế': True},
#   'positive'),
#  ({'phòng': True,
#    'rẻ': True,
#    'nhưng': True,
#    'k': True,
#    'có': True,
#    'thang_máy': True},
#   'negative'),
#  ({'đẹp': True,
#    'rộng': True,
#    'mà': True,
#    'hơi': True,
#    'xa': True,
#    'trung_tâm': True},
#   'positive'),
#  ({'môi_trường': True, 'tốt': True, 'để': True, 'học_tập': True, '…': True},
#   'positive'),
#  ({'nắng': True, 'cực': True, 'xa_xôi': True, 'lắm': True, 'picachu': True},
#   'negative'),
#  ({'trường': True, 'đẹpcơ': True, 'sở': True, 'vật_chất': True, 'tốt': True},
#   'positive'),
#  ({'xịn': True,
#    'quá': True,
#    'nhìn': True,
#    'phát': True,
#    'mê': True,
#    'luôn': True,
#    '…': True},
#   'positive'),
#  ({'cơ_sở': True, 'vật_chất': True, 'vô_cùng': True, 'xịn': True, 'xò': True},
#   'positive'),
#  ({'cơ_sở': True, 'trang': True, 'thiết_bị': True, 'tân_tiến': True},
#   'positive'),
#  ({'thêm': True,
#    '1': True,
#    'đánh_giá': True,
#    'tốt': True,
#    'cho': True,
#    'ueh': True},
#   'positive'),
#  ({'khang_trang': True, 'dễ': True, 'tìm': True, 'địa_chỉ': True}, 'positive'),
#  ({'căn': True, 'tin': True, 'là': True, 'tuyệt_vời': True, 'nhất': True},
#   'positive'),
#  ({'nice': True, 'place': True, 'for': True, 'students': True, '…': True},
#   'positive'),
#  ({'hiện_đại_tiện_nghi': True, 'sạch_sẽ': True}, 'positive'),
#  ({'khuôn_viên': True, 'trường': True, 'đẹp': True, '3': True}, 'positive'),
#  ({'rộng': True, 'rãirất': True, 'đẹp': True, 'và': True, 'sạch_sẽ': True},
#   'positive'),
#  ({'môi_trường_học_tập': True, 'lý_tưởng': True}, 'positive'),
#  ({'em': True,
#    '2k1': True,
#    'rất': True,
#    'yêu': True,
#    'thích': True,
#    'trường': True},
#   'positive'),
#  ({'ở': True, 'đây': True, 'đi_lại': True, 'rất': True, 'thuận_tiện': True},
#   'positive'),
#  ({'ueh': True, 'cơ_sở': True, 'b': True, 'chất_lượng': True, 'nhất': True},
#   'positive'),
#  ({'nơi': True, 'đào_tạo': True, 'chất_lượng': True, 'cao': True}, 'positive'),
#  ({'trường': True, 'mình': True, 'học': True, 'tuyệt_vời': True}, 'positive'),
#  ({'chưa': True, 'thấy': True, 'công_trình': True, 'nào': True}, 'negative'),
#  ({'cơ_sở': True, 'mới': True, 'xây': True, 'đẹp': True, 'hiện_đại': True},
#   'positive'),
#  ({'trường': True, 'bây_giờ': True, 'rất': True, 'đẹp': True}, 'positive'),
#  ({'cơ_sở': True, 'đào_tạo': True, 'giáo_dục': True, 'tốt': True}, 'positive'),
#  ({'đào_tạo': True, 'các': True, 'ngành': True, 'kế_toán': True}, 'positive'),
#  ({'chất_lượng': True, 'giảng_dạy': True, 'tốt': True}, 'positive'),
#  ({'trường': True, 'đại_học': True, 'nổi_tiếng': True}, 'positive'),
#  ({'sạch': True, 'đẹp': True, 'hơn': True, 'xưa': True, 'nhiều': True},
#   'positive'),
#  ({'nhà_xe': True, 'lúc_nào': True, 'cũng': True, 'chật': True}, 'negative'),
#  ({'hiện_nay': True, 'đã': True, 'cũ': True, 'hơn': True, 'nhiều': True},
#   'negative'),
#  ({'trường': True, 'thiếu': True, 'chỗ': True, 'gửi': True, 'xe': True},
#   'negative'),
#  ({'vị_trí': True,
#    'đẹp': True,
#    'ko': True,
#    'có': True,
#    'bãi': True,
#    'xe': True},
#   'positive'),
#  ({'địa_điểm_chuẩn': True, '5': True, 'sao': True}, 'positive'),
#  ({'đẹp': True, 'rộng_rãi': True, 'sang_trọng': True}, 'positive'),
#  ({'ngày_càng': True, 'chuyên_nghiệp': True}, 'positive'),
#  ({'cơ_sở': True, 'xịn': True, 'xog': True, 'tuyệt_vời': True}, 'positive'),
#  ({'cơ_sở': True, 'vật_chất': True, 'hiện_đại': True}, 'positive'),
#  ({'trường': True, 'khá': True, 'đẹp': True, 'rộng_rãi': True}, 'positive'),
#  ({'trường': True, 'rộng': True, 'thoáng': True, 'mát': True}, 'positive'),
#  ({'rất': True, 'vui': True, 'sinh_viên': True}, 'positive'),
#  ({'rất': True, 'đẹp': True, 'trường': True, 'xịn': True, 'xò': True},
#   'positive'),
#  ({'tuyệt_vời': True, 'ông': True, 'mặt_trời': True}, 'positive'),
#  ({'đào_tạo': True, 'chất_lượng': True, 'cao': True}, 'positive'),
#  ({'trường': True, 'dạy': True, 'rất': True, 'tốt': True}, 'positive'),
#  ({'trường': True, 'đào_tạo': True, 'uy_tín': True}, 'positive'),
#  ({'cơ_sở': True, 'vật_chất': True, 'xịn': True, 'xò': True}, 'positive'),
#  ({'phù_hợp': True, 'cho': True, 'sinh_viên': True}, 'positive'),
#  ({'nhìn': True, 'bên': True, 'ngoài': True, 'thích': True}, 'positive'),
#  ({'sạch_sẽ': True, 'và': True, 'thoáng': True, 'mát': True}, 'positive'),
#  ({'khu': True, 'tự': True, 'học': True, 'tuyệt_vời': True}, 'positive'),
#  ({'kiến_trúc': True, 'cổ': True, 'rất': True, 'đẹp': True}, 'positive'),
#  ({'khá': True, 'rộng': True, 'và': True, 'sạch': True, 'đẹp': True},
#   'positive'),
#  ({'ở': True, 'đây': True, 'tuyệt_vời': True, 'lắm': True}, 'positive'),
#  ({'khuôn_viên': True, 'sạch': True, 'đẹp': True}, 'positive'),
#  ({'trường': True, 'top': True, 'đầu': True, 'tphcm': True}, 'positive'),
#  ({'cơ_sở': True, 'chật': True, 'kẹt': True, 'xe': True}, 'negative'),
#  ({'khuôn_viên': True, 'hơi': True, 'chật': True}, 'negative'),
#  ({'hiện_đại_tiện_nghi': True}, 'positive'),
#  ({'một': True, 'ngôi': True, 'trường': True, 'tốt': True}, 'positive'),
#  ({'mới': True, 'sửa': True, 'lại': True, 'rất': True, 'đẹp': True},
#   'positive'),
#  ({'cơ_sở': True, 'vật_chất': True, 'tốt': True}, 'positive'),
#  ({'ancient': True, 'university': True}, 'positive'),
#  ({'sạch_sẽ': True, 'thoáng': True, 'mát': True}, 'positive'),
#  ({'mái': True, 'trường': True, 'mến_yêu': True}, 'positive'),
#  ({'thuc': True, 'an': True, 'ngon': True, 'bổ': True, 'rẻ': True},
#   'positive'),
#  ({'cơ_sở': True, 'mới': True, 'rất': True, 'rộng': True}, 'positive'),
#  ({'trường': True, 'kinh_tế': True, 'tốt': True}, 'positive'),
#  ({'trường': True, 'khá': True, 'cũ': True, 'rồi': True}, 'negative'),
#  ({'cơ_sở': True, 'vật_chất': True, 'tốt': True}, 'positive'),
#  ({'nhieu': True, 'ki': True, 'niem': True, 'dep': True}, 'positive'),
#  ({'thuận_tiện': True, 'đi_lại': True}, 'positive'),
#  ({'thật_sự': True, 'là': True, 'vui_vẻ': True}, 'positive'),
#  ({'ký_túc_xá': True, 'rất': True, 'cũ': True}, 'negative'),
#  ({'đẹp': True, 'thân_thiện': True}, 'positive'),
#  ({'trường_học': True, 'tốt': True}, 'positive'),
#  ({'sạch_sẽ': True, 'thơm_tho': True}, 'positive'),
#  ({'tốt': True, 'khỏi': True, 'bàn': True, 'rồi': True}, 'positive'),
#  ({'đầy': True, 'để': True, 'tiện_nghi': True}, 'positive'),
#  ({'quá': True, 'đẹp': True, '212022': True}, 'positive'),
#  ({'tốt': True, 'cho': True, 'giới': True, 'trẻ': True}, 'positive'),
#  ({'trường': True, 'mình': True, 'xịnn': True}, 'positive'),
#  ({'great': True, 'university': True}, 'positive'),
#  ({'wa': True, 'tuyet': True, 'i': True, 'will': True}, 'positive'),
#  ({'trường': True, 'cổ_kính': True}, 'positive'),
#  ({'nice': True, 'university': True}, 'positive'),
#  ({'rộng': True, 'thoáng': True, 'mát': True}, 'positive'),
#  ({'nice': True, 'university': True}, 'positive'),
#  ({'thật': True, 'tuyệt_vời': True}, 'positive'),
#  ({'ueh': True, 'tuyệt_vời': True}, 'positive'),
#  ({'dạy': True, 'tốt': True, 'học': True}, 'positive'),
#  ({'thư_viện': True, 'proooo': True}, 'positive'),
#  ({'best': True, 'university': True}, 'positive'),
#  ({'ko': True, 'như': True, 'mong_đợi': True}, 'negative'),
#  ({'trường': True, 'tui': True, 'học': True}, 'positive'),
#  ({'trường': True, 'rất': True, 'tốt': True}, 'positive'),
#  ({'chổ': True, 'này': True, 'dễ': True, 'tìm': True}, 'positive'),
#  ({'chật': True, 'hơi': True, 'bẩn': True}, 'negative'),
#  ({'trường': True, 'quá': True, 'xịn': True}, 'positive'),
#  ({'siêuuuu': True, 'vipppp': True}, 'positive'),
#  ({'chất_lượng': True, 'tốt': True}, 'positive'),
#  ({'trường': True, 'rất': True, 'đẹp': True}, 'positive'),
#  ({'sang': True, 'xịn': True, 'mịn': True}, 'positive'),
#  ({'chuyên_nghiệp': True}, 'positive'),
#  ({'cơ_sở': True, 'này': True, 'đẹp': True}, 'positive'),
#  ({'đẹp': True, 'sạch_sẽ': True}, 'positive'),
#  ({'rất': True, 'tuyệt_vời': True}, 'positive'),
#  ({'sạch': True, 'và': True, 'sang': True}, 'positive'),
#  ({'dung': True, 'dia': True, 'diem': True}, 'positive'),
#  ({'đào_tạo': True, 'chuẩn': True}, 'positive'),
#  ({'rất': True, 'là': True, 'ok': True, 'nha': True}, 'positive'),
#  ({'hơi': True, 'lộn_xộn': True}, 'negative'),
#  ({'đúng': True, 'địa_điểm': True}, 'positive'),
#  ({'cũng': True, 'tam_nha': True}, 'negative'),
#  ({'trường': True, 'chuẩn': True}, 'positive'),
#  ({'vật_chất': True, 'tốt': True}, 'positive'),
#  ({'quá': True, 'là': True, 'okeee': True}, 'positive'),
#  ({'rất': True, 'hài_lòng': True}, 'positive'),
#  ({'sang': True, 'xịn': True, 'mịn': True}, 'positive'),
#  ({'chấp_nhận': True, 'dc': True}, 'positive'),
#  ({'dung': True, 'vi': True, 'tri': True}, 'positive'),
#  ({'ueh': True, '10': True, 'điểm': True}, 'positive'),
#  ({'đào_tạo': True, 'tốt': True}, 'positive'),
#  ({'đào_tạo': True, 'tốt': True}, 'positive'),
#  ({'rất': True, 'sạch_sẽ': True}, 'positive'),
#  ({'nơi': True, 'nên': True, 'đến': True}, 'positive'),
#  ({'trường': True, 'đẹp': True}, 'positive'),
#  ({'tuyệt': True, 'vờiii': True}, 'positive'),
#  ({'dịch_vụ': True, 'tốt': True}, 'positive'),
#  ({'đào_tạo': True, 'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'trường': True, 'đẹp': True}, 'positive'),
#  ({'trường': True, 'đẹp': True}, 'positive'),
#  ({'truong': True, 'dep': True}, 'positive'),
#  ({'thoáng': True, 'mát': True}, 'positive'),
#  ({'trường': True, 'tốt': True}, 'positive'),
#  ({'sạch_sẽ': True}, 'positive'),
#  ({'trường': True, 'đẹp': True}, 'positive'),
#  ({'trường': True, 'mới': True}, 'positive'),
#  ({'trường': True, 'tốt': True}, 'positive'),
#  ({'trường': True, 'tốt': True}, 'positive'),
#  ({'khoáng_mát': True}, 'positive'),
#  ({'trường': True, 'tốt': True}, 'positive'),
#  ({'trường': True, 'top': True}, 'positive'),
#  ({'big': True, 'campus': True}, 'positive'),
#  ({'green': True, 'vibe': True}, 'positive'),
#  ({'đẹp': True, 'rộng': True}, 'positive'),
#  ({'tuyệt_vời': True}, 'positive'),
#  ({'excellent': True}, 'positive'),
#  ({'tuyệt_vời': True}, 'positive'),
#  ({'chính_xác': True}, 'positive'),
#  ({'tuyệt_vời': True}, 'positive'),
#  ({'tuyệt_dời': True}, 'positive'),
#  ({'tiện_nghi': True}, 'positive'),
#  ({'wonderful': True}, 'positive'),
#  ({'tuyet': True, 'voi': True}, 'positive'),
#  ({'rất': True, 'tuyệt': True}, 'positive'),
#  ({'tạm': True, 'thôi': True}, 'negative'),
#  ({'hài_lòng': True}, 'positive'),
#  ({'xuất_sắc': True}, 'positive'),
#  ({'được': True, 'đẹp': True}, 'positive'),
#  ({'khá': True, 'đẹp': True}, 'positive'),
#  ({'dạy': True, 'tốt': True}, 'positive'),
#  ({'rất': True, 'tốt': True}, 'positive'),
#  ({'ok': True, 'good': True}, 'positive'),
#  ({'rất': True, 'đẹp': True}, 'positive'),
#  ({'khá': True, 'tốt': True}, 'positive'),
#  ({'rất': True, 'tốt': True}, 'positive'),
#  ({'an_ninh': True}, 'positive'),
#  ({'rất': True, 'tốt': True}, 'positive'),
#  ({'csvc': True, 'cũ': True}, 'negative'),
#  ({'rất': True, 'tốt': True}, 'positive'),
#  ({'xịn': True}, 'positive'),
#  ({'đẹp': True, 'ghê': True}, 'positive'),
#  ({'rất': True, 'ok': True}, 'positive'),
#  ({'khá': True, 'ổn': True}, 'positive'),
#  ({'tuyệt': True}, 'positive'),
#  ({'chuẩn': True}, 'positive'),
#  ({'tuyệt': True}, 'positive'),
#  ({'thích': True}, 'positive'),
#  ({'tuyệt': True}, 'positive'),
#  ({'được': True}, 'positive'),
#  ({'cx': True, 'đc': True}, 'positive'),
#  ({'tuyệt': True}, 'positive'),
#  ({'chuẩn': True}, 'positive'),
#  ({'tụyt': True}, 'positive'),
#  ({'giỏi': True}, 'positive'),
#  ({'được': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'hay': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'god': True}, 'negative'),
#  ({'đẹp': True}, 'positive'),
#  ({'đẹp': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tạm': True}, 'negative'),
#  ({'tốt': True}, 'positive'),
#  ({'…': True}, 'negative'),
#  ({'đẹp': True}, 'positive'),
#  ({'đẹp': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'đẹp': True}, 'positive'),
#  ({'…': True}, 'positive'),
#  ({'xịn': True}, 'positive'),
#  ({'đẹp': True}, 'positive'),
#  ({'đẹp': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'đẹp': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'đẹp': True}, 'positive'),
#  ({'đẹp': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'nơi': True,
#    'đào_tạo': True,
#    'uy_tín': True,
#    'chất_lượng': True,
#    'tốt': True,
#    'đã': True,
#    'được': True,
#    'khẳng_định': True,
#    'với': True,
#    'các': True,
#    'ngành': True,
#    'về': True,
#    'kinh_tế': True,
#    'của': True,
#    'miền': True,
#    'nam': True},
#   'positive'),
#  ({'nơi': True, 'đáng': True, 'sống': True}, 'positive'),
#  ({'đại_học': True, 'tui': True, 'mà': True}, 'positive'),
#  ({'rất': True, 'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'tốt': True}, 'positive'),
#  ({'sạch_sẽ': True}, 'positive'),
#  ({'xấu': True}, 'negative'),
#  ({'đhkt': True,
#    'tphồ': True,
#    'chí': True,
#    'minh': True,
#    'là': True,
#    'cơ_sở': True,
#    'đào_tạo': True,
#    'đại_học': True,
#    'và': True,
#    'sau': True,
#    'các': True,
#    'ngành': True,
#    'về': True,
#    'kinh_tế': True,
#    'hàng_đầu': True,
#    'của': True,
#    'vn': True,
#    'nơi': True,
#    'đây': True,
#    'có': True,
#    'đội_ngũ': True,
#    'giao': True,
#    'sư': True,
#    'chuyên_môn': True,
#    'cao': True,
#    'giáo_trình': True,
#    'liên_tục': True,
#    'cập_nhật': True,
#    'quan_hệ': True,
#    'tốt': True,
#    'với': True,
#    'trường': True,
#    'tổ_chức': True,
#    'quốc_tế': True,
#    'đã': True,
#    'đạo': True,
#    'tạo': True,
#    'rất': True,
#    'nhiều': True,
#    'nhân_sự': True,
#    'trình_độ': True,
#    'cho': True,
#    'nền': True,
#    'quốc': True,
#    'giatuy': True,
#    'nhiên': True,
#    'vật_chất': True,
#    'manh_mún': True,
#    'nhỏ_lẻ': True,
#    'cũ_kỹ': True,
#    'không': True,
#    'tương_xứng': True,
#    'tầm_vóc': True,
#    'giá_trị': True,
#    'nó': True,
#    'mang': True,
#    'lại': True},
#   'negative'),
#  ({'xanh': True, 'sạch': True, 'đẹp': True}, 'positive'),
#  ({'là': True,
#    'ký_túc_xá': True,
#    'khá': True,
#    'lâu_đời': True,
#    'của': True,
#    'sinh_viên': True,
#    'trường': True,
#    'đại_học': True,
#    'kinh_tế': True,
#    'tp': True,
#    'hồ': True,
#    'chí': True,
#    'minh': True,
#    'khoảng_cách': True,
#    'từ': True,
#    'đến': True,
#    'gần': True,
#    'có_thể': True,
#    'đi': True,
#    'bộ': True,
#    'sau': True,
#    'một': True,
#    'thời_gian': True,
#    'xuống_cấp': True,
#    'đã': True,
#    'được': True,
#    'cải_tạo': True,
#    'phần': True,
#    'tuy_nhiên': True,
#    'khu_vực': True,
#    'chung': True,
#    'quang': True,
#    'phức_tạp': True,
#    'gái': True,
#    'ngành': True,
#    'hoạt_động': True,
#    'ầm_ầm': True,
#    'thậm_chí': True,
#    'mở': True,
#    'căn': True,
#    'tin': True,
#    'ngay': True,
#    'mặt': True,
#    'tiền_đường': True,
#    'nguyễn': True,
#    'thanh': True,
#    'nên': True,
#    'không': True,
#    'tránh': True,
#    'khỏi': True,
#    'các': True,
#    'thành_phần': True,
#    'khác': True,
#    'nhau': True,
#    'trong': True,
#    'xã_hội': True,
#    'tụ_tập': True,
#    'này': True},
#   'negative'),
#  ({'một': True,
#    'môi_trường': True,
#    'quá': True,
#    'hoàn_hảo': True,
#    'cho': True,
#    'việc': True,
#    'trau_dồi': True,
#    'kiến_thức': True,
#    'giúp_ích': True,
#    'bản_thân': True,
#    'và': True,
#    'xã_hội': True,
#    'sau_này': True},
#   'positive'),
#  ({'ktx': True,
#    'xanh': True,
#    'sạch': True,
#    'đẹp': True,
#    'quá': True,
#    'iii': True,
#    'thui': True},
#   'positive'),
#  ({'rất': True,
#    'yên': True,
#    'tĩnhcực': True,
#    'kì': True,
#    'an_ninh': True,
#    'thoáng': True,
#    'mát': True,
#    'rộng_rãi': True,
#    'nhân_viên': True,
#    'dễ_thương': True,
#    'ân_cần': True,
#    'chu_đáo': True,
#    'hỗ_trợ': True,
#    'tư_vấn': True,
#    'chuyên_nghiệp': True,
#    'phòng': True,
#    'sạch_sẽ': True,
#    'gọn_gàng': True,
#    'giá_cả': True,
#    'hợp_lý': True,
#    'có': True,
#    'bãi': True,
#    'xe_hơi': True,
#    'xe_máy': True},
#   'positive'),
#  ({'truong': True, 'dai': True, 'hoc': True}, 'negative'),
#  ({'trường': True,
#    'không': True,
#    'rõ_ràng': True,
#    'khi': True,
#    'đăng': True,
#    'thông_tin': True,
#    'tuyển_dụng': True,
#    'của': True,
#    'vb2đhcq': True,
#    'trong': True,
#    'nêu': True,
#    'thời_gian': True,
#    'học': True,
#    'các': True,
#    'buổi': True,
#    'tối': True,
#    'từ': True,
#    '246': True,
#    'hoặc': True,
#    '357': True,
#    'tuy_nhiên': True,
#    'rõ': True,
#    'sẽ': True,
#    'chung': True,
#    'với': True,
#    'chính_quy': True,
#    'vào': True,
#    'ban_ngày': True,
#    'đủ': True,
#    'số_lượng': True,
#    'đã': True,
#    'chọn': True,
#    'vb2': True,
#    'phần_lớn': True,
#    'đều': True,
#    'là': True,
#    'người': True,
#    'đi': True,
#    'làm': True,
#    'nhưng': True,
#    'lịch': True,
#    'thì': True,
#    'sao': True,
#    'tham_gia': True,
#    'được': True,
#    'đến': True,
#    'kì': True,
#    'thứ': True,
#    '3': True,
#    'thời': True,
#    'khóa': True,
#    'biểu': True,
#    'xếp': True,
#    'có': True,
#    'phải': True,
#    'bỏ': True,
#    'con': True,
#    'giữa': True,
#    'chợ': True,
#    'đề_cập': True,
#    'ngay': True,
#    'đầu': True,
#    'gì': True,
#    'ai': True,
#    'đăng_ký': True,
#    'xét': True,
#    'tuyển': True,
#    'nữa': True,
#    'đợi': True,
#    'hết': True,
#    '2': True,
#    'rồi': True,
#    'mới': True,
#    'nói': True,
#    'thông_báo': True,
#    'rộng_rãi': True,
#    'đúng': True,
#    'lừa_đảo': True,
#    'mà': True},
#   'negative'),
#  ({'yêu': True, 'thích': True}, 'positive'),
#  ({'cơ_sở': True, 'tốt': True}, 'positive'),
#  ({'trường': True, 'đẹp': True}, 'positive'),
#  ({'đỉnh': True, 'của': True}, 'positive'),
#  ({'place': True, 'not': True, 'dep': True}, 'negative'),
#  ({'trường': True,
#    'đại_học': True,
#    'kinh_tế': True,
#    'thành_phố': True,
#    'hồ': True,
#    'chí': True,
#    'minh': True,
#    'tiếng': True,
#    'anh': True,
#    'university': True,
#    'of': True,
#    'economics': True,
#    'ho': True,
#    'chi': True,
#    'city': True,
#    'hiện_nay': True,
#    'cơ_sở': True,
#    'vật_chất': True,
#    'của': True,
#    'hiện_đại_hội_trường': True,
#    'rộng': True,
#    'nhiều': True,
#    'chỗ': True,
#    'ngồi': True,
#    'là': True,
#    'nơi': True,
#    'tổ_chức': True,
#    'buổi': True,
#    'lễ': True,
#    'cũng': True,
#    'như': True,
#    'hoạt_động': True,
#    'sinh_viên': True,
#    'và': True,
#    'nhà': True,
#    'trườngngoài': True,
#    'ra': True,
#    'còn': True,
#    'có': True,
#    'hệ_thống': True,
#    'máy_lạnh': True,
#    'đền': True,
#    'chiếu': True,
#    'sáng': True,
#    'đáp_ứng': True,
#    'nhu_cầu': True,
#    'đa_dạng': True,
#    'giáo_viên': True,
#    'tại': True,
#    'hội_trường': True,
#    'chính': True,
#    'khu': True,
#    'tiếp': True,
#    'khách': True,
#    'riêng': True,
#    'sảnh': True,
#    'chờ': True,
#    'rộng_lớn': True},
#   'positive'),
#  ({'bảo_vệ': True, 'thân_thiện': True, 'vui_vẻ': True}, 'positive'),
#  ({'top': True,
#    'những': True,
#    'điều': True,
#    'nên': True,
#    'làm': True,
#    'khi': True,
#    'học': True,
#    'đại_học': True,
#    'kinh_tế': True,
#    '01': True,
#    'ở': True,
#    'ktx': True},
#   'positive'),
#  ({'bãi': True, 'xe_hơi': True, 'nhỏ': True, 'phòng': True, 'học': True},
#   'negative'),
#  ({'xinh_xắn': True, 'sạch_sẽ': True, 'xịn': True, 'xò': True}, 'positive'),
#  ({'ngoi': True, 'truong': True, 'hang': True, 'mo': True, 'uoc': True},
#   'positive'),
#  ({'trường': True,
#    'nhìn': True,
#    'cũng': True,
#    'khá': True,
#    'là': True,
#    'đẹp': True},
#   'positive'),
#  ({'cơ_sở': True,
#    'này': True,
#    'thật_sự': True,
#    'khá': True,
#    'rộng': True,
#    'so': True,
#    'với': True,
#    'các': True,
#    'khác': True,
#    'thuộc': True,
#    'ueh': True,
#    'tòa': True,
#    'nhà': True,
#    'rất': True,
#    'cao': True,
#    'thư_viện': True,
#    'thông_minh': True,
#    'chứa': True,
#    'đa_số': True,
#    'sách': True,
#    'và': True,
#    'tài_liệu': True,
#    'của': True,
#    'sân': True,
#    'trường': True,
#    'là': True,
#    'một': True,
#    'nơi': True,
#    'vô_cùng': True,
#    'phù_hợp': True,
#    'để': True,
#    'tổ_chức': True,
#    'lễ_hội': True,
#    'chương_trình': True,
#    'ngoài_ra': True,
#    'thì': True,
#    'trên': True,
#    'còn': True,
#    'được': True,
#    'gắn': True,
#    'đèn': True,
#    'led': True,
#    'phát': True,
#    'sáng': True,
#    'vào': True,
#    'buổi': True,
#    'tối': True},
#   'positive'),
#  ({'tô': True, 'phở': True, 'to': True, 'vị': True, 'vừa': True, 'ăn': True},
#   'positive'),
#  ({'trường': True,
#    'đại_học': True,
#    'kinh_tế': True,
#    'tp': True,
#    'hồ': True,
#    'chí': True,
#    'minh': True,
#    'số': True,
#    '59c': True,
#    'nguyễn': True,
#    'đình': True,
#    'chiểu': True,
#    'là': True,
#    'trong': True,
#    'top': True,
#    'công_danh_tiếng': True,
#    'của': True,
#    'việt': True,
#    'nam': True,
#    'tọa_lạc': True,
#    'tại': True,
#    'quận': True,
#    '3': True,
#    'trung_tâm': True,
#    'với': True,
#    'đội_ngũ': True,
#    'giảng_viên': True,
#    'uy_tín': True,
#    'và': True,
#    'giàu': True,
#    'kinh_nghiệm': True,
#    'cơ_sở': True,
#    'vật_chất': True,
#    'khang': True,
#    'tranh': True,
#    'hiện': True,
#    'đạitọa': True,
#    'lạc': True},
#   'positive'),
#  ({'thư_viện': True, 'xịn': True, 'xò': True}, 'positive'),
#  ({'nơi': True, 'mang': True, 'lại': True, 'tri_thức': True}, 'positive'),
#  ({'là': True,
#    'trường': True,
#    'nổi_tiếng': True,
#    'trong': True,
#    'khối': True,
#    'kinh_tế': True,
#    'ở': True,
#    'sài_gòn': True,
#    'nhiều': True,
#    'cử_nhân': True,
#    'đã': True,
#    'tốt_nghiệp': True,
#    'đây': True,
#    'và': True,
#    'làm': True,
#    'khởi_nghiệp': True,
#    'thành_công_trường': True,
#    'giảng_dạy': True,
#    'các': True,
#    'lớp': True,
#    'chính_quy': True,
#    'đại_học': True,
#    'bổ_túc': True,
#    'tín_chỉ': True,
#    'chuyển_đổi': True,
#    'từ': True,
#    'kỹ_sư': True,
#    'sang': True,
#    'cao_học': True,
#    'thạc': True,
#    'sỹ': True,
#    'tiến_sỹ': True,
#    'chất_lượng': True,
#    'tốt': True,
#    'học_phí': True,
#    'phù_hợp': True,
#    'đặc_biệt': True,
#    'có': True,
#    '100': True,
#    'tiếng': True,
#    'anh': True},
#   'positive'),
#  ({'là': True, 'trường_học': True, 'của': True, 'tôi': True}, 'positive'),
#  ({'nhìn': True,
#    'cũ': True,
#    'nên': True,
#    'sửa': True,
#    'lại': True,
#    'cho': True,
#    'đẹp': True},
#   'negative'),
#  ({'kí_túc_xá': True,
#    'đại_học': True,
#    'kinh_tế': True,
#    'quốc_gia': True,
#    'nằm': True,
#    'gần': True,
#    'trường': True,
#    'nông_lâm': True,
#    'nếu': True,
#    'ai': True,
#    'đi': True,
#    'từ': True,
#    'sài_gòn': True,
#    'về': True,
#    'hướng': True,
#    'suối': True,
#    'tiên': True,
#    'thì': True,
#    'kia': True,
#    'túc_xá': True,
#    'sẽ': True,
#    'bên': True,
#    'tay_trái': True,
#    'còn': True,
#    'ngược_lại': True,
#    'tay': True,
#    'phảituy': True,
#    'nhiên': True,
#    'có': True,
#    '1': True,
#    'lưu_ý': True,
#    'khi': True,
#    'xuống': True,
#    'nên': True,
#    'dừng': True,
#    'xe': True,
#    'lại': True,
#    'ngay': True,
#    'nút': True,
#    'cổng': True,
#    'và': True,
#    'chịu_khó': True,
#    'ngược': True,
#    'chiều': True,
#    'khoảng': True,
#    '500m': True,
#    'trái': True,
#    'đường': True,
#    'lớn': True,
#    'lát': True,
#    'nhựa': True,
#    'khá': True,
#    'rộngko': True,
#    'rồi': True,
#    'quay': True,
#    'đầu': True,
#    'vì': True,
#    'xa': True,
#    'tắc': True,
#    'xekhu': True,
#    'vực': True,
#    'này': True,
#    'lơn': True,
#    'rất': True,
#    'đông': True,
#    'cũng': True,
#    'nguy_hiểm_ko': True,
#    'mở': True,
#    'google': True,
#    'map': True,
#    'để': True,
#    'tới': True,
#    'đây': True,
#    'là': True,
#    'vòng': True,
#    'vèobất': True,
#    'tiện': True},
#   'negative'),
#  ({'ngôi': True, 'trường': True, 'tuyệt_vời': True, '3': True}, 'positive'),
#  ({'trường': True,
#    'đại_học': True,
#    'kinh_tế': True,
#    'bậc': True,
#    'nhất': True,
#    'tại': True,
#    'thành_phố': True,
#    'hcm': True,
#    'cơ_sở': True,
#    'vc': True,
#    'xịn': True,
#    'sò': True,
#    'lễ': True,
#    'nhập_học': True,
#    'chào_mừng': True,
#    'sinh_viên': True,
#    'k49': True,
#    'phải': True,
#    'nói': True,
#    'đỉnh': True,
#    'của': True,
#    'mấy': True,
#    'bạn': True,
#    'đang': True,
#    'tìm_hiểu': True,
#    'về': True,
#    'hãy': True,
#    'lên': True,
#    'gg': True,
#    'search': True,
#    'ueh': True,
#    'wiki': True,
#    'sẽ': True,
#    'rõ': True,
#    'cỡ': True,
#    'nào': True},
#   'positive'),
#  ({'trường': True,
#    'sau': True,
#    'khi': True,
#    'xây': True,
#    'mới': True,
#    'thực_sự': True,
#    'rất': True,
#    'ấn_tượng': True,
#    'hiện_đại': True,
#    'đẹp': True,
#    'tiện_nghi': True,
#    'nơi': True,
#    'này': True,
#    'có': True,
#    'cửa_hàng': True,
#    'tiện_lợi': True,
#    'ministop': True,
#    'ngay': True,
#    'đối_diện': True,
#    'trên': True,
#    'lầu': True,
#    'quán': True,
#    'cafe': True,
#    'phòng': True,
#    'tập': True,
#    'gym': True,
#    'thư_viện': True,
#    'trệt': True,
#    'ngân_hàng': True,
#    'ocb': True,
#    'khuôn_viên': True,
#    'rộng': True,
#    'sảnh': True,
#    'để': True,
#    'trang_trí': True,
#    'cho': True,
#    'lễ': True,
#    'tốt_nghiệp': True,
#    'sinh_viên': True,
#    'tha_hồ': True,
#    'chụp': True,
#    'hình_thang_máy': True,
#    'và': True,
#    'thang': True,
#    'bộ': True,
#    'khu': True,
#    'vệ_sinh': True,
#    'nhưng': True,
#    'nhà': True,
#    'nam': True,
#    'ở': True,
#    'cạnh': True,
#    'thang_máy': True,
#    'đầu_tiên': True,
#    'vòi': True,
#    'xít': True,
#    'ngàm': True,
#    'đỡ': True,
#    'không': True,
#    'tương_thích': True,
#    'nên': True,
#    'xịt': True,
#    'luôn_luôn': True,
#    'bị': True,
#    'rơi': True,
#    'xuống': True,
#    'nền': True,
#    'mất': True,
#    'đề_nghị': True,
#    'nhân_viên': True,
#    'của': True,
#    'nếu': True,
#    'đọc': True,
#    'được': True,
#    'bình_luận': True,
#    'vui_lòng': True,
#    'phản_hồi': True,
#    'bộ_phận': True,
#    'chịu': True,
#    'trách_nhiệm': True,
#    'sửa_chữa': True,
#    'làm': True,
#    'hoàn_thiện': True,
#    'trải': True,
#    'nghiệm': True,
#    'khách_hàng': True,
#    'với': True,
#    'dịch_vụ': True,
#    'kinh_tế': True,
#    'xây_dựng': True,
#    'cũng': True,
#    'mang': True,
#    'tính': True,
#    'luôn': True,
#    'tôi': True,
#    'thích': True,
#    'cách': True,
#    'hihi': True},
#   'positive'),
#  ({'kí_túc_xá': True, 'xanh': True}, 'positive'),
#  ({'medium': True, 'quality': True}, 'negative'),
#  ({'trường': True, 'sịn': True, 'lắm': True}, 'positive'),
#  ({'ghet': True}, 'negative'),
#  ({'là': True,
#    'cơ_sở': True,
#    'đẹp': True,
#    'chất': True,
#    'và': True,
#    'chất_lượng': True,
#    'phòng': True,
#    'học': True,
#    'cao': True,
#    'nhất': True,
#    'của': True,
#    'đại_học': True,
#    'kinh_tế': True,
#    'các': True,
#    'trang': True,
#    'thiết_bị': True,
#    'mới': True,
#    'hiện_đại': True,
#    'sáng_sủa': True,
#    'ghế_ngồi': True,
#    'bàn': True,
#    'thoải_mái': True,
#    'tạo': True,
#    'cảm_giác': True,
#    'dễ_chịu': True,
#    'để': True,
#    'có_thể': True,
#    'tiếp_thu': True,
#    'kiến_thức': True,
#    'một_cách': True,
#    'tốt': True,
#    'thanh': True},
#   'positive'),
#  ({'trường': True, 'điểm': True, 'của': True, 'việt_nam': True}, 'positive'),
#  ({'là': True,
#    'tân': True,
#    'sv': True,
#    'uehmình': True,
#    'thực_sự': True,
#    'rất': True,
#    'tự_hào': True,
#    'vs': True,
#    'truyền_thống': True,
#    'và': True,
#    'bề': True,
#    'dày': True,
#    'đào_tạo': True,
#    'của': True,
#    'trường': True,
#    'một': True,
#    'trong': True,
#    'những': True,
#    'trọng_điểm': True,
#    'qg': True,
#    'môi_trường': True,
#    'lí_tưởng': True,
#    'cho': True,
#    'những_ai': True,
#    'đã': True,
#    'đang': True,
#    'sẽ': True,
#    'theo': True,
#    'học': True,
#    'khối': True,
#    'ngành': True,
#    'kinh_tế': True,
#    'uehk42': True},
#   'positive'),
#  ({'cổng': True,
#    'sau': True,
#    'gửi': True,
#    'xe': True,
#    'đại_học': True,
#    'kinh_tế': True,
#    'tp': True,
#    'hcm': True,
#    'cơ_sở': True,
#    'b': True,
#    'số': True,
#    '279': True,
#    'đường': True,
#    'ba': True,
#    'tháng': True,
#    'hai': True,
#    'quận': True,
#    '10': True,
#    'từ': True,
#    '2': True,
#    'đến': True,
#    'thứ': True,
#    '7': True,
#    'buổi': True,
#    'tối': True,
#    'lúc': True,
#    '600': True,
#    'pm': True,
#    'luôn': True,
#    'kẹt': True,
#    'vì': True,
#    'đó': True,
#    'là': True,
#    'thời_gian': True,
#    'bắt_đầu': True,
#    'vô_học': True,
#    'đi': True,
#    'học': True,
#    'trước': True,
#    'đỡ': True,
#    'hơn': True,
#    'vô': True},
#   'negative'),
#  ({'trường': True,
#    'đại_học': True,
#    'kinh_tế': True,
#    'cơ_sở': True,
#    'b': True,
#    'ngay': True,
#    'góc': True,
#    'đường': True,
#    'nguyễn': True,
#    'tri': True,
#    'phương': True,
#    'mới': True,
#    'vị_trí': True,
#    'đẹp': True,
#    'xây_dựng': True,
#    'cũng': True,
#    'khu_vực': True,
#    'này': True,
#    'nhiều': True,
#    'quán': True,
#    'ăn': True,
#    'cafe': True,
#    'vặt': True,
#    'cho': True,
#    'các': True,
#    'bạn': True,
#    'sinh_viên': True,
#    'ban_đêm_trường': True,
#    'có': True,
#    'mở': True,
#    'toà': True,
#    'nhà': True,
#    'ấn_tượng': True},
#   'positive'),
#  ({'môi_trường': True, 'an_ninh': True, 'rất': True, 'tốt': True}, 'positive'),
#  ({'đã': True,
#    'có': True,
#    'quá_trình': True,
#    'được': True,
#    'trải': True,
#    'nghiệm': True,
#    'một': True,
#    'trong': True,
#    'những': True,
#    'trường': True,
#    'hàng_đầu': True,
#    'vn': True},
#   'positive'),
#  ({'là': True,
#    'một': True,
#    'trong': True,
#    'những': True,
#    'trường': True,
#    'công_lập': True,
#    'đứng': True,
#    'đầu': True,
#    'về': True,
#    'đào_tạo': True,
#    'khối': True,
#    'ngành': True,
#    'kinh_tế': True,
#    'và': True,
#    'quản_lý': True,
#    'tại': True,
#    'miền': True,
#    'nam': True,
#    'việt_nam': True,
#    'nổi_bật': True,
#    'với': True,
# ...
#  ({'ow': True}, 'negative'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'studied': True,
#    'perspective': True,
#    'everything': True,
#    'good': True,
#    'got': True,
#    'job': True,
#    'graduation': True,
#    'professors': True,
#    'friendly': True,
#    'helpful': True,
#    'school': True,
#    'atmosphere': True,
#    'compromised': True,
#    'nature': True,
#    'modern': True},
#   'positive'),
#  ({'bad': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'ok': True}, 'positive'),
#  ({'dc': True}, 'positive'),
#  ({'no1': True}, 'positive'),
#  ({'love': True, 'ueh': True}, 'positive'),
#  ({'thich': True}, 'positive'),
#  ({'toan': True, 'ly': True, 'thuyet': True, 'xuong': True}, 'negative'),
#  ({'moi': True, 'truong': True, 'hic': True, 'rat': True, 'tot': True},
#   'positive'),
#  ({'good': True}, 'positive'),
#  ({'good': True,
#    'opportunity': True,
#    'gain': True,
#    'knowleage': True,
#    'experience': True,
#    'economy': True,
#    'well': True,
#    'persional': True,
#    'skill': True,
#    'high': True,
#    'education': True,
#    'standard': True,
#    'also': True,
#    'lot': True,
#    'event': True,
#    'competion': True,
#    'meeting': True,
#    'camping': True,
#    'etc': True,
#    'join': True},
#   'positive'),
#  ({'study': True,
#    'prestigious': True,
#    'university': True,
#    'pretty': True,
#    'good': True,
#    'education': True,
#    'quality': True,
#    'compared': True,
#    'others': True,
#    'vietnam': True,
#    'problem': True,
#    'seriously': True,
#    'lacks': True,
#    'parking': True,
#    'space': True},
#   'positive'),
#  ({'ueh': True,
#    'moee': True,
#    'beautiful': True,
#    'cafe': True,
#    'book': True,
#    'stor': True,
#    'stay': True,
#    'nice': True,
#    'place': True,
#    'enjoy': True,
#    'time': True,
#    'feel': True,
#    'proud': True,
#    'university': True},
#   'positive'),
#  ({'meeting': True,
#    'hall': True,
#    'repaired': True,
#    'aircon': True,
#    'started': True,
#    'working': True,
#    'well': True,
#    'therere': True,
#    'many': True,
#    'performances': True,
#    'student': True,
#    'educations': True,
#    'entertaiment': True},
#   'positive'),
#  ({'fresh': True,
#    'air': True,
#    'quiet': True,
#    'great': True,
#    'place': True,
#    'study': True},
#   'positive'),
#  ({'love': True,
#    'school': True,
#    'much': True,
#    'lots': True,
#    'talented': True,
#    'people': True},
#   'positive'),
#  ({'everything': True,
#    'fantastic': True,
#    'great': True,
#    'rooms': True,
#    'simple': True,
#    'decor': True,
#    'amenities': True,
#    'quiet': True,
#    'street': True,
#    'lovely': True,
#    'staff': True},
#   'positive'),
#  ({'ok': True}, 'positive'),
#  ({'top': True, 'university': True, 'hcmc': True}, 'positive'),
#  ({'school': True}, 'positive'),
#  ({'surely': True,
#    'beautiful': True,
#    'university': True,
#    'light': True,
#    'show': True,
#    'ho': True,
#    'chi minh': True},
#   'positive'),
#  ({'love': True}, 'positive'),
#  ({'ueh': True,
#    'smart': True,
#    'library': True,
#    'provides': True,
#    'high': True,
#    'quality': True,
#    'facilities': True,
#    'large': True,
#    'number': True,
#    'books': True,
#    'mainly': True,
#    'related': True,
#    'economics': True,
#    'also': True,
#    'suitable': True,
#    'place': True,
#    'students': True,
#    'seflstudy': True,
#    'practise': True,
#    'presentation': True,
#    'skills': True,
#    'well': True,
#    'group': True,
#    'work': True,
#    'notice': True,
#    'student': True,
#    'bring': True,
#    'card': True,
#    'something': True,
#    'prove': True,
#    'eligible': True,
#    'come': True},
#   'positive'),
#  ({'review': True,
#    'khoi': True,
#    'sat': True,
#    '23072023': True,
#    'would': True,
#    'like': True,
#    'give': True,
#    '5': True,
#    'star': True,
#    'rating': True,
#    'university': True,
#    'economy': True,
#    'ho': True,
#    'chi minh': True,
#    'city': True,
#    'even': True,
#    'though': True,
#    'student': True,
#    'school': True,
#    'attended': True,
#    'several': True,
#    'events': True,
#    'talk': True,
#    'shows': True,
#    'hosted': True,
#    'impressed': True,
#    'quality': True,
#    'diversity': True,
#    'speakers': True,
#    'hall': True,
#    'accommodate': True,
#    'around': True,
#    '200': True,
#    'people': True,
#    'always': True,
#    'full': True,
#    'enthusiastic': True,
#    'curious': True,
#    'listeners': True,
#    'often': True,
#    'invites successful': True,
#    'business': True,
#    'owners': True,
#    'directors': True,
#    'big': True,
#    'corporations': True,
#    'share': True,
#    'insights': True,
#    'experiences': True,
#    'students': True,
#    'well': True,
#    'scout': True,
#    'potential': True,
#    'startups': True,
#    'talents': True,
#    'learned': True,
#    'lot': True,
#    'think': True,
#    'valuable': True,
#    'anyone interested': True,
#    'entrepreneurship': True},
#   'positive'),
#  ({'room': True,
#    '25': True,
#    'quality': True,
#    'ok': True,
#    'didnt': True,
#    'clean': True,
#    'stayed': True,
#    'days': True,
#    'services': True,
#    '15': True,
#    'got': True,
#    'discount': True,
#    'voucher': True,
#    'paid': True,
#    'immediately': True,
#    'check': True,
#    'carefully': True,
#    'cause': True,
#    'day': True,
#    'checked': True,
#    'said': True,
#    'pay': True,
#    'extra': True,
#    'staff': True,
#    'lost': True,
#    'stuff': True,
#    'food': True,
#    'served': True,
#    'every': True,
#    'morning': True,
#    'noodle': True,
#    'egg': True,
#    'sandwich': True},
#   'negative'),
#  ({'ive': True,
#    'seen': True,
#    'students': True,
#    'struggle': True,
#    'succeed': True,
#    'phenomenally': True,
#    'think': True,
#    'experience': True,
#    'get': True,
#    'definitely': True,
#    'depends': True,
#    'handle': True,
#    'workload': True,
#    'interact': True,
#    'professors': True,
#    'tas': True,
#    'least': True,
#    'small': True,
#    'part': True,
#    'psychology': True,
#    'dont': True,
#    'slack': True,
#    'keep': True,
#    'work': True,
#    'start': True,
#    'assignments': True,
#    'well': True,
#    'advance': True,
#    'deadline': True,
#    'ask': True,
#    'help': True,
#    'soon': True,
#    'realize': True,
#    'youre': True,
#    'struggling': True,
#    'fine': True,
#    'hard': True,
#    'pay': True,
#    'offs': True,
#    'diligent': True,
#    'cramming': True,
#    'last': True,
#    'week': True,
#    'doesnt': True,
#    'enough': True,
#    'come': True,
#    'university': True,
#    'understanding': True,
#    'hardest': True,
#    'educational': True,
#    'life': True,
#    'thus': True,
#    'far': True,
#    'youll': True,
#    'would': True,
#    'expect': True,
#    'believe': True,
#    'found': True,
#    'extremely': True,
#    'rewarding': True,
#    'due': True,
#    'mindset': True,
#    'focusing': True,
#    'schoolwork': True,
#    'early': True,
#    'worked': True,
#    'first': True,
#    'second': True,
#    'year': True,
#    'gave': True,
#    'lot': True,
#    'opportunities': True,
#    'later': True,
#    'allowed': True,
#    'involved': True,
#    'extracurriculars': True,
#    'without': True,
#    'worrying': True,
#    'grades': True,
#    'science': True,
#    'program': True,
#    'say': True,
#    'spent': True,
#    '2': True,
#    'nights': True,
#    'per': True,
#    'socializing': True,
#    'otherwise': True,
#    'keeping': True,
#    'readings': True,
#    'reviewing': True,
#    'lecture': True,
#    'notes': True,
#    'recommended': True,
#    'problemsreadings': True,
#    'preparing': True,
#    'labs': True,
#    'etc': True,
#    'including': True,
#    'weekends': True,
#    'wasnt': True,
#    'strictly': True,
#    'marked': True,
#    'required': True,
#    'easy': True,
#    'forgo': True,
#    'many': True,
#    'thats': True,
#    'economics': True,
#    'ho': True,
#    'chi minh': True,
#    'city': True,
#    'consider': True,
#    'super': True,
#    'smart': True,
#    'time': True,
#    'practicing': True,
#    'problems': True,
#    'working': True,
#    'material': True,
#    'thinking': True,
#    'also': True,
#    'used': True,
#    'memorization': True,
#    'techniques': True,
#    'maximize': True,
#    'efficiency': True,
#    'studying': True,
#    'chemistry': True,
#    'department': True,
#    'faculty': True,
#    'generally': True,
#    'approachable': True,
#    'willing': True,
#    'especially': True,
#    'teaching': True,
#    'staff': True,
#    'go': True,
#    'office': True,
#    'hours': True,
#    'unused': True,
#    'reason': True,
#    'complain': True,
#    'difficulty': True,
#    'seems': True,
#    'case': True,
#    'put': True,
#    'less': True,
#    'effort': True,
#    'thought': True,
#    'necessary': True,
#    'got': True,
#    'stellar': True,
#    'result': True,
#    'need': True,
#    'redefine': True,
#    'definition': True,
#    'theres': True,
#    'handholding': True,
#    'able': True,
#    'balance': True,
#    'desired': True,
#    'regular': True,
#    'fitness': True,
#    'social': True,
#    'peers': True,
#    'since': True,
#    'didnt': True,
#    'top': True,
#    'party': True,
#    'looking': True,
#    'scrape': True,
#    'decent': True,
#    'grade': True,
#    'look': True,
#    'elsewhere': True,
#    'weeding': True,
#    'happens': True,
#    'talented': True,
#    'perfectly': True,
#    'normal': True,
#    'feel': True,
#    'confused': True,
#    'overwhelmed': True,
#    'key': True,
#    'back': True,
#    'textbook': True,
#    'past': True,
#    'readlearn': True,
#    'much': True,
#    'understand': True,
#    'cant': True,
#    'hoping': True,
#    'next': True,
#    'snowball': True,
#    'drop': True,
#    'course': True,
#    'adequately': True,
#    'review': True,
#    'beginning': True,
#    'courses': True,
#    'build': True,
#    'solid': True,
#    'foundation': True,
#    'lectures': True,
#    'trust': True,
#    'make': True,
#    'sense': True,
#    'retain': True,
#    'information': True,
#    'increasing': True,
#    'memory': True,
#    'listening': True,
#    'lecturer': True,
#    'background': True,
#    'informationtldr': True,
#    'results': True,
#    'general': True,
#    'attribute': True,
#    'failures': True,
#    'level': True,
#    'higher': True,
#    'step': True,
#    'grow': True},
#   'positive'),
#  ({'came': True,
#    'eat': True,
#    'friends': True,
#    'school': True,
#    'back': True,
#    'offline': True,
#    'learning': True,
#    '100': True,
#    'everyone': True,
#    'wearing': True,
#    'masks': True,
#    'preparation': True,
#    'students': True,
#    '5': True,
#    'merits': True,
#    'introductory': True,
#    'activities': True,
#    'hall': True,
#    'place': True,
#    'motorbikes': True,
#    'basement': True,
#    'get': True,
#    'plastic': True,
#    'card': True,
#    'pay': True,
#    '4000': True,
#    'vnd': True,
#    'noon': True,
#    '5000': True,
#    'leave': True,
#    'elevators': True,
#    'popular': True,
#    'wait': True,
#    'line': True,
#    '14': True,
#    'floors': True,
#    'floor': True,
#    '6': True,
#    'library': True,
#    'also': True,
#    '7': True,
#    'photocopy': True,
#    'machine': True,
#    'student': True,
#    'print': True,
#    '500': True,
#    'pages': True,
#    'free': True,
#    'semester': True,
#    'remember': True,
#    'correctly': True,
#    'drinks': True,
#    'vending': True,
#    'makes': True,
#    'quite': True,
#    'loud': True,
#    'noise': True,
#    'beverages': True,
#    'dropped': True,
#    'sat': True,
#    'bench': True,
#    'next': True,
#    'overall': True,
#    'enjoyable': True,
#    'experience': True},
#   'positive'),
#  ({'locations': True,
#    'great': True,
#    'despite': True,
#    'lack': True,
#    'facilities': True,
#    'compensate': True,
#    'location': True,
#    'service': True,
#    'friendliness': True,
#    'staffs': True,
#    'close': True,
#    'd1': True,
#    'also': True,
#    'common': True,
#    'kitchen': True,
#    'laundry': True,
#    'area': True,
#    'eat': True,
#    'chill': True,
#    'secure': True,
#    'quiet': True,
#    'convenient': True,
#    'get': True,
#    'good': True,
#    'breakfast': True,
#    'morning': True,
#    'crossiant': True,
#    'little': True,
#    'cam beside': True,
#    'amazing': True,
#    'room': True,
#    'aunty': True,
#    'really': True,
#    'nice': True,
#    'definetely': True,
#    'recommend': True,
#    'stayed': True,
#    '2': True,
#    'weeks': True},
#   'positive'),
#  ({'prestigious': True,
#    'school': True,
#    'helpful': True,
#    'teacher': True,
#    'friendly': True,
#    'staff': True,
#    'find': True,
#    'worldclass': True,
#    'economic': True,
#    'knowledge': True,
#    'various': True,
#    'club': True,
#    'help': True,
#    'enhance': True,
#    'soft': True,
#    'skills': True,
#    'create': True,
#    'memorable': True,
#    'events': True,
#    'student': True,
#    'life': True},
#   'positive'),
#  ({'one': True,
#    'biggest': True,
#    'economics': True,
#    'university': True,
#    'south': True,
#    'vietnam': True,
#    'receives': True,
#    '4000': True,
#    '5000': True,
#    'students': True,
#    'year': True,
#    'premise': True,
#    'nguyen tri': True,
#    'phuong': True,
#    'street': True,
#    'focus': True,
#    'majority': True},
#   'positive'),
#  ({'best': True,
#    'campus': True,
#    'tutors': True,
#    'infrastructure': True,
#    'nice': True,
#    'environment': True,
#    'study u': True,
#    'looking': True,
#    'university': True,
#    'learn': True,
#    'get': True,
#    'good': True,
#    'jobs': True,
#    'economics': True,
#    'feild': True,
#    'option': True},
#   'positive'),
#  ({'visited': True,
#    'conference': True,
#    'facilities': True,
#    'good': True,
#    'amazing': True,
#    'faculties': True,
#    'manage': True,
#    'hybrid': True,
#    'simultaneous': True,
#    'online': True,
#    'offline': True,
#    'engagaments': True,
#    'people': True,
#    'nice': True},
#   'positive'),
#  ({'learned': True,
#    'economics': True,
#    'degree': True,
#    'small': True,
#    'cant': True,
#    'bike': True,
#    'parking': True,
#    'teachers': True},
#   'negative'),
#  ({'old': True,
#    'prestigious': True,
#    'university': True,
#    'vietnam': True,
#    'trained': True,
#    'generations': True,
#    'students': True,
#    'become': True,
#    'investors': True,
#    'accountants': True,
#    'economists': True,
#    'etc': True},
#   'positive'),
#  ({'visit': True,
#    'ueh': True,
#    'occasion': True,
#    '25': True,
#    'th': True,
#    'graduation': True,
#    'anniversary': True,
#    'university': True,
#    'rebuilt': True,
#    'renovated': True,
#    'beautifully': True,
#    'spacious': True,
#    'modern': True},
#   'positive'),
#  ({'well': True,
#    'known': True,
#    'located': True,
#    'campus': True,
#    'old': True,
#    'saigon': True,
#    'law': True,
#    'school': True,
#    'cultural': True,
#    'architect': True,
#    'packed': True,
#    'student': True},
#   'positive'),
#  ({'prestigious': True,
#    'old': True,
#    'school': True,
#    'town': True,
#    'parking': True,
#    'lot': True,
#    'small': True,
#    'prioritized': True,
#    'teachers': True},
#   'negative'),
#  ({'great': True,
#    'university': True,
#    'top': True,
#    '100': True,
#    'se': True,
#    'asia': True,
#    '2011': True},
#   'positive'),
#  ({'best': True,
#    'school': True,
#    'town': True,
#    'economics': True,
#    'huge': True,
#    'placement': True,
#    'opportunities': True,
#    'also': True,
#    'available': True},
#   'positive'),
#  ({'excellent': True,
#    'university': True,
#    'world': True,
#    'class': True,
#    'education': True,
#    'best': True,
#    'teachers': True},
#   'positive'),
#  ({'new': True,
#    'campus': True,
#    'really': True,
#    'good': True,
#    'big': True,
#    'parking': True,
#    'space': True,
#    'pretty': True,
#    'looking': True,
#    'infrastructure': True},
#   'positive'),
#  ({'excellent': True,
#    'environment': True,
#    'good': True,
#    'campus': True,
#    'fully': True,
#    'equipped': True,
#    'educational': True,
#    'facilities': True},
#   'positive'),
#  ({'one': True,
#    'best': True,
#    'universities': True,
#    'vietnam': True,
#    'great': True,
#    'time': True,
#    'place': True},
#   'positive')]
# time: 308 ms (started: 2023-12-23 04:54:39 +00:00)

# %%
train_data, test_data = train_test_split(data_tuples, test_size=0.2, random_state=42)
# Out:
# time: 2.03 ms (started: 2023-12-23 04:54:42 +00:00)

# %%
def wt_predicted(sentence, lang):
    if lang == 'en':
        tokens = word_tokenize(sentence)
    else:
        tokens = ViTokenizer.tokenize(sentence).split()
    return dict([(token, True) for token in tokens])
# Out:
# time: 1.01 ms (started: 2023-12-23 04:54:43 +00:00)

# %%
def predict_sentiment(new_context, lang):
    features = wt_predicted(new_context, lang)
    predicted_label = classifier.classify(features)
    return predicted_label
# Out:
# time: 773 µs (started: 2023-12-23 04:54:45 +00:00)

# %% [markdown]
# ##Naive Bayes

# %% [markdown]
# ### Huấn luyện mô hình

# %%
# Train Naive Bayes Classifier
classifier = NaiveBayesClassifier.train(train_data)
# Out:
# time: 58.1 ms (started: 2023-12-23 04:54:46 +00:00)

# %%
predicted_labels = [classifier.classify(example[0]) for example in test_data]
true_labels = [example[1] for example in test_data]
accuracy = accuracy_score(true_labels, predicted_labels)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8047337278106509
# time: 29.8 ms (started: 2023-12-23 04:54:48 +00:00)

# %%
label_map = {label: i for i, label in enumerate(classifier.labels())}
true_labels_numeric = [label_map[label] for label in true_labels]
predicted_labels_numeric = [label_map[label] for label in predicted_labels]
precision, recall, f1, _ = precision_recall_fscore_support(true_labels_numeric, predicted_labels_numeric, average='weighted')
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.9040990239215092
# Recall: 0.8047337278106509
# F1 Score: 0.8317195761243729
# time: 7.98 ms (started: 2023-12-23 04:54:49 +00:00)

# %%
def cal_neg_score (true_labels, predicted_labels, label ):
  cm = confusion_matrix(true_labels, predicted_labels, labels= label)
  tn, fp, fn, tp = cm.ravel()
  accuracy_negative = (tn + tp) / (tn + fp + fn + tp)
  precision_negative = tn / (tn + fn)
  recall_negative = tn / (tn + fp)
  f1_negative = 2 * (precision_negative * recall_negative) / (precision_negative + recall_negative)
  return accuracy_negative, precision_negative, recall_negative, f1_negative
# Out:
# time: 787 µs (started: 2023-12-23 04:55:12 +00:00)

# %%
an_test , pn_test, rn_test, fn_test =  cal_neg_score(true_labels, predicted_labels, ['negative', 'positive'])
# Out:
# time: 3.94 ms (started: 2023-12-23 04:57:38 +00:00)

# %%
print(f'N_Accuracy: {an_test}\nN_Precision: {pn_test}\nN_Recall {rn_test} \nN_F1: {fn_test} ')
# Out:
# N_Accuracy: 0.8047337278106509
# N_Precision: 0.40384615384615385
# N_Recall 0.9130434782608695
# N_F1: 0.5599999999999999
# time: 4.48 ms (started: 2023-12-23 04:59:59 +00:00)

# %%
le = LabelEncoder()
true_labels_encoded = le.fit_transform(true_labels)
predicted_labels_encoded = le.transform(predicted_labels)

cm = confusion_matrix(true_labels_encoded, predicted_labels_encoded)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Ma trận nhầm lẫn cho Naive Bayes')
plt.show()
# Out:
# time: 246 ms (started: 2023-12-23 04:54:51 +00:00)

# %% [markdown]
# ### Đánh giá mô hình

# %%
for example in test_data:
    context, true_label = example
    predicted_label = classifier.classify(context)
    print(f"Context: {context}, True Label: {true_label}, Predicted Label: {predicted_label}")
# Out:
# Context: {'gửi': True, 'xe': True, 'chật_chội': True, 'phòng': True, 'cũ': True, 'quá': True}, True Label: negative, Predicted Label: negative
# Context: {'school': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'thì': True, 'khỏi': True, 'phải': True, 'chê': True, 'rùi': True, 'ạ': True, 'csvc': True, 'top': True, 'đầu': True, 'nha': True, 'yêu': True, 'ueh': True}, True Label: positive, Predicted Label: negative
# Context: {'“': True, '…': True, 'là': True, 'bầu_trời': True, 'của': True, 'sự': True, 'trưởng_thành': True, 'bằng': True, 'cách': True, 'trải': True, 'nghiệm': True, 'việc_làm': True, 'thêm': True, '”': True, 'thật': True, 'nhiều': True, 'cảm_xúc': True, 'khó': True, 'tả': True, 'một': True, 'năm': True, 'trước': True, 'cũng': True, 'ngày': True, 'hôm_nay': True, 'mình': True, 'bắt_đầu': True, 'bước': True, 'vào': True, 'đây': True, 'làm': True, 'lúc': True, 'đó': True, 'chỉ': True, 'con': True, 'nhóc': True, 'vừa': True, 'thi': True, 'xong': True, 'đại_học': True, 'còn': True, 'không': True, 'biết': True, 'đậu': True, 'rớt': True, 'thế_nào': True, 'đã': True, 'chững_chạc': True, 'hơn': True, 'rất': True, 'năm_học_hỏi': True, 'cố_gắng': True, 'thành_công': True, 'từ': True, 'những': True, 'đầu': True, 'đi': True, 'học': True, 'được': True, 'nhẫn_nhịn': True, 'kìm': True, 'chế': True, 'rồi': True, 'chia_sẻ': True, 'hợp_tác': True, 'với': True, 'đồng_đội': True, 'một_ít': True, 'về': True, 'kinh_doanh': True, 'tư_duy': True, 'quản_lí': True, 'nhân_tâm': True, 'nhờ': True, 'vậy_mà': True, 'đỡ': True, 'ngây_thơ': True, 'dễ': True, 'bị': True, 'kích_động': True, 'nữa': True, 'có': True, 'gì': True, 'suy_nghĩ': True, 'thấu_đáo': True, 'và': True, 'điều': True, 'nếu': True, 'tài_năng': True, 'thiên_phú': True, 'cần': True, 'ngừng': True, 'nhất_định': True, 'sẽ': True, 'kim': True, 'yến': True, '–': True, 'đh': True, 'kinh_tế': True, 'tphcm': True, 'ấy': True, 'tôi': True, 'từng': True, 'qua': True, 'bạn_bè': True, 'anh_chị': True, 'vậy': True, 'khi': True, 'đứa': True, 'sinh_viên': True, 'mà': True, 'bạn': True, 'bản_lĩnh': True, 'cứng_cỏi': True, 'so': True, 'có_thể': True, 'không_thể': True, 'tự': True, 'nuôi': True, 'chính': True, 'bản_thân': True, 'nhưng': True, 'san_sẻ': True, 'gánh': True, 'nặng': True, 'cho': True, 'ba': True, 'mẹ': True, 'như': True, 'thế': True, 'đang': True, 'dần': True, 'làm_chủ': True, 'cuộc_sống': True, 'nên': True, 'đừng': True, 'lười_biếng': True, 'sau': True, 'vùi_đầu': True, 'sách_vở': True, 'cắm_đầu': True, 'vô': True, 'facebook': True, 'phim_ảnh': True, 'buổi': True, 'chơi': True, 'thả': True, 'ga': True, 'hãy': True, 'tìm': True, 'thích_hợp': True, 'thử': True, 'việc': True, 'nhất': True, 'bởi': True, 'con_người': True, 'nhân_viên': True, 'phục_vụ': True, 'nhà_hàng': True, 'gia_sư': True, 'bán': True, 'hàng': True, 'cộng_tác_viên': True, 'shop': True, 'online': True, 'tất_cả': True, 'mọi': True, 'nghĩ': True, 'công_việc': True, 'phù_hợp': True, 'đến': True, 'hai': True, 'trở': True, 'lên': True, 'kiến_thức': True, 'chuyên_ngành': True, 'sức': True, 'trong': True, 'công_ty': True, 'ngành': True, 'học_hỏi': True, 'thứ': True, 'bên': True, 'ngoài': True}, True Label: positive, Predicted Label: negative
# Context: {'uy_tín': True, 'chất_lượng': True, 'lơn': True, 'nhất': True, 'miền': True, 'nam': True}, True Label: positive, Predicted Label: positive
# Context: {'đào_tạo': True, 'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'muốn': True, 'cho': True, 'sinh_viên': True, 'ra': True, 'học': True, 'ở': True, 'ngoại': True, 'mà_lại': True, 'không': True, 'xây': True, 'kí_túc_xá': True, 'có': True, 'gọi': True, 'là': True, 'sự': True, 'thiếu': True, 'chu_đáo': True, 'trong': True, 'tính_toán': True}, True Label: negative, Predicted Label: negative
# Context: {'đhkt': True, 'tphồ': True, 'chí': True, 'minh': True, 'là': True, 'cơ_sở': True, 'đào_tạo': True, 'đại_học': True, 'và': True, 'sau': True, 'các': True, 'ngành': True, 'về': True, 'kinh_tế': True, 'hàng_đầu': True, 'của': True, 'vn': True, 'nơi': True, 'đây': True, 'có': True, 'đội_ngũ': True, 'giao': True, 'sư': True, 'chuyên_môn': True, 'cao': True, 'giáo_trình': True, 'liên_tục': True, 'cập_nhật': True, 'quan_hệ': True, 'tốt': True, 'với': True, 'trường': True, 'tổ_chức': True, 'quốc_tế': True, 'đã': True, 'đạo': True, 'tạo': True, 'rất': True, 'nhiều': True, 'nhân_sự': True, 'trình_độ': True, 'cho': True, 'nền': True, 'quốc': True, 'giatuy': True, 'nhiên': True, 'vật_chất': True, 'manh_mún': True, 'nhỏ_lẻ': True, 'cũ_kỹ': True, 'không': True, 'tương_xứng': True, 'tầm_vóc': True, 'giá_trị': True, 'nó': True, 'mang': True, 'lại': True}, True Label: negative, Predicted Label: negative
# Context: {'trường': True, 'đại_học': True, 'kinh_tế': True, 'thành_phố': True, 'hồ': True, 'chí': True, 'minh': True, 'tiếng': True, 'anh': True, 'university': True, 'of': True, 'economics': True, 'ho': True, 'chi': True, 'city': True, 'viết': True, 'tắt': True, 'ueh': True, 'khẩu_hiệu': True, 'nơi': True, 'đào_tạo': True, 'nhà': True, 'quản_lý': True, 'và': True, 'doanh_nhân': True, 'thành_đạt': True, 'là': True, 'một': True, 'chuyên_ngành': True, 'tại': True, 'việt': True, 'nam': True, 'nằm': True, 'trong': True, 'nhóm': True, 'trọng_điểm': True, 'quốc_gia': True, 'đây': True, 'trụ_cột': True, 'hệ_thống': True, 'giáo_dục': True, 'bậc': True, 'cao': True, 'của': True, 'việt_nam': True, 'cũng': True, 'trung_tâm': True, 'nghiên_cứu': True, 'các': True, 'chính_sách': True, 'cho': True, 'chính_phủ': True, 'doanh_nghiệp': True, 'lớn': True, 'ngoài_ra': True, 'còn': True, 'được': True, 'đánh_giá': True, '1000': True, 'kinh_doanh': True, 'đứng': True, 'đầu': True, 'thế_giới': True, 'theo': True, 'nhiều': True, 'tổ_chức': True, 'xếp_hạng': True, 'uy_tín': True, 'chẳng_hạn': True, 'như': True, 'eduniversal': True}, True Label: positive, Predicted Label: positive
# Context: {'mình': True, 'được': True, 'tư_vấn': True, 'kỹ': True, 'về': True, 'ngành': True, 'học': True, 'trước': True, 'khi': True, 'đăng_ký': True, 'vào': True, 'trường': True, 'thầy': True, 'cô': True, 'cũng': True, 'rất': True, 'thân_thiện': True, 'luôn': True, 'nhiệt_tình': True, 'giúp_đỡ': True, 'dù': True, 'hỏi': True, 'khá': True, 'nhiều': True, 'một': True, 'nơi': True, 'học_tập': True, 'tốt': True, 'nên': True, 'cân_nhắc': True}, True Label: positive, Predicted Label: negative
# Context: {'mong_ước': True, 'sang': True, 'năm': True, 'được': True, 'học': True, 'tại': True, 'ngôi': True, 'trường': True, 'này': True, 'i': True, 'love': True, 'ueh': True}, True Label: positive, Predicted Label: negative
# Context: {'trường': True, 'đẹp': True}, True Label: positive, Predicted Label: positive
# Context: {'dịch_vụ': True, 'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'không_gian': True, 'sạch_sẽ': True, 'thoáng_đãng': True, 'và': True, 'hiền': True, 'đai': True}, True Label: positive, Predicted Label: positive
# Context: {'one': True, 'best': True, 'institution': True, 'vietnam': True, 'good': True, 'atmosphere': True}, True Label: positive, Predicted Label: positive
# Context: {'ko': True, 'như': True, 'mong_đợi': True}, True Label: negative, Predicted Label: positive
# Context: {'chất_lượng': True, 'đào_tạo': True, 'tốt': True, 'tự_hào': True, 'là': True, 'sinh_viên': True, 'của': True, 'trường': True}, True Label: positive, Predicted Label: positive
# Context: {'nhieu': True, 'ki': True, 'niem': True, 'dep': True}, True Label: positive, Predicted Label: positive
# Context: {'sinh_viên': True, 'rất': True, 'ý_thức': True, 'không': True, 'nghẽn': True, 'đường': True}, True Label: positive, Predicted Label: negative
# Context: {'cơ_sở': True, 'nhỏ_xíu': True, 'cũ': True, 'không': True, 'có': True, 'thư_viện': True, 'canteen': True, 'xung_quanh': True, 'bán': True, 'ít': True, 'đồ': True, 'ăn': True, 'vặt': True, 'nhiều': True, 'chỗ': True, 'gửi': True, 'xe': True, 'cho': True, 'sinh_viên': True, 'trong': True, 'trường': True, 'nhỏ': True, 'ra': True, 'sớm': True, 'mà': True, 'để': True, 'ở': True, 'là': True, 'thôi': True, 'rồi': True, 'khó': True, 'lấy': True, 'đi': True, 'trễ': True, 'hết': True, 'xe_máy_tính': True, 'giảng_viên': True, 'xài': True, 'cũng': True, 'máy_lạnh': True, 'hay': True, 'hư': True, 'lên': True, 'xuống': True, 'từ': True, 'lầu': True, '4': True, 'trở': True, 'ghế': True, 'gỗ': True, 'dựa': True, 'được': True, 'cái': True, 'mỗi': True, 'phòng': True, 'wifi': True, 'riêng': True, 'học_sinh': True}, True Label: negative, Predicted Label: negative
# Context: {'ngôi': True, 'trường': True, 'gắn_bó': True, 'mấy': True, 'năm': True, 'hồi': True, 'đó': True, 'mới': True, 'vào': True, 'khá': True, 'cũ': True, 'bây_giờ': True, 'thì': True, 'quá': True, 'hoành_tráng': True}, True Label: positive, Predicted Label: negative
# Context: {'đẹp': True, 'thân_thiện': True}, True Label: positive, Predicted Label: positive
# Context: {'nice': True, 'university': True}, True Label: positive, Predicted Label: positive
# Context: {'dạy': True, 'tốt': True, 'học': True}, True Label: positive, Predicted Label: positive
# Context: {'good': True}, True Label: positive, Predicted Label: positive
# Context: {'tiện_nghi': True}, True Label: positive, Predicted Label: positive
# Context: {'giáo_viên': True, 'nhiều': True, 'kinh_nghiệm': True}, True Label: positive, Predicted Label: positive
# Context: {'csvc': True, 'cũ': True}, True Label: negative, Predicted Label: negative
# Context: {'ở': True, 'đây': True, 'đi_lại': True, 'rất': True, 'thuận_tiện': True}, True Label: positive, Predicted Label: positive
# Context: {'rất': True, 'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'excellent': True, 'university': True, 'world': True, 'class': True, 'education': True, 'best': True, 'teachers': True}, True Label: positive, Predicted Label: positive
# Context: {'thông_minh': True, 'hiện_đại': True, 'khoa_học': True, 'chuyên_nghiệp': True}, True Label: positive, Predicted Label: positive
# Context: {'best': True, 'place': True, 'education': True, 'good': True, 'environment': True}, True Label: positive, Predicted Label: positive
# Context: {'học_phí': True, 'cao': True, 'cơ_sở': True, 'vật_chất': True, 'đẹp': True, 'tốt': True, 'rộng_rãi': True}, True Label: positive, Predicted Label: positive
# Context: {'tọa_lạc': True, 'tại': True, 'địa_chỉ': True, '59c': True, 'nguyễn': True, 'ðình': True, 'chiểu': True, 'phường': True, 'võ': True, 'thị': True, 'sáu': True, 'quận': True, '3': True, 'tp': True, 'hồ': True, 'chí': True, 'minh': True, 'cơ_sở': True, 'là': True, 'trụ_sở': True, 'chính': True, 'của': True, 'trường': True, 'đại_học': True, 'kinh_tế': True, 'ueh': True, 'lâu_đời': True, 'mang': True, 'giá_trị': True, 'truyền_thống': True, 'lịch_sử': True, 'gắn_bó': True, 'với': True, 'nhiều': True, 'thế_hệ': True, 'thầy': True, 'cô': True, 'người': True, 'học': True, 'này': True, 'cũng': True, 'dần': True, 'trở_thành': True, 'một': True, 'nơi': True, 'quen_thuộc': True, 'sinh_viên': True, 'khi': True, 'cần': True, 'hỗ_trợ': True, 'các': True, 'thủ_tục': True, 'liên_quan': True, 'đến': True, 'hồ_sơ': True, 'giấy_tờ': True, 'hành_chính': True, 'quan_trọng': True, 'thường': True, 'diễn': True, 'ra': True, 'chương_trình': True, 'quy_mô': True, 'lớn': True, 'từ': True, 'toàn': True, 'thành': True, 'toàn_quốc': True, 'hoạt_động': True, 'văn_hóa': True, 'bổ_ích': True, 'dành': True, 'cho': True, 'như': True, 'nối': True, 'vòng_tay': True, 'hội': True, 'xuân': True, 'sức': True, 'trẻ': True, 'chung_kết': True, 'cuộc': True, 'thi': True, '…': True, 'một_số': True, 'tính_chất': True, 'khác': True, '“': True, 'tuần': True, 'sinh_hoạt': True, 'công_dân': True, '”': True, 'hội_trường': True, 'a116': True, '1000': True, 'chỗ': True, 'được': True, 'trang_bị': True, 'màn_hình': True, 'led': True, 'siêu': True, 'xịn': True, 'dàn': True, 'âm_thanh': True, 'chuyên_nghiệp': True, 'rất': True, 'những': True, 'ngày': True, 'đầu': True, 'bước': True, 'vào': True, 'lúc': True, 'tốt_nghiệp': True, 'để': True, 'nhắc': True, 'nhớ': True, 'về': True, 'thời': True, 'hoành_tráng': True, 'sôi_động': True, 'cùng': True, 'bề': True, 'dày': True, 'diện_mạo': True, 'và': True, 'vật_chất': True, 'hiện_đại_hóa': True, 'một_cách': True, 'toàn_diện': True, 'trở_nên': True, 'khang_trang': True, 'hơn': True, 'phòng': True, 'đầu_tư': True, 'xây_dựng': True, 'kiến_tạo': True, 'mở_rộng': True, 'đầy_đủ': True, 'bàn': True, 'ghế': True, 'mới': True, 'máy_lạnh': True, 'hệ_thống': True, 'ánh_sáng': True, 'trang': True, 'thiết_bị': True, 'giảng_dạy': True, 'hiện_đại': True, 'tạo': True, 'nên': True, 'môi_trường_học_tập': True, 'lý_tưởng': True, 'nhà': True, 'vệ_sinh': True, 'sạch_sẽ': True, 'không_gian': True, 'thoáng_đãng': True, 'đèn_chiếu': True, 'sáng': True, 'ổn_định': True, '247': True, 'loại': True, 'dụng_cụ': True, 'nước': True, 'rửa': True, 'tay': True, 'gương': True, 'bồn': True, 'khu': True, 'cà_phê': True, 'sân_thượng': True, 'café': True, 'tầng': True, 'sẽ': True, 'địa_điểm': True, 'lý_thú': True, 'mọi': True, 'cán_bộ': True, 'viên_chức': True, 'quán': True, 'góc': True, 'nhỏ': True, 'khoảng': True, 'chừng': True, '50m2': True, 'tuy_nhiên': True, 'lại': True, 'mệnh_danh': True, 'khu_vực': True, 'xanh': True, 'nhất': True, 'ở': True, 'đây': True, 'thoáng': True, 'mát': True, 'cây_xanh': True, 'xung_quanh': True, 'đồng_thời': True, 'thiết_kế': True, 'theo': True, 'phong_cách': True, 'phương': True, 'tây': True, 'cảm_giác': True, 'lịch_thiệp': True, 'sang_trọng': True, 'phục_vụ': True, 'đồ': True, 'uống': True, 'soda': True, 'sinh_tố': True, 'ép': True, 'trà': True, 'thức_ăn': True, 'nhanh': True, 'dịch_vụ': True, 'cơm': True, 'trưa': True, 'văn_phòng': True, 'giếng': True, 'trời': True, 'trệt': True, 'tiểu_cảnh': True, 'hòn': True, 'non_bộ': True, 'nước_hoa': True, 'cây_cảnh': True, 'bài_trí': True, 'hài': True, 'hòa': True, 'lấy': True, 'tự_nhiên': True, 'điều': True, 'không_khí': True, 'sự': True, 'tươi_mát': True, 'thông_thoáng': True, 'toàn_bộ': True, 'dừng': True, 'chân_lý_tưởng': True, 'sau': True, 'giờ': True, 'lên_lớp': True, 'liên_hệ': True, 'giải_quyết': True, 'phòngban': True, 'trung_tâm': True, 'thành_phố': True, 'tuyến': True, 'xe': True, 'bus': True, '03': True, '04': True, '05': True, '150': True, '30': True, '31': True, '36': True, '93': True ...
# Context: {'là': True, 'môi_trường': True, 'họp': True, 'tập': True, 'ngày_càng': True, 'chuyên_nghiệp': True, 'các': True, 'không_gian': True, 'được': True, 'sử_dụng': True, 'tối_đa': True, 'cho': True, 'sinh_viên': True, 'có': True, 'điều_kiện': True, 'học': True, 'nhóm': True, 'sinh_hoạt': True, 'thể_thao': True, 'văn_nghệ': True, 'hội_trường': True, 'và': True, 'dịch_vụ': True, 'công_cộng': True, 'đạt': True, 'chất_lượng': True, 'rất': True, 'cao': True, 'so': True, 'với': True, 'mặt_bằng': True, 'đại_học': True, 'chung': True, 'nhìn_chung': True, 'hài_lòng': True, 'ngay': True, 'cả': True, 'sau': True, 'khi': True, 'chứng_chỉ': True, 'ra': True, 'trường': True, 'thì': True, 'vẫn': True, 'thông_tin': True, 'để': True, 'liên_lạc': True, 'cập_nhật': True, 'thường_xuyên': True, 'đồng': True, 'môn': True, 'nhà_trường': True}, True Label: positive, Predicted Label: negative
# Context: {'đẹp': True}, True Label: positive, Predicted Label: positive
# Context: {'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'rất': True, 'hài_lòng': True}, True Label: positive, Predicted Label: positive
# Context: {'cơ_sở': True, 'vật_chất': True, 'hiện_đại': True, 'chất_lượng': True, 'giảng_dạy': True, 'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'yêu': True, 'lắm': True, 'ueh': True, 'nơi': True, 'đào_tạo': True, 'những': True, 'con_người': True, 'năng_động': True, 'thành_công': True, 'trong': True, 'cuộc_sống': True}, True Label: positive, Predicted Label: negative
# Context: {'cơ_sở': True, 'd': True, 'một': True, 'trong': True, 'những': True, 'chính': True, 'và': True, 'năng_động': True, 'của': True, 'viện': True, 'đào_tạo': True, 'quốc_tế': True, 'isb': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'rất': True, 'đẹp': True, 'hiện_đại_tự_hào': True, 'là': True, 'một': True, 'ueher': True}, True Label: positive, Predicted Label: positive
# Context: {'có': True, 'rất': True, 'nhiều': True, 'câu': True, 'lạc_bộ': True, 'tuyển': True, 'cộng_tác_viên': True, 'ở': True, 'đây': True, 'nào': True, 'cũng': True, 'thú_vị': True, 'trường': True, 'sạch_sẽ': True, 'bên': True, 'ngoài': True, 'còn': True, 'hàng_quán': True, 'bán': True, 'đồ': True, 'ăn': True, 'sáng': True, 'ngon': True, '…': True}, True Label: positive, Predicted Label: negative
# Context: {'chi_phí': True, 'học_phí': True, 'hợp_lý': True, 'đh': True, 'kinh_tế': True, 'tphcm': True, 'là': True, 'trường': True, 'dạy': True, 'về': True, 'tốt': True, 'hàng_đầu': True, 'phía': True, 'nam': True, 'việt_nam': True}, True Label: positive, Predicted Label: positive
# Context: {'kỷ_niệm': True, 'tại': True, 'trường': True, 'thời': True, 'trẻ': True, 'trâu': True, 'nhớ': True, 'thầy': True, 'cô': True, 'và': True, 'các': True, 'bạn': True, 'quá': True, 'giờ': True, 'chắc': True, 'đại_gia': True, 'hết': True, 'rồi': True}, True Label: positive, Predicted Label: negative
# Context: {'học': True, 'nữa': True, 'mãi': True, 'đến': True, 'khi': True, 'nào': True, 'cạn_kiệt': True, 'thì_thôi': True}, True Label: negative, Predicted Label: negative
# Context: {'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'nằm': True, 'trên': True, 'đại_lộ': True, 'nguyễn': True, 'văn': True, 'linh': True, 'trường': True, 'mới': True, 'được': True, 'xây_dựng': True, 'và': True, 'với': True, 'không_gian': True, 'xanh': True, 'bên': True, 'ngoài': True, 'rất': True, 'thoáng': True, 'mát': True}, True Label: positive, Predicted Label: positive
# Context: {'good': True, 'place': True}, True Label: positive, Predicted Label: positive
# Context: {'ok': True, 'good': True}, True Label: positive, Predicted Label: positive
# Context: {'3': True, 'ueh': True}, True Label: positive, Predicted Label: positive
# Context: {'ok': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'ko': True, 'tránh': True, 'nhiệm': True}, True Label: negative, Predicted Label: negative
# Context: {'trường': True, 'đại_học': True, 'kinh_tế': True, 'tp': True, 'hồ': True, 'chí': True, 'minh': True, '59c': True, 'nguyễn': True, 'đình': True, 'chiểu': True, 'p6': True, 'q3': True, 'điện_thoại': True, '0838295299': True, 'fax': True, '0838250359': True, 'được': True, 'thành_lập': True, 'trên': True, 'cơ_sở': True, 'hợp_nhất': True, 'năm': True, '1976': True, 'tài_chính': True, 'kế_toán': True, 'và': True, 'khoa': True, 'thuộc': True, 'tổng_hợp': True, 'theo': True, 'quyết_định': True, 'số': True, '2819gdđt': True, 'ngày': True, '0971996': True, 'của': True, 'bô': True, 'trưởng': True, 'bộ': True, 'giáo_dục': True, 'đào_tạo': True, '10102000': True, 'thủ_tướng': True, 'chính_phủ': True, 'đã': True, 'ban_hành_quyết_định': True, '1182000qđttg': True, 'về': True, 'việc': True, 'thay_đổi': True, 'tổ_chức': True, 'quốc_gia': True, 'này': True, 'tách': True, 'ra': True, 'thành': True, 'trực_thuộc': True, 'là': True, 'một': True, 'đa': True, 'ngành': True, 'với': True, 'nhiều': True, 'bậc': True, 'hệ': True, 'đa_dạng': True, 'có': True, 'đội_ngũ': True, 'giáo_sư': True, 'giảng_viên': True, 'từ': True, 'nguồn': True, 'trình_độ': True, 'cao': True, 'uy_tín': True, 'khoa_học': True, 'chuyên_môn': True, 'đây': True, 'trong': True, 'những': True, 'điều_kiện': True, 'chính': True, 'để': True, 'từng': True, 'bước': True, 'nâng': True, 'chất_lượng': True, 'dạy': True, 'học': True, 'vị_thế': True, 'mình': True, 'xã_hội_trường': True, 'số_lượng': True, 'người': True, 'các': True, 'cử_nhân': True, 'đến': True, 'thạc_sĩ': True, 'tiến_sĩ': True, 'coi': True, 'lớn': True, 'nhất': True, 'nước': True, 'hiện_nay': True, 'hai': True, 'loại_hình': True, 'chính_quy': True, 'vừa': True, 'làm': True, 'sau': True, 'không': True, 'tập_trung_lưu_lượng': True, 'sinh_viên': True, 'học_viên': True, 'hàng': True, 'khoảng': True, '50000': True, 'mục_tiêu': True, 'bồi_dưỡng': True, 'cung_cấp': True, 'cho': True, 'xã_hội': True, 'nhà': True, 'hoạch_định': True, 'chính_sách': True, 'quản_trị': True, 'doanh_nghiệp': True, 'chuyên_gia': True, 'lĩnh_vực': True, 'quản_lý': True, 'kinh_doanh': True, 'luật': True, 'chủ_yếu': True, 'thứ': True, 'nghiên_cứu': True, 'nhằm': True, 'tham_gia': True, 'giải_quyết': True, 'vấn_đề': True, 'phát_sinh': True, 'quá_trình': True, 'phát_triển': True, 'đất_nước': True, 'đồng_thời': True, 'bổ_sung': True, 'lý_luận': True, 'việt': True, 'nam': True, 'luôn': True, 'mở_rộng': True, 'mối': True, 'quan_hệ': True, 'hợp_tác': True, 'ngoài': True, 'bắt': True, 'kịp': True, 'tiên_tiến': True, 'thế_giới': True, 'quốc_tế_hóa': True, 'kiến_thức': True, 'đáp_ứng': True, 'yêu_cầu': True, 'tương_lai': True, '14': True, 'trọng_điểm': True, 'khi': True, 'nay': True, 'chục': True, 'ngàn': True, 'cán_bộ': True, 'cả': True, 'đảm_bảo': True, 'thừa_nhận': True, 'thành_tích': True, 'xuất_sắc': True, 'xây_dựng': True, 'tập_thể': True, 'nhân_viên': True, 'chủ_tịch': True, 'trao_tặng': True, '02': True, 'huân_chương': True, 'lao_động': True, 'hạng': True, 'ba': True, '1986': True, 'nhì': True, '1991': True, '1996': True, 'độc_lập': True, '2001': True, '2010': True, 'danh_hiệu': True, 'anh_hùng': True, '2006': True}, True Label: positive, Predicted Label: negative
# Context: {'khuôn_viên': True, 'trường': True, 'rộng_rãi': True, 'thoáng': True, 'mát': True, 'phòng': True, 'học': True, 'đày': True, 'đủ': True, 'tiện_ích': True, 'và': True, 'hiện_đại': True, 'cơ_sở': True, 'vật_chất': True, 'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'khum': True, 'bít': True, 'mn': True, 'sao': True, 'chứ': True, 'tui': True, 'ở': True, 'đây': True, 'vui': True, 'vl': True, 'í': True}, True Label: positive, Predicted Label: negative
# Context: {'ueh': True, 'tuyệt_vời': True}, True Label: positive, Predicted Label: positive
# Context: {'cơ_sở': True, 'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'ok': True}, True Label: positive, Predicted Label: positive
# Context: {'cố_gắng': True, 'học': True, 'tốt': True, 'nhái': True, 'love': True, 'my': True, 'school3': True}, True Label: positive, Predicted Label: positive
# Context: {'one': True, 'biggest': True, 'economics': True, 'university': True, 'south': True, 'vietnam': True, 'receives': True, '4000': True, '5000': True, 'students': True, 'year': True, 'premise': True, 'nguyen tri': True, 'phuong': True, 'street': True, 'focus': True, 'majority': True}, True Label: positive, Predicted Label: positive
# Context: {'good': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'có': True, '8': True, 'cơ_sở': True, 'dành': True, 'cho': True, 'hoạt_động': True, 'giảng_dạy_học_tập': True, 'và': True, 'làm_việc': True, 'trong': True, 'đó': True, '91': True, 'phòng': True, 'học': True, 'không': True, 'kể': True, 'giảng_đường': True, 'thuê': True, 'ngoài': True, 'toàn_bộ': True, 'các': True, 'đều': True, 'được': True, 'trang_bị': True, 'hệ_thống': True, 'micro': True, 'dây': True, 'máy_chiếu': True, 'đa_phương_tiện': True}, True Label: positive, Predicted Label: negative
# Context: {'chiếc': True, 'cầu_nối': True, 'giữa': True, 'tòa': True, 'nhà': True, 'b2': True, 'cổ_kính': True, 'và': True, 'b1': True, 'hiện_đại': True, 'tại': True, 'cơ_sở': True, 'b': True, 'ueh': True, 'đây': True, 'được': True, 'xem': True, 'như': True, 'là': True, 'cầu': True, 'gắn_kết': True, 'nhiều': True, 'thế_hệ': True, 'với': True, 'nhau': True, 'nếu': True, 'có': True, 'một': True, 'dịp': True, 'ghé': True, 'ngang': True, 'các': True, 'bạn': True, 'nhớ': True, 'vào': True, 'check': True, 'in': True, 'nhé': True}, True Label: positive, Predicted Label: negative
# Context: {'bãi': True, 'xe_hơi': True, 'nhỏ': True, 'phòng': True, 'học': True}, True Label: negative, Predicted Label: negative
# Context: {'môi_trường_học_tập': True, 'lý_tưởng': True}, True Label: positive, Predicted Label: positive
# Context: {'hay': True}, True Label: positive, Predicted Label: positive
# Context: {'xịn': True}, True Label: positive, Predicted Label: positive
# Context: {'địa_điểm_chuẩn': True, '5': True, 'sao': True}, True Label: positive, Predicted Label: positive
# Context: {'good': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'được': True, 'nâng_cấp': True, 'cơ_sở': True, 'vật_chất': True, 'có': True, 'những': True, 'khu_vực': True, 'tự': True, 'học': True, 'thoải_mái': True, 'hội_trường': True, 'trang_bị': True, 'thiết_bị': True, 'tân_tiến': True, 'rất': True, 'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'đẹp': True}, True Label: positive, Predicted Label: positive
# Context: {'hiện_đại': True, 'nhưng': True, 'hơi': True, 'nóng': True, 'tìm': True, 'thùng': True, 'rác': True, 'khó': True}, True Label: negative, Predicted Label: negative
# Context: {'top': True, 'university': True, 'hochiminh': True, 'city': True}, True Label: positive, Predicted Label: positive
# Context: {'decor': True, 'đẹp': True, 'các': True, 'phòng': True, 'trang_bị': True, 'thiết_bị': True, 'hiện_đại': True, 'không_gian': True, 'thoải_mái': True}, True Label: positive, Predicted Label: positive
# Context: {'tệmức': True, 'học_phí': True, 'quá': True, 'cao': True, '930k1': True, 'tíntuyển': True, 'sinh': True, 'đầu_vào': True, 'không': True, 'kĩxét': True, 'học_bạ': True, 'nhiềugiảng': True, 'viên': True, 'dạy': True, 'thiếu': True, 'tâm': True, 'huyếtthời': True, 'gian': True, 'học': True, 'ítcơ': True, 'sở': True, 'vật_chất': True, 'chưa': True, 'đáp_ứng': True, 'được': True, 'với': True, 'lượng': True, 'sinh_viên': True, 'vậy_mà': True, 'trường': True, 'còn': True, 'tuyển': True, 'khá': True, 'nhiều': True, 'chỉ_tiêu': True, 'công_tác': True, 'đào_tạo': True, 'chất_lượng': True, 'càng': True, 'thế_hệ': True, 'sau': True, 'nát': True, 'chỉ': True, 'danh_tiếng': True, 'của': True, 'các': True, 'trước': True}, True Label: negative, Predicted Label: negative
# Context: {'trường': True, 'dạy': True, 'tốt': True, 'kiến_thức': True, 'chuyên_sâu': True, 'nhiều': True, 'hoạt_động': True, 'ngoại': True, 'khóa': True, 'hấp_dẫn': True}, True Label: positive, Predicted Label: positive
# Context: {'rộng': True, 'thoáng': True, 'mát': True}, True Label: positive, Predicted Label: positive
# Context: {'best': True, 'school': True, 'town': True, 'economics': True, 'huge': True, 'placement': True, 'opportunities': True, 'also': True, 'available': True}, True Label: positive, Predicted Label: positive
# Context: {'khá': True, 'là': True, 'xịn': True, 'xò': True, 'bãi': True, 'xe': True, 'dưới': True, 'hầm': True, 'rộng': True, 'bảo_vệ': True, 'thân_thiện': True}, True Label: positive, Predicted Label: negative
# Context: {'trường': True, 'khang_trang': True, 'rộng_rãi': True, 'khá': True, 'ghen_tị': True, 'với': True, 'sinh_viên': True, 'ueh': True}, True Label: positive, Predicted Label: positive
# Context: {'probably': True, 'best': True, 'business': True, 'school': True, 'town': True}, True Label: positive, Predicted Label: positive
# Context: {'best': True, 'campus': True, 'tutors': True, 'infrastructure': True, 'nice': True, 'environment': True, 'study u': True, 'looking': True, 'university': True, 'learn': True, 'get': True, 'good': True, 'jobs': True, 'economics': True, 'feild': True, 'option': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'đhkt': True, 'đã': True, 'có': True, 'những': True, 'bước': True, 'phát_triển': True, 'quan_trọng': True, 'trong': True, 'việc': True, 'nâng': True, 'cao': True, 'chất_lượng': True, 'đào_tạo': True, 'thông_qua': True, 'mở_rộng': True, 'hợp_tác': True, 'với': True, 'các': True, 'đại_học': True, 'tổ_chức': True, 'giáo_dục': True, 'quốc_tế': True, 'tuy_nhiên': True, 'cần': True, 'kết_nối': True, 'nhiều': True, 'hơn': True, 'doanh_nghiệp': True, 'lớn': True, 'nước': True, 'và': True, 'thế_giới': True, 'tăng': True, 'thời_lượng': True, 'thực_hành': True, 'tại': True, 'cho': True, 'sinh_viên': True, 'học_viên': True, 'để': True, 'nữa': True, 'đầu_ra': True}, True Label: positive, Predicted Label: positive
# Context: {'tuyet': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'ở': True, 'vị_trí': True, 'gần': True, 'hồ': True, 'con': True, 'rùa': True, 'phù_hộ': True, 'cho': True, 'sinh_viên': True, 'kinh_tế': True, 'thôi': True, 'chứ': True, 'mấy': True, 'ní': True, 'coi': True, 'chi': True, 'nhiều': True, 'à': True, 'chỗ': True, 'gửi': True, 'xe': True, 'trước': True, '10k': True}, True Label: positive, Predicted Label: negative
# Context: {'ok': True}, True Label: positive, Predicted Label: positive
# Context: {'sức': True, 'chứa': True, 'hội_trường': True, 'lớn': True, '500': True, 'người': True}, True Label: positive, Predicted Label: negative
# Context: {'không_gian': True, 'thoáng_đãng': True, 'thích_hợp': True, 'học_tập': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'đào_tạo': True, 'tốt': True, 'nhiều': True, 'chứng_chỉ': True, 'có_ích': True}, True Label: positive, Predicted Label: positive
# Context: {'nơi': True, 'đào_tạo': True, 'những': True, 'nhà': True, 'kinh_tế': True, 'tương_lai': True, 'sau_này': True, 'ngôi': True, 'trường': True, 'thật': True, 'to': True, 'và': True, 'tiện_nghi': True, 'ngay': True, 'trung_tâm': True, 'thành_phố': True}, True Label: positive, Predicted Label: positive
# Context: {'cơ_sở': True, 'b': True, 'tọa_lạc': True, 'tại': True, 'địa_chỉ': True, '279': True, 'nguyễn': True, 'tri': True, 'phương': True, 'phường': True, '5': True, 'quận': True, '10': True, 'tp': True, 'hồ': True, 'chí': True, 'minh': True, 'là': True, 'nơi': True, 'đi': True, 'qua': True, 'của': True, 'rất': True, 'nhiều': True, 'tuyến': True, 'xe': True, 'bus': True, '07': True, '59': True, '45': True, '119': True, 'đây': True, 'được': True, 'mệnh_danh': True, 'thông_minh': True, 'đánh_dấu': True, 'bước_ngoặt': True, 'về': True, 'đổi_mới': True, 'vật_chất': True, 'theo': True, 'hướng': True, 'chuẩn': True, 'đại_học': True, 'quốc_tế': True, 'ueh': True, 'sảnh': True, 'chính': True, 'tòa_b1': True, 'với': True, 'không_gian': True, 'rộng': True, 'thiết_kế': True, 'sang_trọng': True, 'hiện_đại': True, 'điểm': True, 'nhấn': True, 'như': True, 'bảng': True, 'chỉ_dẫn': True, 'góc': True, 'truyền_thống': True, '1976': True, 'quầy': True, 'lễ_tân': True, 'đàn': True, 'piano': True, 'dãy': True, 'ghế': True, 'sofa': True, 'màu_sắc': True, 'tươi_sáng': True, 'kết_hợp': True, 'cùng': True, 'hệ_thống': True, 'ánh_sáng': True, 'phòng': True, 'khánh_tiết': True, '76m2': True, 'nội_thất': True, 'sô': True, 'pha': True, 'cao_cấp': True, 'và': True, 'hoa_văn': True, 'tinh_xảo': True, 'mang': True, 'phong': True, 'các': True, 'lịch_lãm': True, 'đón_tiếp': True, 'chính_khách': True, 'nhà': True, 'lãnh_đạo': True, 'khoa_học': True, 'khách': True, 'mời': True, 'quan_trọng': True, 'nhà_trường': True, 'hội_trường': True, '300': True, 'chỗ': True, '398m2': True, 'chan': True, 'hòa': True, '3': True, 'màn': True, 'chiếu': True, 'led': True, 'âm_thanh': True, 'gắn': True, 'liền': True, 'những': True, 'sự_kiện': True, 'hoành_tráng': True, 'họp': True, '30': True, 'người': True, 'hội_thảo': True, '60': True, '120': True, 'có': True, 'tv': True, 'máy_tính': True, 'xách': True, 'tay': True, 'máy_lạnh': True, 'máy_chiếu': True, 'đèn': True, 'tổ_chức': True, 'buổi': True, 'trao_đổi': True, 'thảo_luận': True, 'chuyên_môn': True, 'trong': True, 'chuyên_nghiệp': True, 'gắn_kết': True, 'sáng_tạo': True, 'học': True, 'đầu_tư_trang': True, 'thiết_bị': True, 'dạy_học': True, 'phục_vụ': True, 'giảng_dạy': True, 'bục': True, 'giảng': True, '…': True, 'linh_hoạt': True, 'trang_trí': True, 'câu_danh_ngôn': True, 'sống_động': True, 'mở': True, 'khuyến_khích': True, 'sinh_viên': True, 'tinh_thần': True, 'tự': True, 'tham_gia': True, 'hoạt_động': True, 'giảng_đường': True, 'đặc_biệt': True, 'thư_viện': True, 'đầu_tiên': True, 'duy_nhất': True, 'việt_nam': True, 'đông': True, 'nam': True, 'á': True, 'tích_hợp': True, 'công_nghệ': True, '40': True, 'made': True, 'in': True, 'vietnam': True, 'hiện': True, 'hơn': True, '398000': True, 'đầu_sách': True, 'thuộc': True, 'lĩnh_vực': True, 'kinh_tế': True, 'đó': True, '600': True, 'đến': True, 'từ': True, 'harvard': True, 'đồng_thời': True, 'kết_nối': True, 'dữ_liệu': True, '90': True, 'xuất_bản': True, 'trường': True, 'danh_giá': True, 'mỹ': True, 'châu': True, 'âu': True, 'có_thể': True, 'đăng_ký': True, 'tra_cứu': True, 'tài_liệu': True, 'online': True, 'trên': True, 'website': True, 'nhận': True, 'sự': True, 'hỗ_trợ': True, 'nhiệt_tình': True, 'nhân_viên': True, 'học_thuật': True, 'đầu_tư': True, 'hạ_tầng': True, 'tự_động': True, 'tất_cả': True, 'khâu': True, 'trang_bị': True, 'camera': True, 'cảm_biến': True, 'chip': True, 'đo': True, 'vận_dụng': True, 'thuật_toán': True, 'để': True, 'phân_tách': True, 'giữa': True, 'khu_vực': True, 'học_tập': True, 'tập_trung': True, 'cần': True, 'yên_tĩnh': True, 'iot': True, 'kiến_trúc': True, 'nghiệp_vụ': True, 'nhau': True, 'không_những': True, 'tiết_kiệm': True, 'năng_lượng': True, 'bảo_vệ': True, 'sức_khỏe': True, 'nghiên_cứu_sinh': True, 'giảng_viên': True, 'mà': True, 'còn': True, 'giúp': True, 'cá_nhân_hóa': True, 'cao': True, 'phân_biệt': True, 'từng': True, 'trung_tâm': True, 'mô_phỏng': True, 'nghiên_cứu': True, 'simulation': True, 'center': True, 'rèn_luyện': True, 'kỹ_năng ...
# Context: {'beautifull': True, 'school': True, 'food': True, 'served': True}, True Label: negative, Predicted Label: negative
# Context: {'sạch_sẽ': True, 'thơm_tho': True}, True Label: positive, Predicted Label: positive
# Context: {'hồi': True, 'trước': True, 'thi': True, 'vào': True, 'trường': True, 'có': True, '205': True, 'điểm': True, 'năm': True, 'nay': True, 'lấy': True, 'gần': True, 'bằng': True, 'ngoại_thương': True, 'vl': True}, True Label: negative, Predicted Label: negative
# Context: {'good': True}, True Label: positive, Predicted Label: positive
# Context: {'xuất_sắc': True}, True Label: positive, Predicted Label: positive
# Context: {'university': True, 'good': True, 'position': True, 'ho': True, 'chi minh': True, 'city': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'mới': True, 'xây_dựng': True, 'lại': True, 'cơ_sở': True, 'rất': True, 'đẹp': True, 'chất_lượng': True, 'đào_tạo': True, 'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'fine': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'đẹp': True}, True Label: positive, Predicted Label: positive
# Context: {'rất': True, 'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'ok': True}, True Label: positive, Predicted Label: positive
# Context: {'không_gian': True, 'cơ_sở': True, 'khá': True, 'hạn_hẹp': True, 'chật_chội': True, 'nhưng': True, 'nhiều': True, 'hoạt_động': True, 'diễn': True, 'ra': True, 'thu_hút': True, 'sinh_viên': True}, True Label: negative, Predicted Label: negative
# Context: {'good': True}, True Label: positive, Predicted Label: positive
# Context: {'cơ_sở': True, 'vật_chất': True, 'hiện_đại': True, 'không_gian': True, 'xanh': True, 'và': True, 'thoáng': True, 'mọi': True, 'người': True, 'thân_thiện': True}, True Label: positive, Predicted Label: positive
# Context: {'từng': True, 'ở': True, 'đây': True, '4': True, 'năm': True, 'quảng': True, 'đời': True, 'sv': True, 'không_thể_nào': True, 'quên': True}, True Label: positive, Predicted Label: positive
# Context: {'ok': True}, True Label: positive, Predicted Label: positive
# Context: {'không': True, 'có': True, 'trách_nhiệm': True}, True Label: negative, Predicted Label: negative
# Context: {'đỉnh': True, 'của': True}, True Label: positive, Predicted Label: positive
# Context: {'các': True, 'bạn': True, 'sinh_viên': True, 'ở': True, 'đây': True, 'rất': True, 'giỏi': True, 'có': True, 'một': True, 'lớp': True, 'đặt': True, 'đồng_phục': True, 'shop': True, 'mình': True, 'chia_sẻ': True, 'thầy': True, 'cô': True, 'tuyệt_vời': True}, True Label: positive, Predicted Label: negative
# Context: {'good': True, 'đây': True, 'là': True, 'cơ_sở': True, 'lâu_đời': True, 'nên': True, 'khá': True, 'cũ': True}, True Label: positive, Predicted Label: negative
# Context: {'great': True, 'university': True, 'top': True, '100': True, 'se': True, 'asia': True, '2011': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'rất': True, 'đẹp': True, 'ngày': True, 'nào': True, 'cũng': True, 'chạy': True, 'ngang': True}, True Label: positive, Predicted Label: negative
# Context: {'an_ninh': True, 'tốt': True, 'vô': True, 'ngõ_hẻm': True, 'để': True, 'đến': True, 'số': True, '135b': True}, True Label: positive, Predicted Label: negative
# Context: {'thái_độ': True, 'văn_phòng': True, 'đào_tạo': True, 'k': True, 'tốt': True, 'mình': True, 'vào': True, 'hỏi': True, 'mà': True, 'quát': True, 'mặt': True, 'chỉ': True, 'nhớ': True, 'bà_cô': True, 'đó': True, 'tên': True, 'quyên': True, 'mập': True, 'đi': True, 'nộp': True, 'hồ_sơ': True, 'lòng_vòng': True, 'kiểu': True, 'khinh_khỉnh': True, 'chưa': True, 'biết': True, 'bà': True, 'có': True, 'dạy_học_sinh': True, 'như': True, 'nội': True, 'thiên_hạ': True}, True Label: negative, Predicted Label: negative
# Context: {'thich': True}, True Label: positive, Predicted Label: positive
# Context: {'ghé': True, 'đi': True, 'dự': True, 'tốt_nghiệp': True, 'chật_chội': True, 'nhưng': True, 'được': True, 'cái': True, 'cơ_sở': True, 'sạch_sẽ': True, 'hướng_dẫn_nhiệt_tình': True}, True Label: positive, Predicted Label: negative
# Context: {'good': True}, True Label: positive, Predicted Label: positive
# Context: {'chất_lượng': True, 'phục_vụ': True, 'tệ_hại': True, 'hời_hợt': True, 'rất': True, 'thất_vọng': True, 'khi': True, 'đặt': True, 'niềm': True, 'tin': True, 'vào': True, 'đây': True}, True Label: negative, Predicted Label: negative
# Context: {'sinh_viên': True, 'hơi': True, 'ồn_ào': True, 'bất': True, 'lịch_sự': True, 'đề_nghị_trường': True, 'coi': True, 'lại': True, 'kỉ_luật': True, 'hơn': True, 'khi': True, 'ra': True, 'đường': True, 'tránh': True, 'ảnh_hưởng': True, 'đến': True, 'người': True, 'khác': True, 'kể_cả': True, 'xung_quanh': True, 'trường': True}, True Label: negative, Predicted Label: negative
# Context: {'nơi': True, 'đào_tạo': True, 'kinh_tế': True, 'uy_tín': True, 'và': True, 'chất_lượng': True}, True Label: positive, Predicted Label: positive
# Context: {'nơi': True, 'đào_tạo': True, 'nhiều': True, 'nhà': True, 'kinh_tế': True, 'doanh_nghiệp': True, 'trẻ': True, 'có': True, 'uy_tín': True, 'trên': True, 'cả': True, 'nước': True}, True Label: positive, Predicted Label: positive
# Context: {'cơ_sở': True, 'vật_chất': True, 'xịn': True, 'xò': True}, True Label: positive, Predicted Label: positive
# Context: {'một': True, 'cơ_sở': True, 'đẹp': True, 'phong_cách': True, 'hiện_đại': True}, True Label: positive, Predicted Label: positive
# Context: {'tuyệt': True}, True Label: positive, Predicted Label: positive
# Context: {'dịch': True, 'covid': True, 'nên': True, 'xem_lại': True, 'ảnh': True, 'cũ': True, 'thấy': True, 'nhớ': True, 'trường': True, 'bạn_bè': True, 'và': True, 'thầy': True, 'cô': True, 'mình': True, 'ra': True, '6': True, 'năm': True, 'rồi': True, 'cơ_sở': True, 'cũng': True, 'ít': True, 'được': True, 'học': True, 'nhưng': True, 'có': True, 'dịp': True, 'là': True, 'qua': True, 'sớm': True, 'để': True, 'ngồi': True, 'chỗ': True, 'hồ': True, 'nước': True, 'sau_này': True, 'về': True, 'tham_dự': True, 'event': True, 'của': True, 'mấy': True, 'bạn': True, 'sinh_viên': True, 'mời': True, 'mới': True, 'cơ_hội': True, 'ngắm': True, 'khu': True, 'tầng': True, 'thượng': True, 'lần': True, 'lên': True, 'tận': True, 'nóc': True, 'nhìn': True, 'xuyên': True, 'con': True, 'rùa': True, 'hơi': True, 'bị': True, 'vui': True, 'haha': True}, True Label: positive, Predicted Label: negative
# Context: {'đẹp': True, 'sạch_sẽ': True}, True Label: positive, Predicted Label: positive
# Context: {'good': True}, True Label: positive, Predicted Label: positive
# Context: {'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'đẹp': True, 'trải': True, 'nghiệm': True, 'tốt': True, 'thoải_mái': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'ngày_càng': True, 'đẹp': True}, True Label: positive, Predicted Label: positive
# Context: {'khu': True, 'b2': True, 'của': True, 'trường': True, 'ban_đêm': True, 'trông': True, 'như': True, 'khách_sạn': True, '5': True, 'sao': True}, True Label: positive, Predicted Label: negative
# Context: {'mình': True, 'luôn': True, 'tự_hào': True, 'được': True, 'tốt_nghiệp': True, 'từ': True, 'đại_học': True, 'kinh_tế': True, 'tphcm': True}, True Label: positive, Predicted Label: positive
# Context: {'rất': True, 'ok': True}, True Label: positive, Predicted Label: positive
# Context: {'rất': True, 'yên': True, 'tĩnhcực': True, 'kì': True, 'an_ninh': True, 'thoáng': True, 'mát': True, 'rộng_rãi': True, 'nhân_viên': True, 'dễ_thương': True, 'ân_cần': True, 'chu_đáo': True, 'hỗ_trợ': True, 'tư_vấn': True, 'chuyên_nghiệp': True, 'phòng': True, 'sạch_sẽ': True, 'gọn_gàng': True, 'giá_cả': True, 'hợp_lý': True, 'có': True, 'bãi': True, 'xe_hơi': True, 'xe_máy': True}, True Label: positive, Predicted Label: negative
# Context: {'super': True, 'university': True, 'must': True, 'join': True}, True Label: positive, Predicted Label: positive
# Context: {'tốt': True}, True Label: positive, Predicted Label: positive
# Context: {'chất_lượng': True, 'giảng_dạy': True, 'hàng': True, 'đầutuyệt': True, 'vời': True}, True Label: positive, Predicted Label: positive
# Context: {'thư_viện': True, 'xịn': True, 'xò': True}, True Label: positive, Predicted Label: positive
# Context: {'11h': True, 'đêm': True, 'còn': True, 'mở': True, 'nhạc': True, 'ầm_ầm': True, 'ko': True, 'cho': True, 'dân_cư': True, 'ngủ': True, 'trường_học': True, 'hay': True, 'chỗ': True, 'thác_loạn': True}, True Label: negative, Predicted Label: negative
# Context: {'giảng_viên': True, 'không': True, 'có': True, 'tinh_thần': True, 'phòng_ban': True, 'làm_việc': True, 'kém': True, 'môi_trường_học_tập': True, 'độc_hại': True, 'sinh_viên': True, 'sân': True, 'si': True}, True Label: negative, Predicted Label: negative
# Context: {'great': True, 'university': True}, True Label: positive, Predicted Label: positive
# Context: {'cool': True, 'space': True}, True Label: positive, Predicted Label: positive
# Context: {'đẹp': True}, True Label: positive, Predicted Label: positive
# Context: {'enough': True, 'equipment': True, 'practice': True}, True Label: negative, Predicted Label: positive
# Context: {'excellent': True, 'environment': True, 'good': True, 'campus': True, 'fully': True, 'equipped': True, 'educational': True, 'facilities': True}, True Label: positive, Predicted Label: positive
# Context: {'yêu': True, 'thích': True}, True Label: positive, Predicted Label: positive
# Context: {'thật': True, 'tuyệt_vời': True}, True Label: positive, Predicted Label: positive
# Context: {'nơi': True, 'nên': True, 'đến': True}, True Label: positive, Predicted Label: positive
# Context: {'good': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'rộng_rãi': True, 'thoáng': True, 'mát': True, 'bãi': True, 'đậu': True, 'xe': True, 'môi_trường': True, 'thân_thiện': True}, True Label: positive, Predicted Label: positive
# Context: {'ok': True}, True Label: positive, Predicted Label: positive
# Context: {'chuẩn': True}, True Label: positive, Predicted Label: positive
# Context: {'các': True, 'bạn': True, 'sinh_viên': True, 'rất': True, 'tuyệt_vời': True}, True Label: positive, Predicted Label: positive
# Context: {'nơi': True, 'đáng': True, 'sống': True}, True Label: positive, Predicted Label: positive
# Context: {'sạch_sẽ': True}, True Label: positive, Predicted Label: positive
# Context: {'good': True, 'education': True, 'enviroment': True, 'highly': True, 'recommended': True}, True Label: positive, Predicted Label: positive
# Context: {'ở': True, 'ktx': True, 'vui': True, 'lắm': True, 'các': True, 'bạn': True, 'sv': True, 'trẻ': True, 'nên': True, 'trải': True, 'nghiệm': True, 'thử': True}, True Label: positive, Predicted Label: negative
# Context: {'ngôi': True, 'trường': True, 'có': True, 'đội_ngũ': True, 'giáo_viên': True, 'giỏi': True, 'nhiệt_tình': True, 'và': True, 'vô_cùng': True, 'dễ_thương': True, '…': True}, True Label: positive, Predicted Label: negative
# Context: {'khá': True, 'rộng': True, 'và': True, 'sạch': True, 'đẹp': True}, True Label: positive, Predicted Label: positive
# Context: {'trường': True, 'cạnh': True, 'bờ': True, 'sông': True, 'thoáng': True, 'mát': True, 'giảng_viên': True, 'nhiệt_tình': True, 'vui_vẻ': True}, True Label: positive, Predicted Label: positive
# Context: {'xanh': True, 'sạch': True, 'đẹp': True, 'cơ_sở': True, 'vật_chất': True, 'hiện_đại': True, 'xịn': True, 'xò': True}, True Label: positive, Predicted Label: positive
# Context: {'giảng_viên': True, 'không': True, 'có': True, 'tinh_thần': True, 'phòng_ban': True, 'làm_việc': True, 'kém': True, 'môi_trường_học_tập': True, 'độc_hại': True, 'sinh_viên': True, 'sân': True, 'si': True}, True Label: negative, Predicted Label: negative
# Context: {'chổ': True, 'này': True, 'dễ': True, 'tìm': True}, True Label: positive, Predicted Label: negative
# Context: {'12h': True, 'trả': True, 'phòng': True, 'trễ': True, '15': True, 'phút': True, 'phạt': True, '50k': True, 'cứng_nhắc': True, 'mọi': True, 'ng': True, 'cân_nhắc': True, 'khi': True, 'đặt': True, 'chỗ': True, 'này': True, 'ở': True, 'resort': True, 'cũng': True, 'chẳng': True, 'tới': True, 'mức': True, 'quá_đáng': True, 'như': True}, True Label: negative, Predicted Label: negative
# Context: {'ok': True}, True Label: positive, Predicted Label: positive
# Context: {'ktx': True, 'ngày_xưa': True, 'hơi': True, 'cũ': True, 'nhưng': True, '2019': True, 'đã': True, 'khoác': True, 'lên': True, 'mình': True, 'bộ': True, 'đồ': True, 'mới': True, 'rồi': True, 'khang_trang': True, 'hơn': True, 'sạch_sẽ': True, 'hiện_đại': True, 'đẹp': True, 'tiện_nghi': True, 'và': True, 'nội_quy': True, 'cũng': True, 'gắt_gao': True, 'phòng': True, 'bình_thường': True, 'là': True, '9ng': True, 'giường': True, '3': True, 'tầng': True, 'mỗi': True, 'ng': True, 'có': True, 'bàn': True, 'học': True, 'hộc': True, 'tủ': True, 'khóa': True, 'riêng': True, 'wc': True, 'tắm': True, '2': True, 'bồn': True, 'rửa': True, 'mặt': True, 'cửa_sổ': True, 'rộng': True, 'tự': True, 'giặt': True, 'sấy': True, 'khu': True, 'họ': True, 'ở': True, 'lầu': True, '1': True, 'bình': True, 'nấu': True, 'nước': True, 'nóng': True, 'uống': True, 'lạnh': True, 'thang_máy': True, 'đi_lại': True, 'máy_lạnh': True, 'muốn': True, 'vô': True, 'phải': True, 'qua': True, 'cửa': True, 'bảo_vệ': True, 'nên': True, 'an_ninh': True, 'bãi': True, 'gửi': True, 'xe_máy': True, 'giá': True, 'sinh_viên': True, 'trệt': True, 'pgd': True, 'của': True, 'ocb': True, 'kết_thúc': True, '4': True, 'năm': True, 'sv': True, 'nơi': True, 'này': True, 'vs': True, 'cả': True, 'đều': True, 'nhiều': True, 'kỉ_niệm': True, 'chúc': True, 'bền': True, 'lâu': True, 'phát_triển': True, 'my': True, 'saigons': True, 'house': True}, True Label: positive, Predicted Label: negative
# time: 69.8 ms (started: 2023-12-22 12:12:59 +00:00)

# %% [markdown]
# ### Áp dụng dự đoán

# %%
while True:
    text = input('> Hãy nhập câu bất kỳ: ')
    if text.lower() == 'end':
        break
    else:
        sentiment = predict_sentiment(text,'en')
        print(f'Kết quả dự đoán: {sentiment}\n')
# Out:
# > Hãy nhập câu bất kỳ: Yes sỉ
# Kết quả dự đoán: positive
#
# > Hãy nhập câu bất kỳ: end
# time: 9.45 s (started: 2023-12-22 12:13:02 +00:00)

# %%
while True:
    text = input('> Hãy nhập câu bất kỳ: ')
    if text.lower() == 'end':
        break
    else:
        sentiment = predict_sentiment(text,'vn')
        print(f'Kết quả dự đoán: {sentiment}\n')
# Out:
# > Hãy nhập câu bất kỳ: no
# Kết quả dự đoán: positive
#
# > Hãy nhập câu bất kỳ: end
# time: 7.48 s (started: 2023-12-22 12:13:14 +00:00)

# %% [markdown]
# ##Maxent Classifier

# %% [markdown]
# ###Huấn luyện mô hình

# %%
classifier = MaxentClassifier.train(train_data, trace=3, algorithm='iis', max_iter=50)
# Out:
#   ==> Training (50 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.866
#              2          -0.34073        0.900
#              3          -0.27419        0.943
#              4          -0.24059        0.957
#              5          -0.21844        0.967
#              6          -0.20195        0.970
#              7          -0.18884        0.976
#              8          -0.17797        0.978
#              9          -0.16871        0.982
#             10          -0.16068        0.982
#             11          -0.15362        0.982
#             12          -0.14734        0.984
#             13          -0.14170        0.987
#             14          -0.13660        0.991
#             15          -0.13195        0.993
#             16          -0.12770        0.993
#             17          -0.12379        0.993
#             18          -0.12017        0.993
#             19          -0.11681        0.993
#             20          -0.11369        0.993
#             21          -0.11076        0.993
#             22          -0.10802        0.993
#             23          -0.10545        0.993
#             24          -0.10302        0.993
#             25          -0.10073        0.996
#             26          -0.09856        0.996
#             27          -0.09650        0.996
#             28          -0.09454        0.996
#             29          -0.09269        0.996
#             30          -0.09091        0.997
#             31          -0.08922        0.997
#             32          -0.08761        0.997
#             33          -0.08606        0.997
#             34          -0.08458        0.997
#             35          -0.08316        0.997
#             36          -0.08180        0.997
#             37          -0.08049        0.997
#             38          -0.07923        0.997
#             39          -0.07801        0.997
#             40          -0.07684        0.997
#             41          -0.07572        0.997
#             42          -0.07463        0.997
#             43          -0.07358        0.997
#             44          -0.07256        0.997
#             45          -0.07158        0.997
#             46          -0.07062        0.997
#             47          -0.06970        0.997
#             48          -0.06881        0.997
#             49          -0.06794        0.997
#          Final          -0.06710        0.997
# time: 1min 20s (started: 2023-12-22 12:13:24 +00:00)

# %%
#Sử dụng mô hình cho tập train
predicted_labels_train = [classifier.classify(example[0]) for example in train_data]
true_labels_train = [example[1] for example in train_data]
# Out:
# time: 18.6 ms (started: 2023-12-22 12:14:44 +00:00)

# %%
#Sử dụng mô hình cho tập test
predicted_labels_test = [classifier.classify(example[0]) for example in test_data]
true_labels_test = [example[1] for example in test_data]
# Out:
# time: 8.17 ms (started: 2023-12-22 12:14:44 +00:00)

# %% [markdown]
# ### Đánh giá mô hình

# %%
#Tính các tham số đánh giá trên tập train
accuracy_train = accuracy_score(true_labels_train, predicted_labels_train)
precision_train = precision_score(true_labels_train, predicted_labels_train, average='weighted')
recall_train = recall_score(true_labels_train, predicted_labels_train, average='weighted')
f1_train = f1_score(true_labels_train, predicted_labels_train, average='weighted')
#Tính các tham số đánh giá trên tập test
accuracy_test = accuracy_score(true_labels_test, predicted_labels_test)
precision_test = precision_score(true_labels_test, predicted_labels_test, average='weighted')
recall_test = recall_score(true_labels_test, predicted_labels_test, average='weighted')
f1_test = f1_score(true_labels_test, predicted_labels_test, average='weighted')
# Out:
# time: 25.5 ms (started: 2023-12-22 12:15:01 +00:00)

# %%
an_test , pn_test, rn_test, fn_test =  cal_neg_score(true_labels_test, predicted_labels_test, ['negative', 'positive'])
an_train , pn_train, rn_train, fn_train =  cal_neg_score(true_labels_train, predicted_labels_train, ['negative', 'positive'])
# Out:
# time: 5.43 ms (started: 2023-12-22 12:15:07 +00:00)

# %%
from prettytable import PrettyTable
myTable = PrettyTable(['Metrics','P_Train' , 'P_Test', 'N_train', 'N_test'])
myTable.add_row(['Accuracy', accuracy_train, accuracy_test, an_train, an_test])
myTable.add_row(['Precision', precision_train, precision_test, pn_train, pn_test])
myTable.add_row(['recall', recall_train, recall_test, rn_train, rn_test])
myTable.add_row(['f1', f1_train, f1_test, fn_train, fn_test])
print('Bảng đánh giá')
print(myTable)
# Out:
# Bảng đánh giá
# +-----------+--------------------+--------------------+--------------------+---------------------+
# |  Metrics  |      P_Train       |       P_Test       |      N_train       |        N_test       |
# +-----------+--------------------+--------------------+--------------------+---------------------+
# |  Accuracy | 0.9970238095238095 | 0.893491124260355  | 0.9970238095238095 |  0.893491124260355  |
# | Precision | 0.9970340019569471 | 0.8817080355541894 |        1.0         |  0.6666666666666666 |
# |   recall  | 0.9970238095238095 | 0.893491124260355  | 0.9777777777777777 | 0.43478260869565216 |
# |     f1    | 0.9970096418315626 | 0.883699781999377  | 0.9887640449438202 |  0.5263157894736841 |
# +-----------+--------------------+--------------------+--------------------+---------------------+
# time: 19.4 ms (started: 2023-12-22 12:15:09 +00:00)

# %%
le = LabelEncoder()
true_labels_encoded = le.fit_transform(true_labels_test)
predicted_labels_encoded = le.transform(predicted_labels_test)

cm = confusion_matrix(true_labels_encoded, predicted_labels_encoded)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Ma trận nhầm lẫn cho Maxent Classifier')
plt.show()
# Out:
# time: 359 ms (started: 2023-12-22 12:39:19 +00:00)

# %% [markdown]
# ### Áp dụng dự đoán

# %%
new_context = "Giảng viên tệ, không hết mình"
predicted_sentiment = predict_sentiment(new_context, 'vn')
print(f"Predicted Sentiment for '{new_context}': {predicted_sentiment}")
new_context1 = "Sinh viên ồn ào, bãi xe chật chội"
predicted_sentiment1 = predict_sentiment(new_context1, 'vn')
print(f"Predicted Sentiment for '{new_context1}': {predicted_sentiment1}")
new_context2 = "One of the best university in VietNam"
predicted_sentiment2 = predict_sentiment(new_context2, 'en')
print(f"Predicted Sentiment for '{new_context2}': {predicted_sentiment2}")
new_context3 = "Trường học khang trang mát mẻ, chất lượng đào tạo tốt"
predicted_sentiment3 = predict_sentiment(new_context3, 'vn')
print(f"Predicted Sentiment for '{new_context3}': {predicted_sentiment3}")
new_context4 = "Chất lượng giảng đường không tốt, không khí ngột ngạt"
predicted_sentiment4 = predict_sentiment(new_context4, 'vn')
print(f"Predicted Sentiment for '{new_context4}': {predicted_sentiment4}")
# Out:
# Predicted Sentiment for 'Giảng viên tệ, không hết mình': negative
# Predicted Sentiment for 'Sinh viên ồn ào, bãi xe chật chội': negative
# Predicted Sentiment for 'One of the best university in VietNam': positive
# Predicted Sentiment for 'Trường học khang trang mát mẻ, chất lượng đào tạo tốt': positive
# Predicted Sentiment for 'Chất lượng giảng đường không tốt, không khí ngột ngạt': positive
# time: 31.4 ms (started: 2023-12-22 12:15:22 +00:00)

# %% [markdown]
# ##CNN & biLSTM

# %% [markdown]
# ###Huấn luyện mô hình

# %%
df = pd.DataFrame({'nội dung': df['pre_context'], 'nhãn': df['sentiment']})
df = df.dropna().reset_index(drop=True)
df
# Out:
#                                               nội dung      nhãn
# 0    trường sạch đẹp giảng viên dễ thươngchương trì...  positive
# 1    cơ sở vật chất hiện đại thật tuyệt vời 1 trườn...  positive
# 2    ngôi trường có đội ngũ giáo viên giỏi nhiệt tì...  positive
# 3    hay tự ý đổi lịch học của học sinh nhưng nhìn ...  positive
# 4    truong rat dep có sân bóng chuyền cầu lông bón...  positive
# ..                                                 ...       ...
# 836  best school town economics huge placement oppo...  positive
# 837  excellent university world class education bes...  positive
# 838  new campus really good big parking space prett...  positive
# 839  excellent environment good campus fully equipp...  positive
# 840     one best universities vietnam great time place  positive
#
# [841 rows x 2 columns]
# time: 19.7 ms (started: 2023-12-22 12:15:30 +00:00)

# %%
df.nunique()
# Out:
# nội dung    714
# nhãn          2
# dtype: int64
# time: 8.73 ms (started: 2023-12-22 12:15:34 +00:00)

# %%
# nhân bản câu tiếng Việt để train cả có dấu và không dấu
input_pre = []
label_pre = []
text = df['nội dung'].values
label = df['nhãn'].values
for i, data in enumerate(text):
    input_text = list(tf.keras.preprocessing.text.text_to_word_sequence(data))
    input_text = ' '.join(input_text)
    if any(char > 127 for char in map(ord, data)):
        input_text_accent = ViTokenizer.tokenize(input_text)
        input_text_no_accent = str(ViUtils.remove_accents(input_text).decode('utf-8'))
        input_pre.extend([input_text_accent, input_text_no_accent])
        label_pre.extend([label[i], label[i]])
    else:
        input_pre.append(input_text)
        label_pre.append(label[i])
print(len(input_pre))
input_pre
# Out:
# 1475
# ['trường sạch đẹp giảng_viên dễ thươngchương trình học tốt from ueher 43',
#  'truong sach dep giang vien de thuongchuong trinh hoc tot from ueher 43',
#  'cơ_sở vật_chất hiện_đại thật tuyệt_vời 1 trường đại_học lớn của miền nam',
#  'co so vat chat hien dai that tuyet voi 1 truong dai hoc lon cua mien nam',
#  'ngôi trường có đội_ngũ giáo_viên giỏi nhiệt_tình và vô_cùng dễ_thương …',
#  'ngoi truong co doi ngu giao vien gioi nhiet tinh va vo cung de thuong ...',
#  'hay tự_ý đổi lịch học của học_sinh nhưng nhìn_chung rất là tốt gud gud',
#  'hay tu y doi lich hoc cua hoc sinh nhung nhin chung rat la tot gud gud',
#  'truong rat dep có sân bóng_chuyền cầu_lông bóng_đá nữa mình rất yêu ý',
#  'truong rat dep co san bong chuyen cau long bong da nua minh rat yeu y',
#  'cơ_sở vật_chất hiện_đại không_gian xanh và thoáng mọi người thân_thiện',
#  'co so vat chat hien dai khong gian xanh va thoang moi nguoi than thien',
#  'được mỗi cái cơ_sở này là đây đủ tiện_nghi và giống cái trường_học nhất',
#  'duoc moi cai co so nay la day du tien nghi va giong cai truong hoc nhat',
#  'trường rộng_rãi thoáng mát bãi đậu xe rộng_rãi môi_trường thân_thiện',
#  'truong rong rai thoang mat bai dau xe rong rai moi truong than thien',
#  'nơi đào_tạo các chuyên_ngành kinh_tế uy tính của khu_vực tphồ chí minh',
#  'noi dao tao cac chuyen nganh kinh te uy tinh cua khu vuc tpho chi minh',
#  'cơ_sở vật_chất bên campus này là xịn nhứt lunnn đã dữ lắm bà_con uiiii',
#  'co so vat chat ben campus nay la xin nhut lunnn da du lam ba con uiiii',
#  'nơi đào_tạo nhiều nhà kinh_tế doanh_nghiệp trẻ có uy_tín trên cả nước',
#  'noi dao tao nhieu nha kinh te doanh nghiep tre co uy tin tren ca nuoc',
#  'là trường đại_học đào_tạo cử_nhân kinh_tế tốt nhất hiện_nay ở việt_nam',
#  'la truong dai hoc dao tao cu nhan kinh te tot nhat hien nay o viet nam',
#  'ai muốn tài_chính ổn_định trong tương_lai nên chọn trường đại_học này',
#  'ai muon tai chinh on dinh trong tuong lai nen chon truong dai hoc nay',
#  'nơi đào_tạo những cử_nhân nhà quản_lý tương_lai chất_lượng hàng_đầu',
#  'noi dao tao nhung cu nhan nha quan ly tuong lai chat luong hang dau',
#  'là một trong các đại_học uy_tín ở tphcm cũng như cả nước',
#  'la mot trong cac dai hoc uy tin o tphcm cung nhu ca nuoc',
#  'cơ_sở vật_chất hiện_đại sạch_sẽ vô_cùng học_sinh thân_thiện 1000đ',
#  'co so vat chat hien dai sach se vo cung hoc sinh than thien 1000d',
#  'ký_túc_xá nằm vị_trí trung_tâm thoáng mát tiện_nghi và an_ninh',
#  'ky tuc xa nam vi tri trung tam thoang mat tien nghi va an ninh',
#  'chất_lượng giảng_dạy cao nhiều phong_trào hoạt_động cho sinh_viên',
#  'chat luong giang day cao nhieu phong trao hoat dong cho sinh vien',
#  'ngôi trường rất đẹp và tui rất thích nét văn_hóa nơi này',
#  'ngoi truong rat dep va tui rat thich net van hoa noi nay',
#  'một nơi đào_tạo tuyệt_vời chuyên_ngành kinh_tế luật quản_lý',
#  'mot noi dao tao tuyet voi chuyen nganh kinh te luat quan ly',
#  'cơ_sở vật_chất trường quá xịn xò luôn nè tự_hào là một sv ueh',
#  'co so vat chat truong qua xin xo luon ne tu hao la mot sv ueh',
#  'trường mới khang_trang yên_tĩnh nằm trên đường nguyễn văn linh',
#  'truong moi khang trang yen tinh nam tren duong nguyen van linh',
#  'trường hàng_đầu trong hoạt_động đào_tạo lình vực kinh_doanh',
#  'truong hang dau trong hoat dong dao tao linh vuc kinh doanh',
#  'học học nữa học mãi học đến khi nào cạn_kiệt thì_thôi',
#  'hoc hoc nua hoc mai hoc den khi nao can kiet thi thoi',
#  'thư_viện cực_kì xịn xò với cơ_sở vật_chất hiện_đại nè …',
#  'thu vien cuc ki xin xo voi co so vat chat hien dai ne ...',
#  'giá quá rẻ chất_lượng tương_đối ổn một thời không_thể quên',
#  'gia qua re chat luong tuong doi on mot thoi khong the quen',
#  'cơ_sở khang_trang nhiều hoạt_động ngoại khóa cho sinh_viên',
#  'co so khang trang nhieu hoat dong ngoai khoa cho sinh vien',
#  'trường xịn chất_lượng giảng_dạy tốt giảng_viên cute',
#  'truong xin chat luong giang day tot giang vien cute',
#  'rộng_rãi thoáng mát đội_ngũ nhân_viên chuyên_nghiệp',
#  'rong rai thoang mat doi ngu nhan vien chuyen nghiep',
#  'mình luôn tự_hào được tốt_nghiệp từ đại_học kinh_tế tphcm',
#  'minh luon tu hao duoc tot nghiep tu dai hoc kinh te tphcm',
#  'trường thì khỏi phải chê rùi ạ csvc top đầu nha yêu ueh',
#  'truong thi khoi phai che rui a csvc top dau nha yeu ueh',
#  'trường khang_trang rộng_rãi khá ghen_tị với sinh_viên ueh',
#  'truong khang trang rong rai kha ghen ti voi sinh vien ueh',
#  'thầy mới bạn mới trường mới kiến_thức mới tuyệt_vời',
#  'thay moi ban moi truong moi kien thuc moi tuyet voi',
#  'khá là xịn xò bãi xe dưới hầm khá rộng bảo_vệ thân_thiện',
#  'kha la xin xo bai xe duoi ham kha rong bao ve than thien',
#  'quy_mô lớn giáo duc tốt hệ_thống thông_tin tốt',
#  'quy mo lon giao duc tot he thong thong tin tot',
#  'rất thích trường này nhưng đáng tiếc thi không đậu huhu',
#  'rat thich truong nay nhung dang tiec thi khong dau huhu',
#  'cơ_sở vật_chất hiện_đại chương_trình đào_tạo tiên_tiến',
#  'co so vat chat hien dai chuong trinh dao tao tien tien',
#  'sinh_viên trường ra đường đứng làm tắc_nghẽn giao_thông',
#  'sinh vien truong ra duong dung lam tac nghen giao thong',
#  'quá khang_trang quá hiện_đại thân_thiện với môi_trường',
#  'qua khang trang qua hien dai than thien voi moi truong',
#  'chất_lượng đào_tạo tốt tự_hào là sinh_viên của trường',
#  'chat luong dao tao tot tu hao la sinh vien cua truong',
#  'trụ_sở chính nên có hội_trường rất rộng cho sinh_viên',
#  'tru so chinh nen co hoi truong rat rong cho sinh vien',
#  'top 1000 trường đào_tạo kinh_doanh tốt nhất thế_giới',
#  'top 1000 truong dao tao kinh doanh tot nhat the gioi',
#  'trường đại_học hàng_đầu về kinh_tế thương_mại ở tphcm',
#  'truong dai hoc hang dau ve kinh te thuong mai o tphcm',
#  'oktrường đào_tạo những doanh_nhân thành đạt042022',
#  'oktruong dao tao nhung doanh nhan thanh dat042022',
#  'môi_trường rất tốt để các bạn sinh_viên phát_triển',
#  'moi truong rat tot de cac ban sinh vien phat trien',
#  'đẹp thoáng nhưng tiền gửi xe khá mắc hình_như 4k',
#  'dep thoang nhung tien gui xe kha mac hinh nhu 4k',
#  'một ngôi trường mà phải công_nhận top đầu việt_nam',
#  'mot ngoi truong ma phai cong nhan top dau viet nam',
#  'cơ_sở này bé lại hay kẹt xe nói_chung là khó đi',
#  'co so nay be lai hay ket xe noi chung la kho di',
#  'khu_vực trước cửa ktx khá lộn_xộn và không an_toàn',
#  'khu vuc truoc cua ktx kha lon xon va khong an toan',
#  'hiện_đại nhưng hơi nóng tìm thùng rác hơi khó',
#  'hien dai nhung hoi nong tim thung rac hoi kho',
#  'cơ_sở vật_chất hiện_đại nhưng bãi gửi xe_hơi đông',
#  'co so vat chat hien dai nhung bai gui xe hoi dong',
#  'trường dạy về kinh_tế khá nổi_tiếng của thành_phố',
#  'truong day ve kinh te kha noi tieng cua thanh pho',
#  'cơ_sở mới duy_tu_sửa_chữa mới đẹp hơn sạch_sẽ',
#  'co so moi duy tu sua chua moi dep hon sach se',
#  'môi_trường_học_thuật cực tốt giảng_viên uyên_bác',
#  'moi truong hoc thuat cuc tot giang vien uyen bac',
#  'từng ở đây 4 năm quảng đời sv không_thể_nào quên',
#  'tung o day 4 nam quang doi sv khong the nao quen',
#  'cơ_sở mới xây trước mặt nguyễn tri phương rất đẹp',
#  'co so moi xay truoc mat nguyen tri phuong rat dep',
#  'trường tốt nhưng la trường ko biết có việc_làm ko',
#  'truong tot nhung la truong ko biet co viec lam ko',
#  'hiện đai sạch sẽ chất_lượng giáo_dục tuyệt_vời',
#  'hien dai sach se chat luong giao duc tuyet voi',
#  'cơ_sở vật_chất hiện_đại chất_lượng giảng_dạy tốt',
#  'co so vat chat hien dai chat luong giang day tot',
#  'một thời đã xa 25 năm vẫn không thay_đổi nhiều',
#  'mot thoi da xa 25 nam van khong thay doi nhieu',
#  'môi_trường_học_tập sạch_sẽ đẹp thoáng',
#  'moi truong hoc tap sach se dep thoang',
#  'trường đại_học đào_tạo kinh_tế hàng_đầu việt_nam',
#  'truong dai hoc dao tao kinh te hang dau viet nam',
#  'trường tôi đã học chất_lượng giảng_dạy quá tốt',
#  'truong toi da hoc chat luong giang day qua tot',
#  'thông_minh hiện_đại khoa_học chuyên_nghiệp',
#  'thong minh hien dai khoa hoc chuyen nghiep',
#  'trường của mình giáo_viên nhiệt_tình tận_tâm',
#  'truong cua minh giao vien nhiet tinh tan tam',
#  'không_gian sạch_sẽ thoáng_đãng và hiền đai',
#  'khong gian sach se thoang dang va hien dai',
#  'học_phí cao cơ_sở vật_chất đẹp tốt rộng_rãi',
#  'hoc phi cao co so vat chat dep tot rong rai',
#  'trường rất đẹp hiện_đại_tự_hào là một ueher',
#  'truong rat dep hien dai tu hao la mot ueher',
#  'khu tự học b2 b1 hiện_đại sạch_sẽ rộng_rãi',
#  'khu tu hoc b2 b1 hien dai sach se rong rai',
#  'trường cơ_sở cải_tiến đẹp chất_lượng cao',
#  'truong co so cai tien dep chat luong cao',
#  'trường lâu_đời nhiều sinh_viên trong ngành',
#  'truong lau doi nhieu sinh vien trong nganh',
#  'trường đại_học tốt địa_chỉ gần hồ con rùa',
#  'truong dai hoc tot dia chi gan ho con rua',
#  'không_gian thoáng_đãng thích_hợp học_tập',
#  'khong gian thoang dang thich hop hoc tap',
#  'môi_trường tuyệt_vời phòng học hiện_đại',
#  'moi truong tuyet voi phong hoc hien dai',
#  'thích và hứa_hẹn sẽ thi đỗ vào trường này',
#  'thich va hua hen se thi do vao truong nay',
#  'đào_tạo oke mà đông sinh_viên trong 1 lớp',
#  'dao tao oke ma dong sinh vien trong 1 lop',
#  'trường rất đẹp ngày nào cũng chạy ngang',
#  'truong rat dep ngay nao cung chay ngang',
#  'trường đào_tạo tốt nhiều chứng_chỉ có_ích',
#  'truong dao tao tot nhieu chung chi co ich',
#  'cố_gắng học tốt nhái love my school3',
#  'co gang hoc tot nhai love my school3',
#  'cơ_sở hạ_tầng mới sang_trọng rộng_rãi',
#  'co so ha tang moi sang trong rong rai',
#  'trường này buỗi tối bị quán nhậu vây kín',
#  'truong nay buoi toi bi quan nhau vay kin',
#  'chất_lượng giảng_dạy hàng đầutuyệt vời',
#  'chat luong giang day hang dautuyet voi',
#  'nhân_viên giữ xe cơ_sở vật_chất khá tệ',
#  'nhan vien giu xe co so vat chat kha te',
#  'ueh môi_trường năng_động cho sinh_viên',
#  'ueh moi truong nang dong cho sinh vien',
#  'nơi đào_tạo kinh_tế uy_tín và chất_lượng',
#  'noi dao tao kinh te uy tin va chat luong',
#  'trường mới đẹp và nhiều ct hay hữu_ích',
#  'truong moi dep va nhieu ct hay huu ich',
#  'sinh_viên rất ý_thức không nghẽn đường',
#  'sinh vien rat y thuc khong nghen duong',
#  'ktx gần trung_tâm mà phòng_ốc tốt nhất',
#  'ktx gan trung tam ma phong oc tot nhat',
#  'lúc này gọn_gàng sạch_sẽ hơn nhiều rồi',
#  'luc nay gon gang sach se hon nhieu roi',
#  'trường rất đẹp và hiện_đại bên trong',
#  'truong rat dep va hien dai ben trong',
#  'đại_học tốt nhất miền nam love it',
#  'dai hoc tot nhat mien nam love it',
#  'đại_học nổi_tiếng tại tp hồ chí minh',
#  'dai hoc noi tieng tai tp ho chi minh',
#  'tuyệt_vời ngôi trường tầm_cỡ quốc tê',
#  'tuyet voi ngoi truong tam co quoc te',
#  'trường quá xịn xò lun chất_lượng 10 ₫',
#  'truong qua xin xo lun chat luong 10',
#  'xịn xò thậc sự nhưng ghéc trường …',
#  'xin xo thac su nhung ghec truong ...',
#  'quanh khu_vực này vẫn hơi mất an_ninh',
#  'quanh khu vuc nay van hoi mat an ninh',
#  'uy_tín chất_lượng lơn nhất miền nam',
#  'uy tin chat luong lon nhat mien nam',
#  'good đây là cơ_sở lâu_đời nên khá cũ',
#  'good day la co so lau doi nen kha cu',
#  'ngôi trường rất đẹp và nhiều cây_xanh',
#  'ngoi truong rat dep va nhieu cay xanh',
#  'trường đang xây lại chắc sẽ đẹp lắm',
#  'truong dang xay lai chac se dep lam',
#  'sao thấy toàn dây_điện gớm_vậy',
#  'sao thay toan day dien gom vay',
#  'các bạn sinh_viên rất tuyệt_vời',
#  'cac ban sinh vien rat tuyet voi',
#  'công_viên văn_minh học_viên lịch_sự',
#  'cong vien van minh hoc vien lich su',
#  'trường đào_tạo chất_lượng nổi_tiếng',
#  'truong dao tao chat luong noi tieng',
#  'tuyệt_vời cơ_sở vật_chất hiện_đại',
#  'tuyet voi co so vat chat hien dai',
#  'vị_trí siêu đẹp mình học đây ra mà',
#  'vi tri sieu dep minh hoc day ra ma',
#  'con mình học ở đây trường dạy tôt',
#  'con minh hoc o day truong day tot',
#  'thương_hiệu đào_tạo tại phía nam',
#  'thuong hieu dao tao tai phia nam',
#  'trường xây mới rất đẹp và hiện_đại',
#  'truong xay moi rat dep va hien dai',
#  'sức chứa hội_trường lớn 500 người',
#  'suc chua hoi truong lon 500 nguoi',
#  'một cơ_sở đẹp phong_cách hiện_đại',
#  'mot co so dep phong cach hien dai',
#  'trường khá tốt nhưng hơi bất_cập',
#  'truong kha tot nhung hoi bat cap',
#  'đào_tạo sinh_viên chất_lượng cao',
#  'dao tao sinh vien chat luong cao',
#  'trường mình v hong dám chê hahaa',
#  'truong minh v hong dam che hahaa',
#  'thích vô trường này học quá',
#  'thich vo truong nay hoc qua',
#  'ngôi trường thân_yêu tuyệt_vời',
#  'ngoi truong than yeu tuyet voi',
#  'thích_hợp cho các bạn trong nam',
#  'thich hop cho cac ban trong nam',
#  'trường đạo tạo chất_lượng tốt',
#  'truong dao tao chat luong tot',
#  'đẹp trải nghiệm tốt thoải_mái',
#  'dep trai nghiem tot thoai mai',
#  'trường đào_tạo tốt chuẩn 5 sao',
#  'truong dao tao tot chuan 5 sao',
#  'giáo_viên nhiều kinh_nghiệm',
#  'giao vien nhieu kinh nghiem',
#  'đại_học hàng_đầu vn về kinh_tế',
#  'dai hoc hang dau vn ve kinh te',
#  'phòng rẻ nhưng k có thang_máy',
#  'phong re nhung k co thang may',
#  'đẹp rộng mà hơi xa trung_tâm',
#  'dep rong ma hoi xa trung tam',
#  'môi_trường tốt để học_tập …',
#  'moi truong tot de hoc tap ...',
#  'nắng cực xa_xôi lắm picachu',
#  'nang cuc xa xoi lam picachu',
#  'trường đẹpcơ sở vật_chất tốt',
#  'truong depco so vat chat tot',
#  'xịn quá nhìn phát mê luôn …',
#  'xin qua nhin phat me luon ...',
#  'cơ_sở vật_chất vô_cùng xịn xò',
#  'co so vat chat vo cung xin xo',
#  'cơ_sở trang thiết_bị tân_tiến',
#  'co so trang thiet bi tan tien',
#  'thêm 1 đánh_giá tốt cho ueh',
#  'them 1 danh gia tot cho ueh',
#  'khang_trang dễ tìm địa_chỉ',
#  'khang trang de tim dia chi',
#  'căn tin là tuyệt_vời nhất',
#  'can tin la tuyet voi nhat',
#  'nice place for students …',
#  'nice place for students ...',
#  'hiện_đại_tiện_nghi sạch_sẽ',
#  'hien dai tien nghi sach se',
#  'khuôn_viên trường đẹp 3',
#  'khuon vien truong dep 3',
#  'rộng rãirất đẹp và sạch_sẽ',
#  'rong rairat dep va sach se',
#  'môi_trường_học_tập lý_tưởng',
#  'moi truong hoc tap ly tuong',
#  'em 2k1 rất yêu thích trường',
#  'em 2k1 rat yeu thich truong',
#  'ở đây đi_lại rất thuận_tiện',
#  'o day di lai rat thuan tien',
#  'ueh cơ_sở b chất_lượng nhất',
#  'ueh co so b chat luong nhat',
#  'nơi đào_tạo chất_lượng cao',
#  'noi dao tao chat luong cao',
#  'trường mình học tuyệt_vời',
#  'truong minh hoc tuyet voi',
#  'chưa thấy công_trình nào',
#  'chua thay cong trinh nao',
#  'cơ_sở mới xây đẹp hiện_đại',
#  'co so moi xay dep hien dai',
#  'trường bây_giờ rất đẹp',
#  'truong bay gio rat dep',
#  'cơ_sở đào_tạo giáo_dục tốt',
#  'co so dao tao giao duc tot',
#  'đào_tạo các ngành kế_toán',
#  'dao tao cac nganh ke toan',
#  'chất_lượng giảng_dạy tốt',
#  'chat luong giang day tot',
#  'trường đại_học nổi_tiếng',
#  'truong dai hoc noi tieng',
#  'sạch đẹp hơn xưa nhiều',
#  'sach dep hon xua nhieu',
#  'nhà_xe lúc_nào cũng chật',
#  'nha xe luc nao cung chat',
#  'hiện_nay đã cũ hơn nhiều',
#  'hien nay da cu hon nhieu',
#  'trường thiếu chỗ gửi xe',
#  'truong thieu cho gui xe',
#  'vị_trí đẹp ko có bãi xe',
#  'vi tri dep ko co bai xe',
#  'địa_điểm_chuẩn 5 sao',
#  'dia diem chuan 5 sao',
#  'đẹp rộng_rãi sang_trọng',
#  'dep rong rai sang trong',
#  'ngày_càng chuyên_nghiệp',
#  'ngay cang chuyen nghiep',
#  'cơ_sở xịn xog tuyệt_vời',
#  'co so xin xog tuyet voi',
#  'cơ_sở vật_chất hiện_đại',
#  'co so vat chat hien dai',
#  'trường khá đẹp rộng_rãi',
#  'truong kha dep rong rai',
#  'trường rộng thoáng mát',
#  'truong rong thoang mat',
#  'rất vui rất sinh_viên',
#  'rat vui rat sinh vien',
#  'rất đẹp trường xịn xò',
#  'rat dep truong xin xo',
#  'tuyệt_vời ông mặt_trời',
#  'tuyet voi ong mat troi',
#  'đào_tạo chất_lượng cao',
#  'dao tao chat luong cao',
#  'trường dạy rất tốt',
#  'truong day rat tot',
#  'trường đào_tạo uy_tín',
#  'truong dao tao uy tin',
#  'cơ_sở vật_chất xịn xò',
#  'co so vat chat xin xo',
#  'phù_hợp cho sinh_viên',
#  'phu hop cho sinh vien',
#  'nhìn bên ngoài thích',
#  'nhin ben ngoai thich',
#  'sạch_sẽ và thoáng mát',
#  'sach se va thoang mat',
#  'khu tự học tuyệt_vời',
#  'khu tu hoc tuyet voi',
#  'kiến_trúc cổ rất đẹp',
#  'kien truc co rat dep',
#  'khá rộng và sạch đẹp',
#  'kha rong va sach dep',
#  'ở đây tuyệt_vời lắm',
#  'o day tuyet voi lam',
#  'khuôn_viên sạch đẹp',
#  'khuon vien sach dep',
#  'trường top đầu tphcm',
#  'truong top dau tphcm',
#  'cơ_sở chật kẹt xe',
#  'co so chat ket xe',
#  'khuôn_viên hơi chật',
#  'khuon vien hoi chat',
#  'hiện_đại_tiện_nghi',
#  'hien dai tien nghi',
#  'một ngôi trường tốt',
#  'mot ngoi truong tot',
#  'mới sửa lại rất đẹp',
#  'moi sua lai rat dep',
#  'cơ_sở vật_chất tốt',
#  'co so vat chat tot',
#  'ancient university',
#  'sạch_sẽ thoáng mát',
#  'sach se thoang mat',
#  'mái trường mến_yêu',
#  'mai truong men yeu',
#  'thuc an ngon bổ rẻ',
#  'thuc an ngon bo re',
#  'cơ_sở mới rất rộng',
#  'co so moi rat rong',
#  'trường kinh_tế tốt',
#  'truong kinh te tot',
#  'trường khá cũ rồi',
#  'truong kha cu roi',
#  'cơ_sở vật_chất tốt',
#  'co so vat chat tot',
#  'nhieu ki niem dep',
#  'thuận_tiện đi_lại',
#  'thuan tien di lai',
#  'thật_sự là vui_vẻ',
#  'that su la vui ve',
#  'ký_túc_xá rất cũ',
#  'ky tuc xa rat cu',
#  'đẹp thân_thiện',
#  'dep than thien',
#  'trường_học tốt',
#  'truong hoc tot',
#  'sạch_sẽ thơm_tho',
#  'sach se thom tho',
#  'tốt khỏi bàn rồi',
#  'tot khoi ban roi',
#  'đầy để tiện_nghi',
#  'day de tien nghi',
#  'quá đẹp 212022',
#  'qua dep 212022',
#  'tốt cho giới trẻ',
#  'tot cho gioi tre',
#  'trường mình xịnn',
#  'truong minh xinn',
#  'great university',
#  'wa tuyet i will',
#  'trường cổ_kính',
#  'truong co kinh',
#  'nice university',
#  'rộng thoáng mát',
#  'rong thoang mat',
#  'nice university',
#  'thật tuyệt_vời',
#  'that tuyet voi',
#  'ueh tuyệt_vời',
#  'ueh tuyet voi',
#  'dạy tốt học tốt',
#  'day tot hoc tot',
#  'thư_viện proooo',
#  'thu vien proooo',
#  'best university',
#  'ko như mong_đợi',
#  'ko nhu mong doi',
#  'trường tui học',
#  'truong tui hoc',
#  'trường rất tốt',
#  'truong rat tot',
#  'chổ này dễ tìm',
#  'cho nay de tim',
#  'chật hơi bẩn',
#  'chat hoi ban',
#  'trường quá xịn',
#  'truong qua xin',
#  'siêuuuu vipppp',
#  'sieuuuu vipppp',
#  'chất_lượng tốt',
#  'chat luong tot',
#  'trường rất đẹp',
#  'truong rat dep',
#  'sang xịn mịn',
#  'sang xin min',
#  'chuyên_nghiệp',
#  'chuyen nghiep',
#  'cơ_sở này đẹp',
#  'co so nay dep',
#  'đẹp sạch_sẽ',
#  'dep sach se',
#  'rất tuyệt_vời',
#  'rat tuyet voi',
#  'sạch và sang',
#  'sach va sang',
#  'dung dia diem',
#  'đào_tạo chuẩn',
#  'dao tao chuan',
#  'rất là ok nha',
#  'rat la ok nha',
#  'hơi lộn_xộn',
#  'hoi lon xon',
#  'đúng địa_điểm',
#  'dung dia diem',
#  'cũng tam_nha',
#  'cung tam nha',
#  'trường chuẩn',
#  'truong chuan',
#  'vật_chất tốt',
#  'vat chat tot',
#  'quá là okeee',
#  'qua la okeee',
#  'rất hài_lòng',
#  'rat hai long',
#  'sang xịn mịn',
#  'sang xin min',
#  'chấp_nhận dc',
#  'chap nhan dc',
#  'dung vi tri',
#  'ueh 10 điểm',
#  'ueh 10 diem',
#  'đào_tạo tốt',
#  'dao tao tot',
#  'đào_tạo tốt',
#  'dao tao tot',
#  'rất sạch_sẽ',
#  'rat sach se',
#  'nơi nên đến',
#  'noi nen den',
#  'trường đẹp',
#  'truong dep',
#  'tuyệt vờiii',
#  'tuyet voiii',
#  'dịch_vụ tốt',
#  'dich vu tot',
#  'đào_tạo tốt',
#  'dao tao tot',
#  'tốt',
#  'tot',
#  'trường đẹp',
#  'truong dep',
#  'trường đẹp',
#  'truong dep',
#  'truong dep',
#  'thoáng mát',
#  'thoang mat',
#  'trường tốt',
#  'truong tot',
#  'sạch_sẽ',
#  'sach se',
#  'trường đẹp',
#  'truong dep',
#  'trường mới',
#  'truong moi',
#  'trường tốt',
#  'truong tot',
#  'trường tốt',
#  'truong tot',
#  'khoáng_mát',
#  'khoang mat',
#  'trường tốt',
#  'truong tot',
#  'trường top',
#  'truong top',
#  'big campus',
#  'green vibe',
#  'đẹp rộng',
#  'dep rong',
#  'tuyệt_vời',
#  'tuyet voi',
#  'excellent',
#  'tuyệt_vời',
#  'tuyet voi',
#  'chính_xác',
#  'chinh xac',
#  'tuyệt_vời',
#  'tuyet voi',
#  'tuyệt_dời',
#  'tuyet doi',
#  'tiện_nghi',
#  'tien nghi',
#  'wonderful',
#  'tuyet voi',
#  'rất tuyệt',
#  'rat tuyet',
#  'tạm thôi',
#  'tam thoi',
#  'hài_lòng',
#  'hai long',
#  'xuất_sắc',
#  'xuat sac',
#  'được đẹp',
#  'duoc dep',
#  'khá đẹp',
#  'kha dep',
#  'dạy tốt',
#  'day tot',
#  'rất tốt',
#  'rat tot',
#  'ok good',
#  'rất đẹp',
#  'rat dep',
#  'khá tốt',
#  'kha tot',
#  'rất tốt',
#  'rat tot',
#  'an ninh',
#  'rất tốt',
#  'rat tot',
#  'csvc cũ',
#  'csvc cu',
#  'rất tốt',
#  'rat tot',
#  'xịn xịn',
#  'xin xin',
#  'đẹp ghê',
#  'dep ghe',
#  'rất ok',
#  'rat ok',
#  'khá ổn',
#  'kha on',
#  'tuyệt',
#  'tuyet',
#  'chuẩn',
#  'chuan',
#  'tuyệt',
#  'tuyet',
#  'thích',
#  'thich',
#  'tuyệt',
#  'tuyet',
#  'được',
#  'duoc',
#  'cx đc',
#  'cx dc',
#  'tuyệt',
#  'tuyet',
#  'chuẩn',
#  'chuan',
#  'tụyt',
#  'tuyt',
#  'giỏi',
#  'gioi',
#  'được',
#  'duoc',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'hay',
#  'tốt',
#  'tot',
#  'god',
#  'đẹp',
#  'dep',
#  'đẹp',
#  'dep',
#  'tốt',
#  'tot',
#  'tạm',
#  'tam',
#  'tốt',
#  'tot',
#  '…',
#  '...',
#  'đẹp',
#  'dep',
#  'đẹp',
#  'dep',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'đẹp',
#  'dep',
#  '…',
#  '...',
#  'xịn',
#  'xin',
#  'đẹp',
#  'dep',
#  'đẹp',
#  'dep',
#  'tốt',
#  'tot',
#  'đẹp',
#  'dep',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'đẹp',
#  'dep',
#  'đẹp',
#  'dep',
#  'tốt',
#  'tot',
#  'nơi đào_tạo uy_tín chất_lượng tốt đã được khẳng_định với các ngành về kinh_tế của miền nam',
#  'noi dao tao uy tin chat luong tot da duoc khang dinh voi cac nganh ve kinh te cua mien nam',
#  'nơi đáng sống',
#  'noi dang song',
#  'đại_học tui mà',
#  'dai hoc tui ma',
#  'rất tốt',
#  'rat tot',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'tốt',
#  'tot',
#  'sạch_sẽ',
#  'sach se',
#  'xấu',
#  'xau',
#  'đhkt tphồ chí minh là cơ_sở đào_tạo đại_học và sau đại_học các ngành về kinh_tế hàng_đầu của vn nơi đây có đội_ngũ giao sư có chuyên_môn cao giáo_trình liên_tục cập_nhật và quan_hệ tốt với các trường đại_học và tổ_chức quốc_tế trường đã đạo tạo rất nhiều nhân_sự trình_độ chuyên_môn cao cho nền quốc giatuy nhiên cơ_sở vật_chất manh_mún nhỏ_lẻ và cũ_kỹ không tương_xứng với tầm_vóc và giá_trị của nó mang lại',
#  'dhkt tpho chi minh la co so dao tao dai hoc va sau dai hoc cac nganh ve kinh te hang dau cua vn noi day co doi ngu giao su co chuyen mon cao giao trinh lien tuc cap nhat va quan he tot voi cac truong dai hoc va to chuc quoc te truong da dao tao rat nhieu nhan su trinh do chuyen mon cao cho nen quoc giatuy nhien co so vat chat manh mun nho le va cu ky khong tuong xung voi tam voc va gia tri cua no mang lai',
#  'xanh sạch đẹp',
#  'xanh sach dep',
#  'là ký_túc_xá khá lâu_đời của sinh_viên trường đại_học kinh_tế tp hồ chí minh khoảng_cách từ ký_túc_xá đến trường khá gần có_thể đi bộ sau một thời_gian xuống_cấp ký_túc_xá đã được cải_tạo một phần tuy_nhiên khu_vực chung quang ký_túc_xá khá phức_tạp gái ngành hoạt_động ầm_ầm thậm_chí ký_túc_xá mở căn tin ngay mặt tiền_đường nguyễn chí thanh nên không tránh khỏi các thành_phần khác nhau trong xã_hội có_thể tụ_tập trong căn tin này',
#  'la ky tuc xa kha lau doi cua sinh vien truong dai hoc kinh te tp ho chi minh khoang cach tu ky tuc xa den truong kha gan co the di bo sau mot thoi gian xuong cap ky tuc xa da duoc cai tao mot phan tuy nhien khu vuc chung quang ky tuc xa kha phuc tap gai nganh hoat dong am am tham chi ky tuc xa mo can tin ngay mat tien duong nguyen chi thanh nen khong tranh khoi cac thanh phan khac nhau trong xa hoi co the tu tap trong can tin nay',
#  'một môi_trường quá hoàn_hảo cho việc trau_dồi kiến_thức giúp_ích cho bản_thân và xã_hội sau_này',
#  'mot moi truong qua hoan hao cho viec trau doi kien thuc giup ich cho ban than va xa hoi sau nay',
#  'ktx xanh sạch đẹp quá iii thui',
#  'ktx xanh sach dep qua iii thui',
#  'rất yên tĩnhcực kì an_ninh thoáng mát rộng_rãi nhân_viên dễ_thương ân_cần chu_đáo hỗ_trợ tư_vấn chuyên_nghiệp phòng sạch_sẽ gọn_gàng giá_cả hợp_lý có bãi xe_hơi xe_máy',
#  'rat yen tinhcuc ki an ninh thoang mat rong rai nhan vien de thuong an can chu dao ho tro tu van chuyen nghiep phong sach se gon gang gia ca hop ly co bai xe hoi xe may',
#  'truong dai hoc',
#  'trường không rõ_ràng khi đăng thông_tin tuyển_dụng của vb2đhcq trong thông_tin tuyển_dụng nêu thời_gian học các buổi tối từ 246 hoặc 357 tuy_nhiên không nêu rõ sẽ học chung với chính_quy vào ban_ngày khi không đủ số_lượng đã chọn học vb2 phần_lớn đều là người đi làm nhưng lịch học ban_ngày thì sao tham_gia được đến kì học thứ 3 thì thời khóa biểu xếp học với chính_quy thì có phải là bỏ con giữa chợ không sao không đề_cập ngay từ đầu thì làm gì có ai đăng_ký xét tuyển nữa đợi học hết 2 kì rồi mới nói có thông_báo rộng_rãi đúng lừa_đảo mà',
#  'truong khong ro rang khi dang thong tin tuyen dung cua vb2dhcq trong thong tin tuyen dung neu thoi gian hoc cac buoi toi tu 246 hoac 357 tuy nhien khong neu ro se hoc chung voi chinh quy vao ban ngay khi khong du so luong da chon hoc vb2 phan lon deu la nguoi di lam nhung lich hoc ban ngay thi sao tham gia duoc den ki hoc thu 3 thi thoi khoa bieu xep hoc voi chinh quy thi co phai la bo con giua cho khong sao khong de cap ngay tu dau thi lam gi co ai dang ky xet tuyen nua doi hoc het 2 ki roi moi noi co thong bao rong rai dung lua dao ma',
#  'yêu thích',
#  'yeu thich',
#  'cơ_sở tốt',
#  'co so tot',
#  'trường đẹp',
#  'truong dep',
#  'đỉnh của đỉnh',
#  'dinh cua dinh',
#  'place not dep',
#  'trường đại_học kinh_tế thành_phố hồ chí minh tiếng anh university of economics ho chi minh city hiện_nay cơ_sở vật_chất của trường hiện_đại_hội_trường rộng nhiều chỗ ngồi là nơi tổ_chức nhiều buổi lễ cũng như nhiều hoạt_động của sinh_viên và nhà trườngngoài ra còn có hệ_thống máy_lạnh đền chiếu sáng và đáp_ứng nhiều nhu_cầu đa_dạng của sinh_viên cũng như giáo_viên tại hội_trường chính có khu tiếp khách riêng và sảnh chờ rộng_lớn',
#  'truong dai hoc kinh te thanh pho ho chi minh tieng anh university of economics ho chi minh city hien nay co so vat chat cua truong hien dai hoi truong rong nhieu cho ngoi la noi to chuc nhieu buoi le cung nhu nhieu hoat dong cua sinh vien va nha truongngoai ra con co he thong may lanh den chieu sang va dap ung nhieu nhu cau da dang cua sinh vien cung nhu giao vien tai hoi truong chinh co khu tiep khach rieng va sanh cho rong lon',
#  'bảo_vệ thân_thiện vui_vẻ',
#  'bao ve than thien vui ve',
#  'top những điều nên làm khi học đại_học kinh_tế top 01 ở ktx',
#  'top nhung dieu nen lam khi hoc dai hoc kinh te top 01 o ktx',
#  'bãi xe_hơi nhỏ phòng học nhỏ',
#  'bai xe hoi nho phong hoc nho',
#  'xinh_xắn sạch_sẽ xịn xò',
#  'xinh xan sach se xin xo',
#  'ngoi truong hang mo uoc',
#  'trường nhìn cũng khá là đẹp',
#  'truong nhin cung kha la dep',
#  'cơ_sở này thật_sự khá rộng so với các cơ_sở khác thuộc ueh tòa nhà rất cao với thư_viện thông_minh chứa đa_số các sách và tài_liệu của ueh cơ_sở với sân trường rất rộng là một nơi vô_cùng phù_hợp để tổ_chức các lễ_hội chương_trình ngoài_ra thì trên tòa nhà còn được gắn đèn led để phát sáng vào buổi tối',
#  'co so nay that su kha rong so voi cac co so khac thuoc ueh toa nha rat cao voi thu vien thong minh chua da so cac sach va tai lieu cua ueh co so voi san truong rat rong la mot noi vo cung phu hop de to chuc cac le hoi chuong trinh ngoai ra thi tren toa nha con duoc gan den led de phat sang vao buoi toi',
#  'tô phở to vị vừa ăn',
#  'to pho to vi vua an',
#  'trường đại_học kinh_tế tp hồ chí minh số 59c nguyễn đình chiểu là trường trong top trường công_danh_tiếng của việt nam tọa_lạc tại quận 3 trung_tâm tp hồ chí minh với đội_ngũ giảng_viên uy_tín và giàu kinh_nghiệm cơ_sở vật_chất khang tranh và hiện đạitọa lạc tại quận 3 trung_tâm tp hồ chí minh',
#  'truong dai hoc kinh te tp ho chi minh so 59c nguyen dinh chieu la truong trong top truong cong danh tieng cua viet nam toa lac tai quan 3 trung tam tp ho chi minh voi doi ngu giang vien uy tin va giau kinh nghiem co so vat chat khang tranh va hien daitoa lac tai quan 3 trung tam tp ho chi minh',
#  'thư_viện xịn xò',
#  'thu vien xin xo',
#  'nơi mang lại tri_thức',
#  'noi mang lai tri thuc',
#  'là trường nổi_tiếng trong khối kinh_tế ở sài_gòn nhiều cử_nhân đã tốt_nghiệp ở đây và làm khởi_nghiệp thành_công_trường giảng_dạy các lớp chính_quy đại_học bổ_túc tín_chỉ chuyển_đổi từ kỹ_sư sang kinh_tế các lớp cao_học thạc sỹ tiến_sỹ chất_lượng giảng_dạy tốt học_phí phù_hợp đặc_biệt có các lớp giảng_dạy 100 tiếng anh',
#  'la truong noi tieng trong khoi kinh te o sai gon nhieu cu nhan da tot nghiep o day va lam khoi nghiep thanh cong truong giang day cac lop chinh quy dai hoc bo tuc tin chi chuyen doi tu ky su sang kinh te cac lop cao hoc thac sy tien sy chat luong giang day tot hoc phi phu hop dac biet co cac lop giang day 100 tieng anh',
#  'là trường_học của tôi',
#  'la truong hoc cua toi',
#  'nhìn cũ nên sửa lại cho đẹp',
#  'nhin cu nen sua lai cho dep',
#  'kí_túc_xá đại_học kinh_tế quốc_gia nằm gần trường đại_học nông_lâm nếu ai đi từ sài_gòn về hướng suối tiên thì kia túc_xá sẽ nằm bên tay_trái còn ngược_lại thì nằm bên tay phảituy nhiên có 1 lưu_ý khi đi từ sài_gòn xuống thì nên dừng xe lại ngay nút cổng trường nông_lâm và chịu_khó đi ngược chiều khoảng 500m bên trái sẽ có đường lớn lát nhựa khá rộngko nên đi xuống suối tiên rồi quay đầu lại vì khá xa và tắc xekhu vực này xe lơn đi rất đông cũng nguy_hiểm_ko nên mở google map để đi tới đây vì khá là vòng vèobất tiện',
#  'ki tuc xa dai hoc kinh te quoc gia nam gan truong dai hoc nong lam neu ai di tu sai gon ve huong suoi tien thi kia tuc xa se nam ben tay trai con nguoc lai thi nam ben tay phaituy nhien co 1 luu y khi di tu sai gon xuong thi nen dung xe lai ngay nut cong truong nong lam va chiu kho di nguoc chieu khoang 500m ben trai se co duong lon lat nhua kha rongko nen di xuong suoi tien roi quay dau lai vi kha xa va tac xekhu vuc nay xe lon di rat dong cung nguy hiem ko nen mo google map de di toi day vi kha la vong veobat tien',
#  'ngôi trường tuyệt_vời 3',
#  'ngoi truong tuyet voi 3',
#  'trường đại_học kinh_tế bậc nhất tại thành_phố hcm cơ_sở vc xịn sò lễ nhập_học chào_mừng sinh_viên k49 phải nói đỉnh của đỉnh mấy bạn đang tìm_hiểu về trường hãy lên gg search ueh wiki sẽ rõ trường đỉnh cỡ nào',
#  'truong dai hoc kinh te bac nhat tai thanh pho hcm co so vc xin so le nhap hoc chao mung sinh vien k49 phai noi dinh cua dinh may ban dang tim hieu ve truong hay len gg search ueh wiki se ro truong dinh co nao',
#  'trường sau khi xây mới thực_sự rất ấn_tượng hiện_đại đẹp tiện_nghi nơi này có cửa_hàng tiện_lợi ministop ngay đối_diện trên lầu có quán cafe phòng tập gym thư_viện trệt có ngân_hàng ocb khuôn_viên mới rộng có sảnh để trang_trí cho lễ tốt_nghiệp sinh_viên tha_hồ chụp hình_thang_máy và thang bộ tiện_lợi khu vệ_sinh hiện_đại nhưng nhà vệ_sinh nam ở ngay cạnh thang_máy phòng đầu_tiên vòi xít và ngàm đỡ không tương_thích nên vòi xịt luôn_luôn bị rơi xuống nền rất mất vệ_sinh đề_nghị nhân_viên của trường nếu đọc được bình_luận này vui_lòng phản_hồi bộ_phận chịu trách_nhiệm để sửa_chữa làm hoàn_thiện trải nghiệm khách_hàng với dịch_vụ của trường trường kinh_tế nên xây_dựng mới cũng mang tính kinh_tế luôn nhưng tôi thích cách làm này hihi',
#  'truong sau khi xay moi thuc su rat an tuong hien dai dep tien nghi noi nay co cua hang tien loi ministop ngay doi dien tren lau co quan cafe phong tap gym thu vien tret co ngan hang ocb khuon vien moi rong co sanh de trang tri cho le tot nghiep sinh vien tha ho chup hinh thang may va thang bo tien loi khu ve sinh hien dai nhung nha ve sinh nam o ngay canh thang may phong dau tien voi xit va ngam do khong tuong thich nen voi xit luon luon bi roi xuong nen rat mat ve sinh de nghi nhan vien cua truong neu doc duoc binh luan nay vui long phan hoi bo phan chiu trach nhiem de sua chua lam hoan thien trai nghiem khach hang voi dich vu cua truong truong kinh te nen xay dung moi cung mang tinh kinh te luon nhung toi thich cach lam nay hihi',
#  'kí_túc_xá xanh',
#  'ki tuc xa xanh',
#  'medium quality',
#  'trường sịn lắm',
#  'truong sin lam',
#  'ghet',
#  'là cơ_sở đẹp chất và chất_lượng phòng học cao nhất của đại_học kinh_tế các trang thiết_bị mới và hiện_đại phòng học sáng_sủa ghế_ngồi và bàn học thoải_mái tạo cảm_giác dễ_chịu để có_thể tiếp_thu kiến_thức một_cách tốt nhất thanh',
#  'la co so dep chat va chat luong phong hoc cao nhat cua dai hoc kinh te cac trang thiet bi moi va hien dai phong hoc sang sua ghe ngoi va ban hoc thoai mai tao cam giac de chiu de co the tiep thu kien thuc mot cach tot nhat thanh',
#  'trường điểm của việt_nam',
#  'truong diem cua viet nam',
#  'là tân sv uehmình thực_sự rất tự_hào vs truyền_thống và bề dày đào_tạo của trường là một trong những trường trọng_điểm qg và là môi_trường lí_tưởng cho những_ai đã đang và sẽ theo học khối ngành kinh_tế uehk42',
#  'la tan sv uehminh thuc su rat tu hao vs truyen thong va be day dao tao cua truong la mot trong nhung truong trong diem qg va la moi truong li tuong cho nhung ai da dang va se theo hoc khoi nganh kinh te uehk42',
#  'cổng sau gửi xe đại_học kinh_tế tp hcm cơ_sở b số 279 đường ba tháng hai quận 10 từ 2 đến thứ 7 buổi tối lúc 600 pm luôn kẹt xe vì đó là thời_gian bắt_đầu vô_học đi học trước 600 pm đỡ kẹt hơn vô lúc sau 600 pm',
#  'cong sau gui xe dai hoc kinh te tp hcm co so b so 279 duong ba thang hai quan 10 tu 2 den thu 7 buoi toi luc 600 pm luon ket xe vi do la thoi gian bat dau vo hoc di hoc truoc 600 pm do ket hon vo luc sau 600 pm',
#  'trường đại_học kinh_tế cơ_sở b ngay góc đường nguyễn tri phương cơ_sở mới vị_trí đẹp xây_dựng cũng đẹp khu_vực này nhiều quán ăn cafe ăn vặt cho các bạn sinh_viên ban_đêm_trường có mở đẹp toà nhà ấn_tượng',
#  'truong dai hoc kinh te co so b ngay goc duong nguyen tri phuong co so moi vi tri dep xay dung cung dep khu vuc nay nhieu quan an cafe an vat cho cac ban sinh vien ban dem truong co mo dep toa nha an tuong',
#  'môi_trường an_ninh rất tốt',
#  'moi truong an ninh rat tot',
#  'đã có quá_trình được trải nghiệm một trong những trường hàng_đầu vn',
#  'da co qua trinh duoc trai nghiem mot trong nhung truong hang dau vn',
#  'là một trong những trường công_lập đứng đầu về đào_tạo khối ngành kinh_tế và quản_lý tại miền nam việt_nam nổi_bật với giáo_trình được biên_soạn lại từ các đại_học lớn trên thế giớiđồng thời cũng là trung_tâm nghiên_cứu các chính_sách kinh_tế và quản_lý cho chính_phủ và các doanh_nghiệp lớn',
#  'la mot trong nhung truong cong lap dung dau ve dao tao khoi nganh kinh te va quan ly tai mien nam viet nam noi bat voi giao trinh duoc bien soan lai tu cac dai hoc lon tren the gioidong thoi cung la trung tam nghien cuu cac chinh sach kinh te va quan ly cho chinh phu va cac doanh nghiep lon',
#  'trường sạch_sẽ cơ_sở vật_chất khá mới cầ có thẻ mới có_thể vào trường',
#  'truong sach se co so vat chat kha moi ca co the moi co the vao truong',
#  'ước_mơ của e là đậu vào trường này đấy ạ5ting 572000',
#  'uoc mo cua e la dau vao truong nay day a5ting 572000',
#  'ghé vài lần hiện_nay sạch_sẽ hơn nhiều trồng thêm cây_xanh nhìn khác hẳn sinh_viên bây_giờ ở trong môi_trường tốt hơn xưa rất nhiều',
#  'ghe vai lan hien nay sach se hon nhieu trong them cay xanh nhin khac han sinh vien bay gio o trong moi truong tot hon xua rat nhieu',
#  'đẹp mới cơ_sở vật_chất hiện_đại xịn xò',
#  'dep moi co so vat chat hien dai xin xo',
#  'môi_trường_học thân_thiện nhiều cây_xanh thầy cô nhiệt_tình dễ mến',
#  'moi truong hoc than thien nhieu cay xanh thay co nhiet tinh de men',
#  'cơ_sở vật_chất ổn phòng học trang_bị đầy_đủ thầy cô dạy rất tốt tuy_nhiên bãi giữ xe thường sẽ hết chỗ sau 8h30 nên các bạn nên đi sớm và các chú giữ xe cũng không được nhiệt_tình lắm',
#  'co so vat chat on phong hoc trang bi day du thay co day rat tot tuy nhien bai giu xe thuong se het cho sau 8h30 nen cac ban nen di som va cac chu giu xe cung khong duoc nhiet tinh lam',
#  'kí_túc_xá toàn sinh_viên ueh hay có các hoạt_động ngoại_khoá siêu dth nghe bảo ngày_xưa toàn gái_gọi nhưng nay thấy ổn nhiều lắm bảo_vệ cũng chặt nữa ra vào phải quẹt thẻ đó nha',
#  'ki tuc xa toan sinh vien ueh hay co cac hoat dong ngoai khoa sieu dth nghe bao ngay xua toan gai goi nhung nay thay on nhieu lam bao ve cung chat nua ra vao phai quet the do nha',
#  'mảng xanh thật đẹp trong trường',
#  'mang xanh that dep trong truong',
#  'các hoạt_động clb đoàn hội nổi_bật phòng học lạnh hơn trái_tim crush của bạn cơ_sở vật_chất ko có chỗ chê cơ_mà thang_máy hơi tắc',
#  'cac hoat dong clb doan hoi noi bat phong hoc lanh hon trai tim crush cua ban co so vat chat ko co cho che co ma thang may hoi tac',
#  'có rất nhiều câu lạc_bộ tuyển cộng_tác_viên ở đây câu lạc_bộ nào cũng thú_vị trường sạch_sẽ bên ngoài còn có nhiều hàng_quán bán đồ ăn sáng rất ngon …',
#  'co rat nhieu cau lac bo tuyen cong tac vien o day cau lac bo nao cung thu vi truong sach se ben ngoai con co nhieu hang quan ban do an sang rat ngon ...',
#  'chỉ ghé ngang nên không có gì để nói',
#  'chi ghe ngang nen khong co gi de noi',
#  'khuôn_viên trường rộng_rãi sạch đẹp',
#  'khuon vien truong rong rai sach dep',
#  'trường đẹp dạy tốt nằm ngay trung_tâm',
#  'truong dep day tot nam ngay trung tam',
#  'ktx giờ hiện_đại và tiện_nghi hơn xưa',
#  'ktx gio hien dai va tien nghi hon xua',
#  'trường bây_giờ sạch đẹp khang_trang hơn rất nhiều',
#  'truong bay gio sach dep khang trang hon rat nhieu',
#  'đã đến và cảm_nhận rất thích môi_trường_học_tập rèn_luyện đặc_biệt là môi_trường sống xanh ươm trong_lành',
#  'da den va cam nhan rat thich moi truong hoc tap ren luyen dac biet la moi truong song xanh uom trong lanh',
#  'trường tui học đó quá đẹp sang xịn min bây_giờ có thang_máy đầy_đủ r nhé thư_viện to xịn mịn có phòng họp riêng',
#  'truong tui hoc do qua dep sang xin min bay gio co thang may day du r nhe thu vien to xin min co phong hop rieng',
#  'trường nằm sâu ở cuối đường gần bờ sông trường có khá nhiều sinh_viên theo học',
#  'truong nam sau o cuoi duong gan bo song truong co kha nhieu sinh vien theo hoc',
#  'chất_lượng giáo_dục hàng_đầu_cơ_sở hiện_đại',
#  'chat luong giao duc hang dau co so hien dai',
#  'ngoài bảo_vệ khó_tính ra thì mọi thứ khá tốt',
#  'ngoai bao ve kho tinh ra thi moi thu kha tot',
#  'không_gian rộng thoáng không_khí trong_lành',
#  'khong gian rong thoang khong khi trong lanh',
#  'cơ_sở vật_chất hiện_đại chất_lượng giảng_dạy tốt',
#  'co so vat chat hien dai chat luong giang day tot',
#  'phòng nghỉ rất ok không_gian yên_tĩnh thoáng mát rất phù_hợp cho nghỉ_ngơi cuối tuần hoặc cho ai đó không thích ồn_ào',
#  'phong nghi rat ok khong gian yen tinh thoang mat rat phu hop cho nghi ngoi cuoi tuan hoac cho ai do khong thich on ao',
#  'khuôn_viên trường rộng_rãi thoáng mát phòng học khác tiện_ích và hiện_đại cơ_sở vật_chất tốt đáng để các bạn đăng_ký',
#  'khuon vien truong rong rai thoang mat phong hoc khac tien ich va hien dai co so vat chat tot dang de cac ban dang ky',
#  'ở ktx vui lắm các bạn sv trẻ nên trải nghiệm thử',
#  'o ktx vui lam cac ban sv tre nen trai nghiem thu',
#  'chất_lượng tốt khuôn_viên rộng_rãi sạch đẹp nhiều cây_xanh giảng_viên giỏi thân_thiện nhiệt_tình_yêu nơi này',
#  'chat luong tot khuon vien rong rai sach dep nhieu cay xanh giang vien gioi than thien nhiet tinh yeu noi nay',
#  'xanh sạch đẹp cơ_sở vật_chất hiện_đại xịn xò',
#  'xanh sach dep co so vat chat hien dai xin xo',
#  'đã từng đào_tạo rất nhiều người giỏi có_ích cho xã_hội',
#  'da tung dao tao rat nhieu nguoi gioi co ich cho xa hoi',
#  'sạch_sẽ phòng 2 giường đơn có không_gian thoải_mái wifi tốt bàn làm_việc vừa đủ 1 người dùng',
#  'sach se phong 2 giuong don co khong gian thoai mai wifi tot ban lam viec vua du 1 nguoi dung',
#  'nhìn ngoài thì nhỏ trong rất to',
#  'nhin ngoai thi nho trong rat to',
#  'cơ_sở vật_chất đầy_đủ sạch_sẽ mới_đầu mình vào ktx nhìn hành_lang mà mình cứ tưởng khách_sạn ko có đầy_đủ tiện_ích như máy bán nước_máy lọc nước nvs khu giặt sấy phòng tự học vv',
#  'co so vat chat day du sach se moi dau minh vao ktx nhin hanh lang ma minh cu tuong khach san ko co day du tien ich nhu may ban nuoc may loc nuoc nvs khu giat say phong tu hoc vv',
#  'trường đại_học kinh_tế tphcm cơ_sở nam thanh phố tuyệt_vời',
#  'truong dai hoc kinh te tphcm co so nam thanh pho tuyet voi',
#  'cơ_sở hạ_tầng tốt giảng_viên thân_thiện nhiệt_tình khuôn_viên trường đẹp thoáng mát',
#  'co so ha tang tot giang vien than thien nhiet tinh khuon vien truong dep thoang mat',
#  'trường_học sạch_sẽ hiện_đại giảng_viên chất_lượng thân_thiện',
#  'truong hoc sach se hien dai giang vien chat luong than thien',
#  'ki_bo với sinh_viên đi học sớm tý cũng không cho vô lớp_học ngồi sợ tốn điện lời nhân_viên dọn phòng',
#  'ki bo voi sinh vien di hoc som ty cung khong cho vo lop hoc ngoi so ton dien loi nhan vien don phong',
#  'trường cơ_sở vật_chất tốt rộng_rãi đầy_đủ tiện_nghi chương_trình học khá ổn so với mặt_bằng chung ạ',
#  'truong co so vat chat tot rong rai day du tien nghi chuong trinh hoc kha on so voi mat bang chung a',
#  'khum bít mn sao chứ tui ở đây vui vl í',
#  'khum bit mn sao chu tui o day vui vl i',
#  'chỗ gửi xe_hơi cực nhưng bù lại có chỗ tự học bàn ghế quạt đàng_hoàng thầy cô dễ_thương nhiệt_tình',
#  'cho gui xe hoi cuc nhung bu lai co cho tu hoc ban ghe quat dang hoang thay co de thuong nhiet tinh',
#  'trường xanh mát chất_lượng đào_tạo của ueh nên không bàn_cãi',
#  'truong xanh mat chat luong dao tao cua ueh nen khong ban cai',
#  'đời sinh_viên sẽ rất đang tiếc nếu không trải nghiệm 2 điều ở ktx và đi mùa hè xanh',
#  'doi sinh vien se rat dang tiec neu khong trai nghiem 2 dieu o ktx va di mua he xanh',
#  'bên 135 trần hưng đạo nhà để xe chung với các trường khác nhỏ hẹp tối cũ cảm_giác không an_toàn',
#  'ben 135 tran hung dao nha de xe chung voi cac truong khac nho hep toi cu cam giac khong an toan',
#  'không_gian dù rộng nhưng vẫn cảm_giác hơi ngộp có_lẽ do đông sinh_viên và xe_cộ trong trường quá',
#  'khong gian du rong nhung van cam giac hoi ngop co le do dong sinh vien va xe co trong truong qua',
#  'nhiều em sv tại trường năng_động rất ok cũng hay đi dạy kèm',
#  'nhieu em sv tai truong nang dong rat ok cung hay di day kem',
#  'trường cạnh bờ sông thoáng mát giảng_viên nhiệt_tình vui_vẻ',
#  'truong canh bo song thoang mat giang vien nhiet tinh vui ve',
#  'trường mới xây_dựng lại cơ_sở rất đẹp chất_lượng đào_tạo tốt',
#  'truong moi xay dung lai co so rat dep chat luong dao tao tot',
#  'có 7 lầu nhưng không thang_máy đây là máy nhà của sv kt trong 4nam phòng để nghỉ_ngơi và ban_công là nơi tuyệt_vời nhất cho không_gian riêng_tư nuôi cá_cảnh',
#  'co 7 lau nhung khong thang may day la may nha cua sv kt trong 4nam phong de nghi ngoi va ban cong la noi tuyet voi nhat cho khong gian rieng tu nuoi ca canh',
#  'mình có nhỏ em học ở isb đánh_giá cao chương_trình đào_tạo của viện',
#  'minh co nho em hoc o isb danh gia cao chuong trinh dao tao cua vien',
#  'cơ_sở trang thiết_bị hiện_đại giảng_viên giàu kinh_nghiệm một ngôi trường uy_tín',
#  'co so trang thiet bi hien dai giang vien giau kinh nghiem mot ngoi truong uy tin',
#  'ghé đi dự tốt_nghiệp chật_chội nhưng được cái cơ_sở sạch_sẽ hướng_dẫn_nhiệt_tình',
#  'ghe di du tot nghiep chat choi nhung duoc cai co so sach se huong dan nhiet tinh',
#  'ngôi trường đào_tạo ra những nhà kinh_tế góp_phần xây_dựng thị_trường cho đất_nước',
#  'ngoi truong dao tao ra nhung nha kinh te gop phan xay dung thi truong cho dat nuoc',
#  'chất_lượng công_tác hỗ_trợ sv quá tệ ai vô nhớ cân_nhắc',
#  'chat luong cong tac ho tro sv qua te ai vo nho can nhac',
#  'trường_học uy_tín chất_lượng hàng_đầu việt nam tôi đã được đào_tạo bài_bản tại ngôi trường thân_yêu này',
#  'truong hoc uy tin chat luong hang dau viet nam toi da duoc dao tao bai ban tai ngoi truong than yeu nay',
#  'mong_ước sang năm được học tại ngôi trường này i love ueh',
#  'mong uoc sang nam duoc hoc tai ngoi truong nay i love ueh',
#  'ktx ngày_càng khang_trang và tiện_nghi cảm_thấy vui vì từng là thành_viên ở đây',
#  'ktx ngay cang khang trang va tien nghi cam thay vui vi tung la thanh vien o day',
#  'cơ_sở này cũng có wifi mỗi phòng nhưng cũng yếu giảng_đường bự và lắp quạt',
#  'co so nay cung co wifi moi phong nhung cung yeu giang duong bu va lap quat',
#  'chất_lượng phục_vụ tệ_hại hời_hợt rất rất thất_vọng khi đặt niềm tin vào đây',
#  'chat luong phuc vu te hai hoi hot rat rat that vong khi dat niem tin vao day',
#  'thư_viện rất yên_tĩnh cơ_sở vật_chất tốt em rất tự_hào khi là một ueher',
#  'thu vien rat yen tinh co so vat chat tot em rat tu hao khi la mot ueher',
#  'địa_điểm gần những khu ăn_uống thíc hợp cho sinh_viên nghĩ ngơi và học_tập',
#  'dia diem gan nhung khu an uong thic hop cho sinh vien nghi ngoi va hoc tap',
#  'học ở vĩnh long chất_lượng ueh nơi đáng để phụ_huynh gửi niềm tin',
#  'hoc o vinh long chat luong ueh noi dang de phu huynh gui niem tin',
#  'thư_viện và khu tự học đẹp sạch_sẽ máy bán cà_phê tự_động rẻ ngon',
#  'thu vien va khu tu hoc dep sach se may ban ca phe tu dong re ngon',
#  'môi_trường thân_thiện thiết_bị hỗ_trợ học_tập đầy_đủ gv nhiệt_tình',
#  'moi truong than thien thiet bi ho tro hoc tap day du gv nhiet tinh',
#  'trường đã được sửa_chữa đổi_mới trang thiết_bị rất mới khuôn_viên trường giờ không sử_dụng để đậu xe nữa thay vào đó là khoản sân_cỏ rộng và xanh tên trường mới là uehcfvg',
#  'truong da duoc sua chua doi moi trang thiet bi rat moi khuon vien truong gio khong su dung de dau xe nua thay vao do la khoan san co rong va xanh ten truong moi la uehcfvg',
#  'rộng_rãi thoáng máttương lai sẽ là rất đẹp nhưng ghét nhất là đi từ thành_phố lên tới đường nguyễn văn linh rồi đi ngược_lại',
#  'rong rai thoang mattuong lai se la rat dep nhung ghet nhat la di tu thanh pho len toi duong nguyen van linh roi di nguoc lai',
#  'trường đẹp vào trong tạo cảm_giác mình là người tri_thức có học_vấn mà tiếc quá mình là dân xh đen',
#  'truong dep vao trong tao cam giac minh la nguoi tri thuc co hoc van ma tiec qua minh la dan xh den',
#  'trường cũ của minh chất_lượng tốt nếu so_sánh các trường đh trong nước nhiều thầy cô giỏi lắm nha có một điểm hay_là trường có nhiều cơ_sở bạn sẽ được chu du khắp thành_phố trong quá_trình học 4 năm hihi',
#  'truong cu cua minh chat luong tot neu so sanh cac truong dh trong nuoc nhieu thay co gioi lam nha co mot diem hay la truong co nhieu co so ban se duoc chu du khap thanh pho trong qua trinh hoc 4 nam hihi',
#  'trường rất có quy_mô có bãi xe rộng_rãi nhiều tiện_ích cho sinh_viên',
#  'truong rat co quy mo co bai xe rong rai nhieu tien ich cho sinh vien',
#  '12h trả phòng trả trễ 15 phút phạt 50k cứng_nhắc mọi ng cân_nhắc khi đặt chỗ này ở resort cũng chẳng tới mức quá_đáng như này',
#  '12h tra phong tra tre 15 phut phat 50k cung nhac moi ng can nhac khi dat cho nay o resort cung chang toi muc qua dang nhu nay',
#  'cơ_sở khang_trang đang xây_dựng hoàn_thiện chúc các bạn sv ueh rèn_luyện tốt tại đây anh cựu k37 nay ghé về thăm chút mà thấy hoành_tráng quá',
#  'co so khang trang dang xay dung hoan thien chuc cac ban sv ueh ren luyen tot tai day anh cuu k37 nay ghe ve tham chut ma thay hoanh trang qua',
#  'chiếc cầu_nối giữa tòa nhà b2 cổ_kính và b1 hiện_đại tại cơ_sở b ueh đây được xem như là chiếc cầu gắn_kết nhiều thế_hệ với nhau nếu có một dịp ghé ngang b các bạn nhớ vào đây check in nhé',
#  'chiec cau noi giua toa nha b2 co kinh va b1 hien dai tai co so b ueh day duoc xem nhu la chiec cau gan ket nhieu the he voi nhau neu co mot dip ghe ngang b cac ban nho vao day check in nhe',
#  'trường đại_học kinh_tế thành_phố hồ chí minh tiếng anh university of economics ho chi minh city viết tắt ueh khẩu_hiệu nơi đào_tạo nhà quản_lý và doanh_nhân thành_đạt là một trường đại_học chuyên_ngành kinh_tế tại việt nam nằm trong nhóm đại_học trọng_điểm quốc_gia đây là một trụ_cột trong hệ_thống giáo_dục bậc cao của việt_nam và cũng là trung_tâm nghiên_cứu các chính_sách kinh_tế quản_lý cho chính_phủ và các doanh_nghiệp lớn ngoài_ra trường đại_học kinh_tế thành_phố hồ chí minh còn được đánh_giá là một trong 1000 trường đại_học chuyên_ngành kinh_tế kinh_doanh đứng đầu thế_giới theo nhiều tổ_chức xếp_hạng uy_tín chẳng_hạn như eduniversal',
#  'truong dai hoc kinh te thanh pho ho chi minh tieng anh university of economics ho chi minh city viet tat ueh khau hieu noi dao tao nha quan ly va doanh nhan thanh dat la mot truong dai hoc chuyen nganh kinh te tai viet nam nam trong nhom dai hoc trong diem quoc gia day la mot tru cot trong he thong giao duc bac cao cua viet nam va cung la trung tam nghien cuu cac chinh sach kinh te quan ly cho chinh phu va cac doanh nghiep lon ngoai ra truong dai hoc kinh te thanh pho ho chi minh con duoc danh gia la mot trong 1000 truong dai hoc chuyen nganh kinh te kinh doanh dung dau the gioi theo nhieu to chuc xep hang uy tin chang han nhu eduniversal',
#  'trường được xây mới khang_trang hiện_đại hơn nhưng mình vẫn thích những tòa nhà kiến_trúc cổ trước_kia',
#  'truong duoc xay moi khang trang hien dai hon nhung minh van thich nhung toa nha kien truc co truoc kia',
#  'cơ_sở đẹp rộng_rãi thoáng nhất có luôn trạm xe_buýt tiện_lợi chưa có ký_túc_xá tiện_ích xung_quanh kém ít quán_xá dịch_vụ',
#  'co so dep rong rai thoang nhat co luon tram xe buyt tien loi chua co ky tuc xa tien ich xung quanh kem it quan xa dich vu',
#  '11h đêm còn mở nhạc ầm_ầm ko cho dân_cư ngủ trường_học hay chỗ thác_loạn',
#  '11h dem con mo nhac am am ko cho dan cu ngu truong hoc hay cho thac loan',
#  'sau khi sửa thấy ok hơn rất nhiều nếu bây_giờ 5 sao thì lúc trc 1 sao thôi',
#  'sau khi sua thay ok hon rat nhieu neu bay gio 5 sao thi luc trc 1 sao thoi',
#  'rất hài_lòng về chất_lượng đào_tạo và cơ_sở vật_chất học_tập của các chương_trình ở isb',
#  'rat hai long ve chat luong dao tao va co so vat chat hoc tap cua cac chuong trinh o isb',
#  'môi_trường đại_học rất xanh rất lý_tưởng cho việc học_tập và nghiên_cứu',
#  'moi truong dai hoc rat xanh rat ly tuong cho viec hoc tap va nghien cuu',
#  'kinh_hoàng vì bãi xe khi lấy xe để ở tầng hầng b2 là xác_định về hít khói 30 phút trước khi ra đc tới cổng',
#  'kinh hoang vi bai xe khi lay xe de o tang hang b2 la xac dinh ve hit khoi 30 phut truoc khi ra dc toi cong',
#  'đây là ngôi trường đại_học thân_yêu của mình rất may_mắn là mình một khoảng thời_gian được học ở cơ_sở mới khang_trang như thế này mọi thứ đều rất tốt hiện_đại đây cũng chỉ mới hoàn_thiện một phần vì mình thấy trong sảnh n1 có trưng_bày mô_hình khuôn_viên thì nhà_trường còn sẽ xây_dựng thêm nhiều hạng_mục quy_mô hơn như ký_túc_xá các khu_vực chức_năng khác nữa các phòng học được trang_bị đầy_đủ cơ_sở vật_chất hiện_đại rộng_rãi và đặc_biệt không có lạnh nhất chỉ có lạnh hơn cảm_giác mùa hè cũng có_thể đóng_băng đa_số những giảng_viên mà mình được học đều rất tận_tâm và nhiệt_huyết trường top đầu về giáo_dục mà nơi đây còn là nơi diễn ra nhiều hoạt_động lễ_hội vô_cùng sôi_nổi có thư việc rộng thoải_mái có nhiều đầu_sách chuyên_ngành cho sinh_viên đặc_biệt cũng rất lạnh đây thực_sự là một cơ_sở mà theo mình là đẹp và khác_biệt so với các cơ_sở khác đặc_biệt không_gian xanh và khuôn_viên rất rộng',
#  'day la ngoi truong dai hoc than yeu cua minh rat may man la minh mot khoang thoi gian duoc hoc o co so moi khang trang nhu the nay moi thu deu rat tot hien dai day cung chi moi hoan thien mot phan vi minh thay trong sanh n1 co trung bay mo hinh khuon vien thi nha truong con se xay dung them nhieu hang muc quy mo hon nhu ky tuc xa cac khu vuc chuc nang khac nua cac phong hoc duoc trang bi day du co so vat chat hien dai rong rai va dac biet khong co lanh nhat chi co lanh hon cam giac mua he cung co the dong bang da so nhung giang vien ma minh duoc hoc deu rat tan tam va nhiet huyet truong top dau ve giao duc ma noi day con la noi dien ra nhieu hoat dong le hoi vo cung soi noi co thu viec rong thoai mai co nhieu dau sach chuyen nganh cho sinh vien dac biet cung rat lanh day thuc su la mot co so ma theo minh la dep va khac biet so voi cac co so khac dac biet khong gian xanh va khuon vien rat rong',
#  'trường đại_học kinh_tế thành_phố hồ chí minh ueh trong thời_gian gần đây có nhiều bước phát_triển mạnh_mẽ chương_trình học được cập_nhật và mô_phỏng theo chương_trình của các trường đại_học danh_tiếng trên thế_giới tài_liệu học rất đa_dạng đặc_biệt là kho tài_liệu số bao_gồm luận_văn các khoá những bài báo nghiên_cứu khoa_học có chất_lượng và giá_trị tham_khảo cao sách giáo_trình luôn được chiết_khấu cho học_viên',
#  'truong dai hoc kinh te thanh pho ho chi minh ueh trong thoi gian gan day co nhieu buoc phat trien manh me chuong trinh hoc duoc cap nhat va mo phong theo chuong trinh cua cac truong dai hoc danh tieng tren the gioi tai lieu hoc rat da dang dac biet la kho tai lieu so bao gom luan van cac khoa nhung bai bao nghien cuu khoa hoc co chat luong va gia tri tham khao cao sach giao trinh luon duoc chiet khau cho hoc vien',
#  'trường đại_học kinh_tế thành_phố hồ chí minh tên tiếng anh university of economics ho chi minh city ueh là trường đại_học trọng_điểm quốc_gia việt_nam và được tổ_chức eduniversal xếp_hạng 701 trong 1000 trường kinh_tế tốt nhất thế giới1 trường được xem là một trung_tâm đào_tạo và nghiên_cứu khoa_học kinh_tế có uy_tín của toàn_thể việt nam trực_tiếp cung_cấp hàng trăm ngàn cử_nhân thạc_sĩ tiến_sĩ cho cả nước kể_cả cho lào và campuchia2 quy_mô đào_tạo của trường giữ mức ổn_định đạt trên 50000 sinh viênnăm3',
#  'truong dai hoc kinh te thanh pho ho chi minh ten tieng anh university of economics ho chi minh city ueh la truong dai hoc trong diem quoc gia viet nam va duoc to chuc eduniversal xep hang 701 trong 1000 truong kinh te tot nhat the gioi1 truong duoc xem la mot trung tam dao tao va nghien cuu khoa hoc kinh te co uy tin cua toan the viet nam truc tiep cung cap hang tram ngan cu nhan thac si tien si cho ca nuoc ke ca cho lao va campuchia2 quy mo dao tao cua truong giu muc on dinh dat tren 50000 sinh viennam3',
#  'tới đây training cho các em về sơ_cấp_cứu cùng vietdiver các em rất nhiệt_tình',
#  'toi day training cho cac em ve so cap cuu cung vietdiver cac em rat nhiet tinh',
#  'trường đhkt đã có những bước phát_triển quan_trọng trong việc nâng cao chất_lượng đào_tạo thông_qua việc mở_rộng hợp_tác với các trường đại_học tổ_chức giáo_dục quốc_tế tuy_nhiên cần kết_nối nhiều hơn với các doanh_nghiệp lớn trong nước và thế_giới tăng thời_lượng thực_hành tại các doanh_nghiệp cho các sinh_viên học_viên để nâng cao hơn nữa chất_lượng đầu_ra',
#  'truong dhkt da co nhung buoc phat trien quan trong trong viec nang cao chat luong dao tao thong qua viec mo rong hop tac voi cac truong dai hoc to chuc giao duc quoc te tuy nhien can ket noi nhieu hon voi cac doanh nghiep lon trong nuoc va the gioi tang thoi luong thuc hanh tai cac doanh nghiep cho cac sinh vien hoc vien de nang cao hon nua chat luong dau ra',
#  'kỷ_niệm tại trường thời trẻ trâu nhớ thầy cô và các bạn quá giờ chắc đại_gia hết rồi',
#  'ky niem tai truong thoi tre trau nho thay co va cac ban qua gio chac dai gia het roi',
#  'là cơ_sở chính của đại_học kinh_tế tphcm nơi đặt các phòng chức_năng của trường cũng như là nơi diễn ra các sự kiên lớn của trường nên trang thiết_bị cũng như cơ_sở vật_chất ở đây khá đầy_đủ và hiện_đại đặc_biệt thời_gian gần đây trường đã chú_trọng nâng_cấp csvc ở đây các thầy cô ở các phòng hỗ_trợ sinh_viên thì tuy có hơi khó và cằn_nhằn đôi_chút nhưng nhìn_chung vẫn rất nhiệt_tình giúp_đỡ hỗ_trợ sinh_viên thanh',
#  'la co so chinh cua dai hoc kinh te tphcm noi dat cac phong chuc nang cua truong cung nhu la noi dien ra cac su kien lon cua truong nen trang thiet bi cung nhu co so vat chat o day kha day du va hien dai dac biet thoi gian gan day truong da chu trong nang cap csvc o day cac thay co o cac phong ho tro sinh vien thi tuy co hoi kho va can nhan doi chut nhung nhin chung van rat nhiet tinh giup do ho tro sinh vien thanh',
#  'ktx mới xây lại sạch_sẽ rộng_rãi thoáng mát',
#  'ktx moi xay lai sach se rong rai thoang mat',
#  'trường đạt chuẩn is 2022',
#  'truong dat chuan is 2022',
#  'bãi xe quá_tải cơ sơ vật_chất không đáp_ứng cho số_lượng con_người',
#  'bai xe qua tai co so vat chat khong dap ung cho so luong con nguoi',
#  'khu b2 của trường ban_đêm trông như khách_sạn 5 sao',
#  'khu b2 cua truong ban dem trong nhu khach san 5 sao',
#  'gái xinh được',
#  'gai xinh duoc',
#  'gửi xe chật_chội phòng cũ quá',
#  'gui xe chat choi phong cu qua',
#  'excellent',
#  'nơi ở tôt cho sinh_viên',
#  'noi o tot cho sinh vien',
#  'trường đã làm tốt trong công_tác thúc_đẩy phát_triển hoạt_động khởi_nghiệp đặc_biệt là khởi_nghiệp trong sinh_viên',
#  'truong da lam tot trong cong tac thuc day phat trien hoat dong khoi nghiep dac biet la khoi nghiep trong sinh vien',
#  'so bad',
#  'cơ_sở nhỏ_xíu cũ không có thư_viện không có canteen xung_quanh bán ít đồ ăn vặt có nhiều chỗ gửi xe cho sinh_viên chỗ gửi xe trong trường nhỏ ra sớm mà xe để ở trong là thôi rồi khó lấy ra đi trễ là hết chỗ để xe_máy_tính cho giảng_viên xài cũng cũ rồi máy_lạnh cũng hay hư lên hư xuống từ lầu 4 trở lên là ghế gỗ không có chỗ dựa được cái mỗi phòng có wifi riêng cho học_sinh sinh_viên giảng_viên',
#  'co so nho xiu cu khong co thu vien khong co canteen xung quanh ban it do an vat co nhieu cho gui xe cho sinh vien cho gui xe trong truong nho ra som ma xe de o trong la thoi roi kho lay ra di tre la het cho de xe may tinh cho giang vien xai cung cu roi may lanh cung hay hu len hu xuong tu lau 4 tro len la ghe go khong co cho dua duoc cai moi phong co wifi rieng cho hoc sinh sinh vien giang vien',
#  'đơn_giản vì tôi yêu nơi này …',
#  'don gian vi toi yeu noi nay ...',
#  'trường đào_tạo khối ngành kinh_tế hàng_đầu cho kv phía nam và cả nước chất_lượng đào_tạo tốt giá rẻ nhất so với các ngành khác thời_gian học ngắn mau ra trường bước vào đời sớm',
#  'truong dao tao khoi nganh kinh te hang dau cho kv phia nam va ca nuoc chat luong dao tao tot gia re nhat so voi cac nganh khac thoi gian hoc ngan mau ra truong buoc vao doi som',
#  'tôi đóng tiền giữ chổ và đóng luôn tiền học anh văn để đạt đủ điểm ieltsnhưng vì lý_do tài_chính khó_khăn không_thể theo học đượctôi có đến liên_lạc xin nhận lại 1 phần tiền đã đóngnhưng các cô ở đây trả_lời là không có hỗ_trợ trả lại tiềnđó là số tiền lớnmặc dù con tôi chưa học 1 ngày nàochưa nhận 1 tờ giấy hay bất_cứ gì từ trườngthật sự tôi rất bức_xúc và thất vọngmọi người nên cân_nhắc trước khi đóng tiềnđây là hành_vi lừa_đảo chiếm_đoạt tiền trắng_trợn',
#  'toi dong tien giu cho va dong luon tien hoc anh van de dat du diem ieltsnhung vi ly do tai chinh kho khan khong the theo hoc duoctoi co den lien lac xin nhan lai 1 phan tien da dongnhung cac co o day tra loi la khong co ho tro tra lai tiendo la so tien lonmac du con toi chua hoc 1 ngay naochua nhan 1 to giay hay bat cu gi tu truongthat su toi rat buc xuc va that vongmoi nguoi nen can nhac truoc khi dong tienday la hanh vi lua dao chiem doat tien trang tron',
#  'hồi trước thi vào trường có 205 điểm năm nay trường lấy gần bằng ngoại_thương vl',
#  'hoi truoc thi vao truong co 205 diem nam nay truong lay gan bang ngoai thuong vl',
#  'trường dạy tốt kiến_thức chuyên_sâu nhiều hoạt_động ngoại khóa hấp_dẫn',
#  'truong day tot kien thuc chuyen sau nhieu hoat dong ngoai khoa hap dan',
#  'căn tin tương_đối đeph giá thì cũng tạm ổn tại khu_vực trung_tâm',
#  'can tin tuong doi deph gia thi cung tam on tai khu vuc trung tam',
#  'an_ninh tốt vô ngõ_hẻm để đến số 135b',
#  'an ninh tot vo ngo hem de den so 135b',
#  'mình là cựu sinh_viên k26 của trường này tự_hào là ngôi trường đào_tạo đa ngành và 1 trong các trường tạo ra nhiều giám_đốc doanh_nghiệp nhất nước cơ_sở hiện_nay khá khang_trang và sạch_sẽ học_phí cũng cao hơn nhiều so với ngày_xưa mình theo học',
#  'minh la cuu sinh vien k26 cua truong nay tu hao la ngoi truong dao tao da nganh va 1 trong cac truong tao ra nhieu giam doc doanh nghiep nhat nuoc co so hien nay kha khang trang va sach se hoc phi cung cao hon nhieu so voi ngay xua minh theo hoc',
#  'mình đã xác_minh là chỗ này đã đập bỏ rồi mà google không xem_xét là sao đội_ngũ làm_việc có thiếu hiểu_biết thì vừa vừa thôi chứ',
#  'minh da xac minh la cho nay da dap bo roi ma google khong xem xet la sao doi ngu lam viec co thieu hieu biet thi vua vua thoi chu',
#  'trường ở vị_trí gần hồ con rùa phù_hộ cho sinh_viên kinh_tế thôi chứ mấy ní coi chi nhiều à chỗ gửi xe trước trường 10k',
#  'truong o vi tri gan ho con rua phu ho cho sinh vien kinh te thoi chu may ni coi chi nhieu a cho gui xe truoc truong 10k',
#  'cơ_sở vật_chất môi_trường_học_tập tuyệt_vời',
#  'co so vat chat moi truong hoc tap tuyet voi',
#  'trường có nhiều chương_trình học đa_dạng và ngày_càng được mở_rộng em mình đang học và chuẩn_bị đi du_học trong suốt quá_trình đó em mình luôn được hỗ_trợ và thầy cô cũng chú_trọng truyền_đạt những kiến_thức cần_thiết nhất để em mình du_học thuận_lợi nói_chung là rất hài_lòng về trường và các chương_trình ở isb',
#  'truong co nhieu chuong trinh hoc da dang va ngay cang duoc mo rong em minh dang hoc va chuan bi di du hoc trong suot qua trinh do em minh luon duoc ho tro va thay co cung chu trong truyen dat nhung kien thuc can thiet nhat de em minh du hoc thuan loi noi chung la rat hai long ve truong va cac chuong trinh o isb',
#  'giáo_dục quá kém quá khinh ng k trách nghiệm',
#  'giao duc qua kem qua khinh ng k trach nghiem',
#  'ueh môi_trường tốt đào tào nhân_lực khối ngành kinh_tế địa_điểm thuận_lợi có bãi đỗ xe_máy tầng hầm sảnh rộng thoáng sang_trọng có chỗ ngồi chờ',
#  'ueh moi truong tot dao tao nhan luc khoi nganh kinh te dia diem thuan loi co bai do xe may tang ham sanh rong thoang sang trong co cho ngoi cho',
#  'chất lương giảng_dạy tuyệt_vời',
#  'chat luong giang day tuyet voi',
#  'mình học ở đây tuy là cơ_sở này đẹp và rộng hơn các cơ_sở cũ nhưng nó hơi xa đi học mất tầm 20 phút trở lên ở đây có lối đi cho xe_lăn lên lầu 1 trệt nhưng lên lầu tòa n2 chưa có thang_máy',
#  'minh hoc o day tuy la co so nay dep va rong hon cac co so cu nhung no hoi xa di hoc mat tam 20 phut tro len o day co loi di cho xe lan len lau 1 tret nhung len lau toa n2 chua co thang may',
#  'đang xây_dựng sửa_chữa nhưng vẫn cố_tình nhận khách gây ồn_ào không_thể nghỉ_ngơi được wifi rất chậm và chập_chờn ăn sáng cực chán',
#  'dang xay dung sua chua nhung van co tinh nhan khach gay on ao khong the nghi ngoi duoc wifi rat cham va chap chon an sang cuc chan',
#  'đại_học kinh_tế tphcm ueh mình là khoá 43 rất tự_hào về trường',
#  'dai hoc kinh te tphcm ueh minh la khoa 43 rat tu hao ve truong',
#  'hơn 20 năm sống ở sg lần đầu_tiên kẹt xe ở bãi gửi xe cs b xây lại hoành_tráng nhưng bãi xe hệ_thống gửi xe quá tệ hy_vọng nhà_trường cải_thiện sớm',
#  'hon 20 nam song o sg lan dau tien ket xe o bai gui xe cs b xay lai hoanh trang nhung bai xe he thong gui xe qua te hy vong nha truong cai thien som',
#  'mình rất tâm_đắc với đội_ngũ tuyển_sinh đã tư_vấn rất nhiệt_tình và tận_tâm',
#  'minh rat tam dac voi doi ngu tuyen sinh da tu van rat nhiet tinh va tan tam',
#  'đề_nghị nhà_trường xem_xét_lại thái_độ của nhân_viên nữ làm_việc tại ktx thái_độ trơ_trẽn nói_chuyện không ăn_học ảnh_hưởng đến các sinh_viên thái_độ cực_kì tiêu_cực nếu không có biện_pháp nào thì đây là ktx tồi_tệ nhất cho 1 ngày đi học ở ngôi trường này về',
#  'de nghi nha truong xem xet lai thai do cua nhan vien nu lam viec tai ktx thai do tro tren noi chuyen khong an hoc anh huong den cac sinh vien thai do cuc ki tieu cuc neu khong co bien phap nao thi day la ktx toi te nhat cho 1 ngay di hoc o ngoi truong nay ve',
#  'dịch covid nên xem_lại ảnh cũ thấy nhớ trường bạn_bè và thầy cô mình ra trường 6 năm rồi cơ_sở cũng ít được học nhưng có dịp là qua sớm để ngồi chỗ hồ nước sau_này về tham_dự event của mấy bạn sinh_viên mời mới có cơ_hội ngắm khu tầng thượng có lần lên tận nóc trường nhìn xuyên qua hồ con rùa hơi bị vui haha',
#  'dich covid nen xem lai anh cu thay nho truong ban be va thay co minh ra truong 6 nam roi co so cung it duoc hoc nhung co dip la qua som de ngoi cho ho nuoc sau nay ve tham du event cua may ban sinh vien moi moi co co hoi ngam khu tang thuong co lan len tan noc truong nhin xuyen qua ho con rua hoi bi vui haha',
#  ...]
# time: 278 ms (started: 2023-12-22 12:21:03 +00:00)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
lim = 750

seq_len_1 = [len(i.split()) for i in input_pre[:lim]]
sns.histplot(seq_len_1, bins=15, kde=False, ax=axes[0])
axes[0].set_title(f'Độ dài {lim} câu đầu tiên')

seq_len_2 = [len(i.split()) for i in input_pre[lim:]]
sns.histplot(seq_len_2, bins=15, kde=False, ax=axes[1])
axes[1].set_title(f'Độ dài {len(input_pre)-lim} câu cuối cùng')

plt.tight_layout()
plt.show()
# Out:
# time: 1.15 s (started: 2023-12-22 12:21:07 +00:00)

# %%
label_dict = {'negative': 0, 'positive': 1}
label_idx = [label_dict[i] for i in label_pre]
label_tf = tf.keras.utils.to_categorical(label_idx, num_classes=2, dtype='float32')

maxlen_vector = 600
tokenizer_data = Tokenizer(oov_token='<OOV>', filters='', split=' ')
tokenizer_data.fit_on_texts(input_pre)
tokenizer_data_text = tokenizer_data.texts_to_sequences(input_pre)
vec_data = pad_sequences(tokenizer_data_text, padding='post', maxlen=maxlen_vector)

pkl.dump(tokenizer_data, open('tokenizer_data.pkl', 'wb'))

print(f'Dữ liệu đầu vào (số quan sát, số chiều vector): {vec_data.shape}')
data_vocab_size = len(tokenizer_data.word_index)+1
print(f'Vocab size: {data_vocab_size}')

X_train, X_val, y_train, y_val = train_test_split(vec_data, label_tf, test_size=0.2, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
print(f'Số quan sát tập train: {len(X_train)}')
print(f'Số quan sát tập validation: {len(X_val)}')
print(f'Số quan sát tập test: {len(X_test)}')
# Out:
# Dữ liệu đầu vào (số quan sát, số chiều vector): (1475, 600)
# Vocab size: 3532
# Số quan sát tập train: 944
# Số quan sát tập validation: 295
# Số quan sát tập test: 236
# time: 56.5 ms (started: 2023-12-22 12:21:09 +00:00)

# %%
def model():
    dropout_threshold = 0.2
    initializer = tf.keras.initializers.GlorotNormal()
    input_layer = Input(shape=(maxlen_vector,))

    # tạo Embedding để làm input layer
    feature = Embedding(input_dim=data_vocab_size, output_dim=32, input_length=maxlen_vector,
                        embeddings_initializer='GlorotNormal')(input_layer)

    # CNN
    cnn_feature = Conv1D(filters=32, kernel_size=2, padding='same', activation='relu')(feature)
    cnn_feature = MaxPooling1D()(cnn_feature)
    cnn_feature = Dropout(dropout_threshold)(cnn_feature)
    cnn_feature = Conv1D(filters=32, kernel_size=2, padding='same', activation='relu')(cnn_feature)
    cnn_feature = MaxPooling1D()(cnn_feature)
    cnn_feature = LayerNormalization()(cnn_feature)
    cnn_feature = Dropout(dropout_threshold)(cnn_feature)

    # BiLSTM
    bi_lstm_feature = Bidirectional(LSTM(units=32, dropout=dropout_threshold, return_sequences=True,
                                         kernel_initializer=initializer))(feature)
    bi_lstm_feature = MaxPooling1D()(bi_lstm_feature)
    bi_lstm_feature = Bidirectional(LSTM(units=32, dropout=dropout_threshold, return_sequences=True,
                                        kernel_initializer=initializer))(bi_lstm_feature)
    bi_lstm_feature = MaxPooling1D()(bi_lstm_feature)
    bi_lstm_feature = LayerNormalization()(bi_lstm_feature)

    # kết hợp hai model
    combine_feature = tf.keras.layers.Concatenate()([cnn_feature, bi_lstm_feature])
    combine_feature = GlobalMaxPooling1D()(combine_feature)
    combine_feature = LayerNormalization()(combine_feature)

    # các dense layers
    classifier = Dense(70, activation='relu')(combine_feature)
    classifier = Dropout(0.2)(classifier)
    classifier = Dense(50, activation='relu')(classifier)
    classifier = Dropout(0.2)(classifier)
    classifier = Dense(30, activation='relu')(classifier)
    classifier = Dropout(0.2)(classifier)
    classifier = Dense(2, activation='softmax')(classifier)

    # xây dựng mô hình cuối cùng
    model = tf.keras.Model(inputs=input_layer, outputs=classifier)
    return model
# Out:
# time: 1.02 ms (started: 2023-12-22 12:21:11 +00:00)

# %%
model = model()
adam = Adam(learning_rate=0.001)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 600)]                0         []
#
#  embedding (Embedding)       (None, 600, 32)              113024    ['input_1[0][0]']
#
#  conv1d (Conv1D)             (None, 600, 32)              2080      ['embedding[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 300, 32)              0         ['conv1d[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 300, 32)              0         ['max_pooling1d[0][0]']
#
#  bidirectional (Bidirection  (None, 600, 64)              16640     ['embedding[0][0]']
#  al)
#
#  conv1d_1 (Conv1D)           (None, 300, 32)              2080      ['dropout[0][0]']
#
#  max_pooling1d_2 (MaxPoolin  (None, 300, 64)              0         ['bidirectional[0][0]']
#  g1D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 150, 32)              0         ['conv1d_1[0][0]']
#  g1D)
#
#  bidirectional_1 (Bidirecti  (None, 300, 64)              24832     ['max_pooling1d_2[0][0]']
#  onal)
#
#  layer_normalization (Layer  (None, 150, 32)              64        ['max_pooling1d_1[0][0]']
#  Normalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 150, 64)              0         ['bidirectional_1[0][0]']
#  g1D)
#
#  dropout_1 (Dropout)         (None, 150, 32)              0         ['layer_normalization[0][0]']
#
#  layer_normalization_1 (Lay  (None, 150, 64)              128       ['max_pooling1d_3[0][0]']
#  erNormalization)
#
#  concatenate (Concatenate)   (None, 150, 96)              0         ['dropout_1[0][0]',
#                                                                      'layer_normalization_1[0][0]'
#                                                                     ]
#
#  global_max_pooling1d (Glob  (None, 96)                   0         ['concatenate[0][0]']
#  alMaxPooling1D)
#
#  layer_normalization_2 (Lay  (None, 96)                   192       ['global_max_pooling1d[0][0]']
#  erNormalization)
#
#  dense (Dense)               (None, 70)                   6790      ['layer_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 70)                   0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 50)                   3550      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 50)                   0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 30)                   1530      ['dropout_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 30)                   0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 2)                    62        ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 170972 (667.86 KB)
# Trainable params: 170972 (667.86 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# time: 1.66 s (started: 2023-12-22 12:21:14 +00:00)

# %%
# fit model
callback_model = tf.keras.callbacks.ModelCheckpoint('CNN-BILSTM_model.h5',
                                                    monitor='val_loss')
history = model.fit(x=X_train, y=y_train, epochs=20, batch_size=128,
                    validation_split=0.1, callbacks=[callback_model])
# Out:
# Epoch 1/20
# 7/7 [==============================] - 15s 1s/step - loss: 0.7945 - accuracy: 0.5748 - val_loss: 0.5008 - val_accuracy: 0.8421
# Epoch 2/20
# 7/7 [==============================] - 6s 947ms/step - loss: 0.5034 - accuracy: 0.8363 - val_loss: 0.4358 - val_accuracy: 0.8421
# Epoch 3/20
# 7/7 [==============================] - 6s 907ms/step - loss: 0.4698 - accuracy: 0.8492 - val_loss: 0.4393 - val_accuracy: 0.8421
# Epoch 4/20
# 7/7 [==============================] - 7s 939ms/step - loss: 0.4552 - accuracy: 0.8516 - val_loss: 0.4337 - val_accuracy: 0.8421
# Epoch 5/20
# 7/7 [==============================] - 6s 822ms/step - loss: 0.4424 - accuracy: 0.8528 - val_loss: 0.4301 - val_accuracy: 0.8421
# Epoch 6/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.4406 - accuracy: 0.8528 - val_loss: 0.4295 - val_accuracy: 0.8421
# Epoch 7/20
# 7/7 [==============================] - 6s 831ms/step - loss: 0.4183 - accuracy: 0.8516 - val_loss: 0.4216 - val_accuracy: 0.8421
# Epoch 8/20
# 7/7 [==============================] - 6s 834ms/step - loss: 0.3922 - accuracy: 0.8516 - val_loss: 0.4127 - val_accuracy: 0.8421
# Epoch 9/20
# 7/7 [==============================] - 6s 895ms/step - loss: 0.3552 - accuracy: 0.8551 - val_loss: 0.4007 - val_accuracy: 0.8421
# Epoch 10/20
# 7/7 [==============================] - 6s 806ms/step - loss: 0.3387 - accuracy: 0.8598 - val_loss: 0.3849 - val_accuracy: 0.8421
# Epoch 11/20
# 7/7 [==============================] - 6s 907ms/step - loss: 0.2999 - accuracy: 0.8740 - val_loss: 0.3778 - val_accuracy: 0.8526
# Epoch 12/20
# 7/7 [==============================] - 6s 831ms/step - loss: 0.2478 - accuracy: 0.9128 - val_loss: 0.3462 - val_accuracy: 0.8632
# Epoch 13/20
# 7/7 [==============================] - 6s 939ms/step - loss: 0.1880 - accuracy: 0.9552 - val_loss: 0.4082 - val_accuracy: 0.8632
# Epoch 14/20
# 7/7 [==============================] - 6s 831ms/step - loss: 0.1113 - accuracy: 0.9764 - val_loss: 0.3454 - val_accuracy: 0.8737
# Epoch 15/20
# 7/7 [==============================] - 6s 929ms/step - loss: 0.0877 - accuracy: 0.9835 - val_loss: 0.3082 - val_accuracy: 0.8842
# Epoch 16/20
# 7/7 [==============================] - 6s 800ms/step - loss: 0.0668 - accuracy: 0.9870 - val_loss: 0.3840 - val_accuracy: 0.8842
# Epoch 17/20
# 7/7 [==============================] - 6s 928ms/step - loss: 0.0362 - accuracy: 0.9965 - val_loss: 0.5006 - val_accuracy: 0.8737
# Epoch 18/20
# 7/7 [==============================] - 6s 817ms/step - loss: 0.0747 - accuracy: 0.9812 - val_loss: 0.4813 - val_accuracy: 0.8737
# Epoch 19/20
# 7/7 [==============================] - 6s 901ms/step - loss: 0.0503 - accuracy: 0.9894 - val_loss: 0.3767 - val_accuracy: 0.8842
# Epoch 20/20
# 7/7 [==============================] - 6s 829ms/step - loss: 0.0343 - accuracy: 0.9953 - val_loss: 0.5125 - val_accuracy: 0.8947
# time: 2min 13s (started: 2023-12-22 12:21:21 +00:00)

# %%
model.load_weights('CNN-BILSTM_model.h5')
model.evaluate(X_test, y_test)
# Out:
# 8/8 [==============================] - 1s 86ms/step - loss: 0.6641 - accuracy: 0.8729
# [0.6641241312026978, 0.8728813529014587]
# time: 1.38 s (started: 2023-12-22 12:34:15 +00:00)

# %%
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)
print(classification_report(y_true_labels, y_pred_labels))
# Out:
# 8/8 [==============================] - 1s 82ms/step
#               precision    recall  f1-score   support
#
#            0       0.54      0.47      0.50        32
#            1       0.92      0.94      0.93       204
#
#     accuracy                           0.87       236
#    macro avg       0.73      0.70      0.71       236
# weighted avg       0.87      0.87      0.87       236
#
# time: 1.33 s (started: 2023-12-22 12:34:18 +00:00)

# %%
le = LabelEncoder()
true_labels_encoded = le.fit_transform(y_true_labels)
predicted_labels_encoded = le.transform(y_pred_labels)

cm = confusion_matrix(true_labels_encoded, predicted_labels_encoded)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Ma trận nhầm lẫn cho CNN & biLSTM trước khi gán trọng số nhãn S')
plt.show()
# Out:
# time: 443 ms (started: 2023-12-22 12:35:09 +00:00)

# %%
value_counts = df['nhãn'].value_counts()
# Print the number of occurrences for each unique value
for value, count in value_counts.items():
    print(f'{value}: {count}')
# Out:
# positive: 728
# negative: 113
# time: 13.7 ms (started: 2023-12-22 12:42:50 +00:00)

# %%
value_counts = df['nhãn'].value_counts()

# Plot a pie chart
plt.figure(figsize=(6, 6))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Tỷ lệ giữa 2 giá trị positive và negative')
plt.show()
# Out:
# time: 155 ms (started: 2023-12-22 12:37:53 +00:00)

# %%
# fit model nhma do data bị imbalance nên gán thêm trọng số weight
callback_model = tf.keras.callbacks.ModelCheckpoint('CNN-BILSTM_model.h5',
                                                    monitor='val_loss')
weights = {}
class_weights = compute_class_weight('balanced',
                classes=np.unique(label_pre), y=label_pre)
for index, weight in enumerate(class_weights) :
  weights[index] = weight

history = model.fit(x=X_train, y=y_train, class_weight=weights, epochs=20,
          batch_size=128, validation_split=0.1, callbacks=[callback_model])
# Out:
# Epoch 1/20
# 7/7 [==============================] - 10s 826ms/step - loss: 0.1031 - accuracy: 0.9764 - val_loss: 0.3314 - val_accuracy: 0.8842
# Epoch 2/20
# 7/7 [==============================] - 6s 940ms/step - loss: 0.0676 - accuracy: 0.9870 - val_loss: 0.2795 - val_accuracy: 0.9158
# Epoch 3/20
# 7/7 [==============================] - 6s 820ms/step - loss: 0.0587 - accuracy: 0.9894 - val_loss: 0.3225 - val_accuracy: 0.9263
# Epoch 4/20
# 7/7 [==============================] - 6s 941ms/step - loss: 0.0262 - accuracy: 0.9941 - val_loss: 0.3024 - val_accuracy: 0.8842
# Epoch 5/20
# 7/7 [==============================] - 6s 806ms/step - loss: 0.0447 - accuracy: 0.9918 - val_loss: 0.3134 - val_accuracy: 0.9263
# Epoch 6/20
# 7/7 [==============================] - 6s 932ms/step - loss: 0.0234 - accuracy: 0.9906 - val_loss: 0.2817 - val_accuracy: 0.9053
# Epoch 7/20
# 7/7 [==============================] - 6s 817ms/step - loss: 0.0303 - accuracy: 0.9953 - val_loss: 0.2914 - val_accuracy: 0.9263
# Epoch 8/20
# 7/7 [==============================] - 7s 1s/step - loss: 0.0505 - accuracy: 0.9859 - val_loss: 0.5365 - val_accuracy: 0.8842
# Epoch 9/20
# 7/7 [==============================] - 6s 819ms/step - loss: 0.0471 - accuracy: 0.9882 - val_loss: 0.2810 - val_accuracy: 0.9263
# Epoch 10/20
# 7/7 [==============================] - 7s 1s/step - loss: 0.0319 - accuracy: 0.9929 - val_loss: 0.2550 - val_accuracy: 0.9053
# Epoch 11/20
# 7/7 [==============================] - 6s 835ms/step - loss: 0.0241 - accuracy: 0.9929 - val_loss: 0.2651 - val_accuracy: 0.9263
# Epoch 12/20
# 7/7 [==============================] - 6s 850ms/step - loss: 0.0198 - accuracy: 0.9976 - val_loss: 0.3050 - val_accuracy: 0.9368
# Epoch 13/20
# 7/7 [==============================] - 6s 931ms/step - loss: 0.0132 - accuracy: 0.9941 - val_loss: 0.3367 - val_accuracy: 0.9263
# Epoch 14/20
# 7/7 [==============================] - 6s 838ms/step - loss: 0.0259 - accuracy: 0.9929 - val_loss: 0.3906 - val_accuracy: 0.9158
# Epoch 15/20
# 7/7 [==============================] - 6s 920ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.4380 - val_accuracy: 0.9053
# Epoch 16/20
# 7/7 [==============================] - 6s 817ms/step - loss: 0.0124 - accuracy: 0.9941 - val_loss: 0.3656 - val_accuracy: 0.9263
# Epoch 17/20
# 7/7 [==============================] - 7s 1s/step - loss: 0.0210 - accuracy: 0.9965 - val_loss: 0.3709 - val_accuracy: 0.9158
# Epoch 18/20
# 7/7 [==============================] - 6s 807ms/step - loss: 0.0190 - accuracy: 0.9918 - val_loss: 0.4297 - val_accuracy: 0.9053
# Epoch 19/20
# 7/7 [==============================] - 6s 912ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.3282 - val_accuracy: 0.9263
# Epoch 20/20
# 7/7 [==============================] - 6s 815ms/step - loss: 0.0261 - accuracy: 0.9965 - val_loss: 0.3204 - val_accuracy: 0.9368
# time: 2min 8s (started: 2023-12-22 12:25:49 +00:00)

# %%
model.load_weights('CNN-BILSTM_model.h5')
model.evaluate(X_test, y_test)
# Out:
# 8/8 [==============================] - 2s 240ms/step - loss: 0.6641 - accuracy: 0.8729
# [0.6641241312026978, 0.8728813529014587]
# time: 2.22 s (started: 2023-12-22 12:27:59 +00:00)

# %%
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)
print(classification_report(y_true_labels, y_pred_labels))
# Out:
# 8/8 [==============================] - 1s 84ms/step
#               precision    recall  f1-score   support
#
#            0       0.54      0.47      0.50        32
#            1       0.92      0.94      0.93       204
#
#     accuracy                           0.87       236
#    macro avg       0.73      0.70      0.71       236
# weighted avg       0.87      0.87      0.87       236
#
# time: 896 ms (started: 2023-12-22 12:28:02 +00:00)

# %%
le = LabelEncoder()
true_labels_encoded = le.fit_transform(y_true_labels)
predicted_labels_encoded = le.transform(y_pred_labels)

cm = confusion_matrix(true_labels_encoded, predicted_labels_encoded)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Ma trận nhầm lẫn cho CNN & biLSTM sau khi gán trọng số nhãn')
plt.show()
# Out:
# time: 197 ms (started: 2023-12-22 12:32:58 +00:00)

# %% [markdown]
# ###Dump mô hình và dự đoán

# %%
def get_vectorize(input, tokenizer):
    input_text_pre = list(tf.keras.preprocessing.text.text_to_word_sequence(input))
    input_text_pre = ' '.join(input_text_pre)
    input_text_pre_accent = ViTokenizer.tokenize(input_text_pre)
    print(f'Input đã được xử lý là: {input_text_pre_accent}')
    tokenized_data_text = tokenizer.texts_to_sequences([input_text_pre_accent])
    vec_data = pad_sequences(tokenized_data_text, padding='post', maxlen=600)
    return vec_data

def get_confidence(feature, model):
    label_dict = {'negative': 0, 'positive': 1}
    label = list(label_dict.keys())
    output = model(feature).numpy()[0]
    result = output.argmax()
    conf = float(output.max())
    return label[int(result)], conf

def get_prediction(input, tokenizer, model):
    input_model = get_vectorize(input, tokenizer)
    result, conf = get_confidence(input_model, model)
    return result, conf

model_using = load_model('CNN-BILSTM_model.h5', compile=False)
with open('tokenizer_data.pkl', 'rb') as file:
    tokenizer_using = pkl.load(file)

# %%
print(get_prediction('mấy chú bãi giữ xe hay đuổi sinh viên', tokenizer_using, model_using))
print(get_prediction('sinh viên nhiệt tình, hay giúp đỡ bạn bè', tokenizer_using, model_using))
# Out:
# Input đã được xử lý là: mấy chú bãi giữ xe hay đuổi sinh_viên
# ('negative', 1.0)
# Input đã được xử lý là: sinh_viên nhiệt_tình hay giúp_đỡ bạn_bè
# ('negative', 0.9999997615814209)

# %%
while(True):
    text = input('> Hãy nhập câu bất kỳ: ')
    print(get_prediction(text, tokenizer_using, model_using)[0]+'\n---')
    if (input('Tiếp tục (C/K)? ').upper() == 'K'):
        break
print('---\nKết thúc.')
# Out:
# > Hãy nhập câu bất kỳ: Trường tốt
# Input đã được xử lý là: trường tốt
# positive
# ---
# Tiếp tục (C/K)? K
# ---
# Kết thúc.

# %% [markdown]
# ###Trực quan kiến trúc mô hình
# Tham khảo: [visualkeras](www.analyticsvidhya.com/blog/2022/03/visualize-deep-learning-models-using-visualkeras/)

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # So sánh 3 mô hình

# %%
# kết quả metrics của 3 mô hình từ các file notebook trước
labels = ['Accuracy', 'Precision', 'Recall', 'F1-score']
nbc_metrics = [0.85, 0.87, 0.85, 0.85]
mc_metrics = [0.87, 0.88, 0.87, 0.87]
cb_metrics = [0.90, 0.90, 0.90, 0.90]

data = pd.DataFrame({
    'Model': ['NaiveBayesClassifier']*4 + ['MaxentClassifier']*4 + ['CNN & BiLSTM']*4,
    'Metric': labels*3,
    'Score': nbc_metrics + mc_metrics + cb_metrics
})
data
# Out:
#                    Model     Metric  Score
# 0   NaiveBayesClassifier   Accuracy   0.85
# 1   NaiveBayesClassifier  Precision   0.87
# 2   NaiveBayesClassifier     Recall   0.85
# 3   NaiveBayesClassifier   F1-score   0.85
# 4       MaxentClassifier   Accuracy   0.87
# 5       MaxentClassifier  Precision   0.88
# 6       MaxentClassifier     Recall   0.87
# 7       MaxentClassifier   F1-score   0.87
# 8           CNN & BiLSTM   Accuracy   0.90
# 9           CNN & BiLSTM  Precision   0.90
# 10          CNN & BiLSTM     Recall   0.90
# 11          CNN & BiLSTM   F1-score   0.90

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(8, 6))
plt.ylim(0, (max(data['Score'])+0.35))
sns.barplot(x='Metric', y='Score', hue='Model', data=data, width=0.7, palette='muted', dodge=True)
for i in plt.gca().patches:
    plt.gca().annotate(f'{i.get_height():.2f}', (i.get_x() + i.get_width()/2., i.get_height()),
            ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)
plt.title('BIỂU ĐỒ CỘT ĐÁNH GIÁ HIỆU SUẤT TỪNG MÔ HÌNH', fontsize=14, fontweight='bold')
plt.xlabel('Các chỉ số đánh giá')
plt.ylabel('Điểm số score')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# thời gian chạy
labels_execution = ['NaiveBayesClassifier', 'MaxentClassifier', 'CNN & BiLSTM']
execution_times = [0.2, 0.3, 10.85]
data_execution = {'Model': labels_execution, 'Time (s)': execution_times}
df_execution = pd.DataFrame(data_execution)

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(8, 6))
plt.ylim(0, (max(df_execution['Time (s)'])+1))
sns.barplot(x='Model', y='Time (s)', data=df_execution)
for i in plt.gca().patches:
    plt.gca().annotate(f'{i.get_height():.2f}', (i.get_x() + i.get_width()/2., i.get_height()),
            ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=10)
plt.title('BIỂU ĐỒ CỘT THỜI GIAN CHẠY CỦA TỪNG MÔ HÌNH', fontsize=14, fontweight='bold')
plt.xlabel('Mô hình')
plt.ylabel('Thời gian chạy (s)')
plt.tight_layout()
plt.show()
